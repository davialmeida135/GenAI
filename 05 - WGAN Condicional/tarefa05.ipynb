# %% [markdown]
# Código adaptado de:
#
# [1] David Foster, Generative Deep Learning: Teaching Machines to Paint, Write, Compose, and Play, Second Edition, O'Reilly, 2023.
#
# [2] Sayak Paul, Conditional GAN tutorial, disponível no site do Keras [(link)](https://keras.io/examples/generative/conditional_gan/).
#
# [3] Aurélien Géron, Hands-On Machine Learning with Scikit-Learn: Concepts, Tools and Techniques to Build Intelligent Systems, Keras & tensorFlow, Third Edition, O'Reilly, 2023.

# %% [markdown]
# # Importações

# %%
import torch                                # Importa a biblioteca principal do PyTorch, usada para computação com tensores
from torch import nn                        # Importa o módulo 'nn' do PyTorch, utilizado para criar e treinar redes neurais
from torch.utils.data import DataLoader     # Importa o DataLoader do PyTorch, que facilita o carregamento de dados em mini-lotes (batches).
import torch.nn.functional as F             # Importa funções comuns de ativação e perda do PyTorch, usadas fora do módulo nn.Module (ex.: ReLU, cross_entropy, etc.)
from torchvision import datasets            # Importa o módulo de conjuntos de dados do torchvision, que fornece acesso a conjuntos de dados populares como MNIST, CIFAR, etc. para visão computacional
from torchvision import transforms          # Importa o módulo de transforms do torchvision, usado para pré-processar imagens (conversão em tensor, normalização, etc.).
from torchinfo import summary               # Importa a função summary da biblioteca torchinfo, usada para exibir a arquitetura do modelo
import numpy as np                          # Importa a biblioteca NumPy, usada para operações numéricas eficientes com arrays e matrizes.
import matplotlib.pyplot as plt             # Importa o módulo de visualização matplotlib para gerar gráficos.
from IPython.display import Image           # Importa a classe Image do IPython, usada para exibir imagens diretamente dentro de notebooks.
import gdown                                # Importa utilitário para baixar arquivos do Google Drive via link público
import os                                   # Importa o módulo padrão do Python para interagir com o sistema operacional (ex.: criar pastas, manipular caminhos de arquivos).
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE" # Ajusta a variável de ambiente para evitar erros ao carregar múltiplas bibliotecas MKL

# %%
# Para figuras geradas pelo matplotlib serem exibidas diretamente no notebook
# %matplotlib inline

# %% [markdown]
# # Baixar e carregar os dados

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x * 2.0 - 1.0),
])

# Baixa os dados de treinamento a partir de conjuntos de dados públicos
training_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=True,              # Indica que este é o conjunto de dados de treinamento
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# Baixa os dados de teste a partir de conjuntos de dados públicos
test_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=False,             # Indica que este é o conjunto de dados de teste
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# %%
# Lista com os nomes das classes do conjunto de dados Fashion MNIST, na mesma ordem dos índices
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Dicionário para armazenar um exemplo por classe
examples = {}

# Itera sobre o dataset até obter um exemplo de cada classe
for img, label in training_data:
    if label not in examples:
        examples[label] = img.squeeze()  # remove o canal extra (1, 28, 28) -> (28, 28)
    if len(examples) == 10:
        break

# Plota os exemplos
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(examples[i], cmap="gray")
    plt.title(classes[i])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
batch_size = 64                                                      # Define o tamanho do lote, ou seja, quantas amostras serão processadas por vez
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True, drop_last=True)  # Cria o DataLoader para o conjunto de treinamento
test_dataloader = DataLoader(test_data, batch_size=batch_size)       # Cria o DataLoader para o conjunto de teste

# Itera sobre o DataLoader de teste para visualizar as formas dos dados
for X, y in test_dataloader:
    # Exibe a forma e o tipo do tensor de imagens
    # N = tamanho do lote, C = canais (1 para imagens em tons de cinza), H = altura, W = largura
    print(f"Forma de X [N, C, H, W]: {X.shape}, Tipo de dados em X: {X.dtype}")

    # Exibe a forma e o tipo dos rótulos (labels)
    print(f"Forma de y [N, ] : {y.shape}, Tipo de dados em y: {y.dtype}")

    break  # Encerra o loop após a primeira iteração, apenas para inspeção dos dados
# Out:
# Forma de X [N, C, H, W]: torch.Size([64, 1, 28, 28]), Tipo de dados em X: torch.float32
# Forma de y [N, ] : torch.Size([64]), Tipo de dados em y: torch.int64

# %% [markdown]
# # Redes Neurais

# %% [markdown]
# ## Gerador

# %%
class Gerador(nn.Module):
    def __init__(self, z_dim=100, num_classes=10):
        super().__init__()

        # Definimos a rede sequencial do gerador
        self.rede_neural = nn.Sequential(

            # Camada totalmente conectada                                                       # Entrada: (lote, z_dim + num_classes)  (vetor de ruído z concatenado com rótulo com codificação one-hot)
            nn.Linear(z_dim + num_classes, 7 * 7 * 128),

            # Transforma o vetor 1D em um tensor 3D para convoluções
            nn.Unflatten(1, (128, 7, 7)),

            # Normalização em lote
            nn.BatchNorm2d(128),

            # Primeira convolução transposta
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.ReLU(),  # Função de ativação ReLU

            # Normalização em lote
            nn.BatchNorm2d(64),

            # Segunda convolução transposta
            nn.ConvTranspose2d(64, 1, kernel_size=5, stride=2, padding=2, output_padding=1),

            # Função de ativação final Tanh: valores de saída entre [-1, 1]
            nn.Tanh()
        )

    def forward(self, z, rotulo_one_hot):
        # Concatena o vetor de ruído com o vetor de rótulo one-hot:
        entrada = torch.cat([z, rotulo_one_hot], dim=1)  # Entrada: (lote, z_dim + num_classes)
        return self.rede_neural(entrada)                 # Saída: (lote, 1, 28, 28)

# %% [markdown]
# ## Discriminador

# %%
class Discriminador(nn.Module):
    def __init__(self, num_classes=10, tam_img=28):
        super().__init__()

        # Número de classes
        self.num_classes = num_classes

        # Tamanho da imagem
        self.tam_img = tam_img

        # Definição da rede convolucional sequencial
        self.rede_neural = nn.Sequential(

            # Primeira camada convolucional                                                                 # entrada: [lote, 1 + 10, 28, 28] (1 canal da imagem + canais do rótulo)
            nn.Conv2d(in_channels=1 + num_classes, out_channels=64, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(0.4),

            # Segunda camada convolucional
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(0.4),

            # Achatar o tensor 3D para um vetor 1D
            nn.Flatten(),

            # Camada totalmente conectada
            nn.Linear(7 * 7 * 128, 1),
        )


    def forward(self, imagem, rotulos_one_hot):
        # imagem: (B, 1, H, W) | rotulos_one_hot: (B, C)
        _, _, H, W = imagem.shape

        # (B, C, 1, 1) -> (B, C, H, W)  [expand cria uma view]
        # Cria um tensor do tamanho da imagem, preenchido com os valores do rótulo one-hot, onde cada canal corresponde a um rótulo
        mapa_rotulo = rotulos_one_hot[:, :, None, None].expand(-1, -1, H, W)

        # (B, 1+C, H, W)  [concatenar a imagem com o mapa de rótulo no eixo de canais]
        entrada = torch.cat((imagem, mapa_rotulo), dim=1)

        # Passar pela rede convolucional
        return self.rede_neural(entrada)

# %% [markdown]
# # Configurar Treinamento

# %%
def train_wgan_condicional(
    dataloader,
    gerador,
    discriminador,
    opt_gerador,
    opt_discriminador,
    device,
    epoch,
    z_dim,
    n_critic=5,
    clip_value=0.01,
    num_classes=10,
):

    gerador.train()
    discriminador.train()

    for batch_idx, (dados_reais, rotulos_reais) in enumerate(dataloader):
        batch_size = dados_reais.size(0)
        dados_reais = dados_reais.to(device)
        rotulos_reais = rotulos_reais.to(device)

        # Converte os rótulos reais para one-hot
        rotulos_reais_one_hot = F.one_hot(rotulos_reais, num_classes=num_classes).float()

        # Envia para o dispositivo (GPU/CPU)
        rotulos_reais_one_hot = rotulos_reais_one_hot.to(device)

        # ========================================
        # DISCRIMINADOR
        # ========================================
        for _ in range(n_critic):

            # Gera ruído z
            z = torch.randn((batch_size, z_dim), device=device)

            # Gera dados falsos USANDO OS MESMOS RÓTULOS REAIS (matching label approach)
            dados_falsos = gerador(z, rotulos_reais_one_hot)

            # Avalia dados reais (imagem real + rótulo real)
            saida_reais = discriminador(dados_reais, rotulos_reais_one_hot)

            # Avalia dados falsos (imagem gerada + rótulo real)
            # detach() evita backprop no gerador nessa fase
            # FIXME Teste sem .detach()
            saida_falsos = discriminador(dados_falsos, rotulos_reais_one_hot)

            # Perda do discriminador: soma das perdas para dados reais e falsos
            perda_discriminador = saida_falsos.mean() - saida_reais.mean()

            # Otimiza o discriminador
            opt_discriminador.zero_grad()
            perda_discriminador.backward()
            opt_discriminador.step()

            # Clipping dos pesos do discriminador para satisfazer Lipschitz
            for p in discriminador.parameters():
                p.data.clamp_(-clip_value, clip_value)

        # ========================================
        # GERADOR
        # ========================================

        # Gera novo ruído z
        z = torch.randn((batch_size, z_dim), device=device)

        # Gera dados falsos novamente (com os rótulos reais do batch)
        dados_falsos = gerador(z, rotulos_reais_one_hot)

        # Faz o discriminador avaliar estes dados falsos
        saida_falsos = discriminador(dados_falsos, rotulos_reais_one_hot)

        # Perda do gerador: queremos que o discriminador ache que são reais
        perda_gerador = -saida_falsos.mean()

        # Otimiza o gerador
        opt_gerador.zero_grad()
        perda_gerador.backward()
        opt_gerador.step()

        # ========================================
        # LOG
        # ========================================
        if batch_idx % 100 == 0 or batch_idx == len(dataloader) - 1:
            print(f"[Época {epoch:03d}] [Lote {batch_idx:03d}/{len(dataloader)}] "
                  f"Perda D: {perda_discriminador.item():.4f} | "
                  f"Perda G: {perda_gerador.item():.4f}")

# %%
# Define a função de gerar dados falsos de um vetor latente fixo
def gerar(gerador, device, z_dim=30, num_classes=10, c=0):
    gerador.eval()        # Coloca o modelo em modo de avaliação (desativa dropout, batchnorm, etc.)
    with torch.no_grad(): # Desativa o cálculo de gradientes para economizar memória e acelerar a execução
      z = torch.zeros((1, z_dim), device=device)
      c_tensor = torch.tensor([c], device=device)
      rotulo_one_hot = F.one_hot(c_tensor, num_classes=num_classes).float()
      dados_falsos = gerador(z, rotulo_one_hot).detach().cpu().numpy().reshape(28,28)
    return dados_falsos

# %% [markdown]
# # Executar Treinamento

# %%
# Inicializa os gerador
z_dim = 100
modelo_gerador = Gerador(z_dim)
# Imprime a arquitetura do modelo
print(modelo_gerador)
summary(modelo_gerador, input_size=[(1, 100), (1, 10)])
# Out:
# Gerador(
#   (rede_neural): Sequential(
#     (0): Linear(in_features=110, out_features=6272, bias=True)
#     (1): Unflatten(dim=1, unflattened_size=(128, 7, 7))
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ConvTranspose2d(64, 1, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (7): Tanh()
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Gerador                                  [1, 1, 28, 28]            --
# ├─Sequential: 1-1                        [1, 1, 28, 28]            --
# │    └─Linear: 2-1                       [1, 6272]                 696,192
# │    └─Unflatten: 2-2                    [1, 128, 7, 7]            --
# │    └─BatchNorm2d: 2-3                  [1, 128, 7, 7]            256
# │    └─ConvTranspose2d: 2-4              [1, 64, 14, 14]           204,864
# │    └─ReLU: 2-5                         [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-6                  [1, 64, 14, 14]           128
# │    └─ConvTranspose2d: 2-7              [1, 1, 28, 28]            1,601
# │    └─Tanh: 2-8                         [1, 1, 28, 28]            --
# ==========================================================================================
# Total params: 903,041
# Trainable params: 903,041
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 42.11
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 3.61
# Estimated Total Size (MB): 3.92
# ==========================================================================================

# %%
# Inicializa os discriminador
modelo_discriminador = Discriminador()
# Imprime a arquitetura do modelo
print(modelo_discriminador)
summary(modelo_discriminador, input_size=[(1, 1, 28, 28), (1, 10)])
# Out:
# Discriminador(
#   (rede_neural): Sequential(
#     (0): Conv2d(11, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6272, out_features=1, bias=True)
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Discriminador                            [1, 1]                    --
# ├─Sequential: 1-1                        [1, 1]                    --
# │    └─Conv2d: 2-1                       [1, 64, 14, 14]           17,664
# │    └─LeakyReLU: 2-2                    [1, 64, 14, 14]           --
# │    └─Dropout: 2-3                      [1, 64, 14, 14]           --
# │    └─Conv2d: 2-4                       [1, 128, 7, 7]            204,928
# │    └─LeakyReLU: 2-5                    [1, 128, 7, 7]            --
# │    └─Dropout: 2-6                      [1, 128, 7, 7]            --
# │    └─Flatten: 2-7                      [1, 6272]                 --
# │    └─Linear: 2-8                       [1, 1]                    6,273
# ==========================================================================================
# Total params: 228,865
# Trainable params: 228,865
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 13.51
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.15
# Params size (MB): 0.92
# Estimated Total Size (MB): 1.07
# ==========================================================================================

# %%
# Tenta usar GPU se disponível
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
modelo_gerador.to(device)
modelo_discriminador.to(device)

# Exibe qual dispositivo está sendo utilizado
print(f"Usando {device}.")
# Out:
# Usando cuda.

# %%
# Otimizadores
lr_gerador = 1e-4         # taxa de aprendizagem do gerador
lr_discriminador = 1e-4   # taxa de aprendizagem do discriminador
optimizador_gerador = torch.optim.RMSprop(modelo_gerador.parameters(), lr=lr_gerador)
optimizador_discriminador = torch.optim.RMSprop(modelo_discriminador.parameters(), lr=lr_discriminador)

# %%
num_epochs = 50  # Define o número total de épocas (iterações completas sobre o conjunto de dados de treinamento)
evolução_dado_falso = []
for epoca in range(1, num_epochs + 1):
    train_wgan_condicional(
        dataloader=train_dataloader,
        gerador=modelo_gerador,
        discriminador=modelo_discriminador,
        opt_gerador=optimizador_gerador,
        opt_discriminador=optimizador_discriminador,
        device=device,
        epoch=epoca,
        z_dim=z_dim,
        n_critic=5,
        clip_value=0.01,
        num_classes=10
    )
    if epoca % 5 == 0 or epoca == 1:
      dados_falsos = gerar(gerador=modelo_gerador, device=device, z_dim=z_dim, num_classes=10, c=0)
      plt.imshow(dados_falsos, cmap="gray")
      plt.axis("off")
      plt.title(f"Época {epoca}")
      plt.imsave(f"dados_falsos_epoca_{epoca}.png", dados_falsos, cmap="gray")
      evolução_dado_falso.append(dados_falsos)
print("Fim!")  # Exibe mensagem final indicando que o treinamento terminou
# Out:
# [Época 001] [Lote 000/937] Perda D: -0.1811 | Perda G: 0.1200
# [Época 001] [Lote 100/937] Perda D: -3.0423 | Perda G: -3.8161
# [Época 001] [Lote 200/937] Perda D: -0.6763 | Perda G: 0.9264
# [Época 001] [Lote 300/937] Perda D: -3.7938 | Perda G: -2.4853
# [Época 001] [Lote 400/937] Perda D: -1.8514 | Perda G: 5.2866
# [Época 001] [Lote 500/937] Perda D: -2.4336 | Perda G: -3.7130
# [Época 001] [Lote 600/937] Perda D: -0.4324 | Perda G: -7.2321
# [Época 001] [Lote 700/937] Perda D: -0.9619 | Perda G: -2.2212
# [Época 001] [Lote 800/937] Perda D: -0.4502 | Perda G: -3.7265
# [Época 001] [Lote 900/937] Perda D: -0.5157 | Perda G: -3.6873
# [Época 001] [Lote 936/937] Perda D: -0.5837 | Perda G: -4.5779
# [Época 002] [Lote 000/937] Perda D: -0.5505 | Perda G: -3.9910
# [Época 002] [Lote 100/937] Perda D: -0.5820 | Perda G: -4.3701
# [Época 002] [Lote 200/937] Perda D: -1.7337 | Perda G: -10.3269
# [Época 002] [Lote 300/937] Perda D: -0.9731 | Perda G: -6.9582
# [Época 002] [Lote 400/937] Perda D: -1.2144 | Perda G: -3.0706
# [Época 002] [Lote 500/937] Perda D: -1.0008 | Perda G: -5.5075
# [Época 002] [Lote 600/937] Perda D: -0.7156 | Perda G: -7.8506
# [Época 002] [Lote 700/937] Perda D: -1.0780 | Perda G: -6.7430
# [Época 002] [Lote 800/937] Perda D: -1.1569 | Perda G: -7.8419
# [Época 002] [Lote 900/937] Perda D: -0.6718 | Perda G: -7.2223
# [Época 002] [Lote 936/937] Perda D: -0.7743 | Perda G: -3.4971
# [Época 003] [Lote 000/937] Perda D: -0.5476 | Perda G: -4.5003
# [Época 003] [Lote 100/937] Perda D: -1.1339 | Perda G: -0.3349
# [Época 003] [Lote 200/937] Perda D: -1.0930 | Perda G: -0.3164
# [Época 003] [Lote 300/937] Perda D: -0.9831 | Perda G: -5.7797
# [Época 003] [Lote 400/937] Perda D: -0.1793 | Perda G: 1.6751
# [Época 003] [Lote 500/937] Perda D: -0.5930 | Perda G: -4.6089
# [Época 003] [Lote 600/937] Perda D: -0.2050 | Perda G: -2.0372
# [Época 003] [Lote 700/937] Perda D: -0.5915 | Perda G: -2.2697
# [Época 003] [Lote 800/937] Perda D: -0.2148 | Perda G: 3.5798
# [Época 003] [Lote 900/937] Perda D: 0.5214 | Perda G: -4.9265
# [Época 003] [Lote 936/937] Perda D: -0.6998 | Perda G: -2.4781
# [Época 004] [Lote 000/937] Perda D: -0.0520 | Perda G: -0.9023
# [Época 004] [Lote 100/937] Perda D: -0.3052 | Perda G: -3.8332
# [Época 004] [Lote 200/937] Perda D: -0.8116 | Perda G: -1.1062
# [Época 004] [Lote 300/937] Perda D: -0.4994 | Perda G: -0.2541
# [Época 004] [Lote 400/937] Perda D: -0.1854 | Perda G: 4.9539
# [Época 004] [Lote 500/937] Perda D: -0.5916 | Perda G: 1.4137
# [Época 004] [Lote 600/937] Perda D: -0.6191 | Perda G: 2.6118
# [Época 004] [Lote 700/937] Perda D: -0.7161 | Perda G: -3.2874
# [Época 004] [Lote 800/937] Perda D: -0.5082 | Perda G: -1.8425
# [Época 004] [Lote 900/937] Perda D: -0.4449 | Perda G: -0.5665
# [Época 004] [Lote 936/937] Perda D: 0.0190 | Perda G: -7.2516
# [Época 005] [Lote 000/937] Perda D: -0.3210 | Perda G: 0.0977
# [Época 005] [Lote 100/937] Perda D: -0.6288 | Perda G: 6.6985
# [Época 005] [Lote 200/937] Perda D: -0.2583 | Perda G: -2.5091
# [Época 005] [Lote 300/937] Perda D: -0.4046 | Perda G: -3.2294
# [Época 005] [Lote 400/937] Perda D: -0.4595 | Perda G: 2.4459
# [Época 005] [Lote 500/937] Perda D: -0.7341 | Perda G: 4.9332
# [Época 005] [Lote 600/937] Perda D: -0.3397 | Perda G: 2.2524
# [Época 005] [Lote 700/937] Perda D: -0.6350 | Perda G: -11.4848
# [Época 005] [Lote 800/937] Perda D: -0.3604 | Perda G: -0.0350
# [Época 005] [Lote 900/937] Perda D: -0.7825 | Perda G: -4.5187
# [Época 005] [Lote 936/937] Perda D: 0.0318 | Perda G: -5.9433
# [Época 006] [Lote 000/937] Perda D: -0.3728 | Perda G: -6.4267
# [Época 006] [Lote 100/937] Perda D: -1.0497 | Perda G: 8.8253
# [Época 006] [Lote 200/937] Perda D: 0.2378 | Perda G: -1.7043
# [Época 006] [Lote 300/937] Perda D: -0.4206 | Perda G: 1.0516
# [Época 006] [Lote 400/937] Perda D: -0.6532 | Perda G: -2.8877
# [Época 006] [Lote 500/937] Perda D: -0.9752 | Perda G: 5.6619
# [Época 006] [Lote 600/937] Perda D: -0.0603 | Perda G: 4.1208
# [Época 006] [Lote 700/937] Perda D: 0.0137 | Perda G: -2.6143
# [Época 006] [Lote 800/937] Perda D: 0.3933 | Perda G: -6.0865
# [Época 006] [Lote 900/937] Perda D: -0.3614 | Perda G: 5.5357
# [Época 006] [Lote 936/937] Perda D: 0.0568 | Perda G: 4.5176
# [Época 007] [Lote 000/937] Perda D: -0.4920 | Perda G: 0.1869
# [Época 007] [Lote 100/937] Perda D: -1.1960 | Perda G: 6.1993
# [Época 007] [Lote 200/937] Perda D: -0.5640 | Perda G: 11.9289
# [Época 007] [Lote 300/937] Perda D: -0.2049 | Perda G: -3.8752
# [Época 007] [Lote 400/937] Perda D: -0.3012 | Perda G: -3.5351
# [Época 007] [Lote 500/937] Perda D: -0.5314 | Perda G: -1.0893
# [Época 007] [Lote 600/937] Perda D: 0.2059 | Perda G: 2.9402
# [Época 007] [Lote 700/937] Perda D: 0.0331 | Perda G: -0.3329
# [Época 007] [Lote 800/937] Perda D: -0.1685 | Perda G: -3.7803
# [Época 007] [Lote 900/937] Perda D: 0.0441 | Perda G: 1.2441
# [Época 007] [Lote 936/937] Perda D: 0.4848 | Perda G: -6.9464
# [Época 008] [Lote 000/937] Perda D: -0.0676 | Perda G: -5.3219
# [Época 008] [Lote 100/937] Perda D: -0.4467 | Perda G: 1.1870
# [Época 008] [Lote 200/937] Perda D: -0.1463 | Perda G: 2.1526
# [Época 008] [Lote 300/937] Perda D: -0.0604 | Perda G: -6.4827
# [Época 008] [Lote 400/937] Perda D: 0.0088 | Perda G: 5.1626
# [Época 008] [Lote 500/937] Perda D: -0.1140 | Perda G: 2.8478
# [Época 008] [Lote 600/937] Perda D: -0.4952 | Perda G: -0.5438
# [Época 008] [Lote 700/937] Perda D: -0.0198 | Perda G: 1.4746
# [Época 008] [Lote 800/937] Perda D: -0.6036 | Perda G: -1.3609
# [Época 008] [Lote 900/937] Perda D: 0.2275 | Perda G: -0.1504
# [Época 008] [Lote 936/937] Perda D: -0.5477 | Perda G: 7.0335
# [Época 009] [Lote 000/937] Perda D: -0.6354 | Perda G: 7.1251
# [Época 009] [Lote 100/937] Perda D: -0.6853 | Perda G: -5.5508
# [Época 009] [Lote 200/937] Perda D: -0.4833 | Perda G: -8.2000
# [Época 009] [Lote 300/937] Perda D: -1.1884 | Perda G: 8.2696
# [Época 009] [Lote 400/937] Perda D: -0.5856 | Perda G: 4.8625
# [Época 009] [Lote 500/937] Perda D: -0.5974 | Perda G: 9.1548
# [Época 009] [Lote 600/937] Perda D: -0.3025 | Perda G: 2.0596
# [Época 009] [Lote 700/937] Perda D: -0.9507 | Perda G: -5.7903
# [Época 009] [Lote 800/937] Perda D: -0.1065 | Perda G: -1.0409
# [Época 009] [Lote 900/937] Perda D: 0.0621 | Perda G: -0.3770
# [Época 009] [Lote 936/937] Perda D: -0.6995 | Perda G: 1.7544
# [Época 010] [Lote 000/937] Perda D: -1.0553 | Perda G: 4.8134
# [Época 010] [Lote 100/937] Perda D: -0.5585 | Perda G: -5.6961
# [Época 010] [Lote 200/937] Perda D: -0.0290 | Perda G: -5.8969
# [Época 010] [Lote 300/937] Perda D: -0.5170 | Perda G: 5.8556
# [Época 010] [Lote 400/937] Perda D: -0.4024 | Perda G: -3.1658
# [Época 010] [Lote 500/937] Perda D: 0.0661 | Perda G: 7.7174
# [Época 010] [Lote 600/937] Perda D: 0.1220 | Perda G: -1.3938
# [Época 010] [Lote 700/937] Perda D: 0.3463 | Perda G: -10.0977
# [Época 010] [Lote 800/937] Perda D: -0.1209 | Perda G: 4.6065
# [Época 010] [Lote 900/937] Perda D: -0.1400 | Perda G: 4.1717
# [Época 010] [Lote 936/937] Perda D: -0.2418 | Perda G: -15.5237
# [Época 011] [Lote 000/937] Perda D: -0.3837 | Perda G: -14.4167
# [Época 011] [Lote 100/937] Perda D: 0.2290 | Perda G: 5.1765
# [Época 011] [Lote 200/937] Perda D: 0.5278 | Perda G: -0.2156
# [Época 011] [Lote 300/937] Perda D: -0.3211 | Perda G: -12.7133
# [Época 011] [Lote 400/937] Perda D: 1.1232 | Perda G: 8.3879
# [Época 011] [Lote 500/937] Perda D: -0.2584 | Perda G: 7.7829
# [Época 011] [Lote 600/937] Perda D: -0.3215 | Perda G: 1.6410
# [Época 011] [Lote 700/937] Perda D: -0.1399 | Perda G: 2.2217
# [Época 011] [Lote 800/937] Perda D: 0.0925 | Perda G: 2.7481
# [Época 011] [Lote 900/937] Perda D: -0.2837 | Perda G: 5.4920
# [Época 011] [Lote 936/937] Perda D: -0.1121 | Perda G: 7.7823
# [Época 012] [Lote 000/937] Perda D: 0.5253 | Perda G: 6.3225
# [Época 012] [Lote 100/937] Perda D: -0.5827 | Perda G: 1.4543
# [Época 012] [Lote 200/937] Perda D: 0.1387 | Perda G: 1.7017
# [Época 012] [Lote 300/937] Perda D: 0.1252 | Perda G: 1.0510
# [Época 012] [Lote 400/937] Perda D: -1.1039 | Perda G: -14.1607
# [Época 012] [Lote 500/937] Perda D: -1.5577 | Perda G: 7.6291
# [Época 012] [Lote 600/937] Perda D: -0.1020 | Perda G: 6.0950
# [Época 012] [Lote 700/937] Perda D: 0.7623 | Perda G: -15.2023
# [Época 012] [Lote 800/937] Perda D: -0.2617 | Perda G: 2.8892
# [Época 012] [Lote 900/937] Perda D: -0.7083 | Perda G: 7.9682
# [Época 012] [Lote 936/937] Perda D: -0.0151 | Perda G: -6.5569
# [Época 013] [Lote 000/937] Perda D: 0.5032 | Perda G: -4.1263
# [Época 013] [Lote 100/937] Perda D: 0.1843 | Perda G: -6.4731
# [Época 013] [Lote 200/937] Perda D: -0.3338 | Perda G: -7.7318
# [Época 013] [Lote 300/937] Perda D: -0.6594 | Perda G: -4.9534
# [Época 013] [Lote 400/937] Perda D: -0.7772 | Perda G: 5.4003
# [Época 013] [Lote 500/937] Perda D: -1.9154 | Perda G: 10.4822
# [Época 013] [Lote 600/937] Perda D: -0.6609 | Perda G: 3.6167
# [Época 013] [Lote 700/937] Perda D: 0.6165 | Perda G: -10.4410
# [Época 013] [Lote 800/937] Perda D: 0.5410 | Perda G: 9.4766
# [Época 013] [Lote 900/937] Perda D: -0.7186 | Perda G: 3.4614
# [Época 013] [Lote 936/937] Perda D: -1.1846 | Perda G: 4.9117
# [Época 014] [Lote 000/937] Perda D: -0.4970 | Perda G: 4.3536
# [Época 014] [Lote 100/937] Perda D: -0.7277 | Perda G: 6.4369
# [Época 014] [Lote 200/937] Perda D: -0.8002 | Perda G: 7.6429
# [Época 014] [Lote 300/937] Perda D: -0.1258 | Perda G: -1.7470
# [Época 014] [Lote 400/937] Perda D: 0.5508 | Perda G: -9.8767
# [Época 014] [Lote 500/937] Perda D: 0.0718 | Perda G: -2.6102
# [Época 014] [Lote 600/937] Perda D: -0.7139 | Perda G: -0.5891
# [Época 014] [Lote 700/937] Perda D: -0.2258 | Perda G: 7.4776
# [Época 014] [Lote 800/937] Perda D: -0.0952 | Perda G: 4.7714
# [Época 014] [Lote 900/937] Perda D: 0.5388 | Perda G: -5.4968
# [Época 014] [Lote 936/937] Perda D: -0.1357 | Perda G: 0.8302
# [Época 015] [Lote 000/937] Perda D: -0.5910 | Perda G: -0.5666
# [Época 015] [Lote 100/937] Perda D: 0.2269 | Perda G: 0.3022
# [Época 015] [Lote 200/937] Perda D: -1.6734 | Perda G: 13.1432
# [Época 015] [Lote 300/937] Perda D: 0.1086 | Perda G: 4.9628
# [Época 015] [Lote 400/937] Perda D: -0.4876 | Perda G: 8.9650
# [Época 015] [Lote 500/937] Perda D: -0.0741 | Perda G: -2.1541
# [Época 015] [Lote 600/937] Perda D: -1.9679 | Perda G: -13.6502
# [Época 015] [Lote 700/937] Perda D: -0.4333 | Perda G: -3.0085
# [Época 015] [Lote 800/937] Perda D: -0.2746 | Perda G: -0.7329
# [Época 015] [Lote 900/937] Perda D: -0.5607 | Perda G: -11.1620
# [Época 015] [Lote 936/937] Perda D: -0.5906 | Perda G: 2.9391
# [Época 016] [Lote 000/937] Perda D: 0.1327 | Perda G: 0.8951
# [Época 016] [Lote 100/937] Perda D: -0.6328 | Perda G: 5.7056
# [Época 016] [Lote 200/937] Perda D: 0.1109 | Perda G: -4.3416
# [Época 016] [Lote 300/937] Perda D: 0.0848 | Perda G: 11.8187
# [Época 016] [Lote 400/937] Perda D: 0.8165 | Perda G: -7.4247
# [Época 016] [Lote 500/937] Perda D: -0.2119 | Perda G: -3.2389
# [Época 016] [Lote 600/937] Perda D: 0.1238 | Perda G: -2.9903
# [Época 016] [Lote 700/937] Perda D: -0.0397 | Perda G: 0.6861
# [Época 016] [Lote 800/937] Perda D: -1.2401 | Perda G: -13.3214
# [Época 016] [Lote 900/937] Perda D: -0.5606 | Perda G: -3.7699
# [Época 016] [Lote 936/937] Perda D: -0.1618 | Perda G: -0.2023
# [Época 017] [Lote 000/937] Perda D: -0.1865 | Perda G: 0.2216
# [Época 017] [Lote 100/937] Perda D: 0.1522 | Perda G: -4.0840
# [Época 017] [Lote 200/937] Perda D: 0.3699 | Perda G: -4.8578
# [Época 017] [Lote 300/937] Perda D: -0.1040 | Perda G: 1.3319
# [Época 017] [Lote 400/937] Perda D: 0.1344 | Perda G: -2.5938
# [Época 017] [Lote 500/937] Perda D: 0.0238 | Perda G: 6.6450
# [Época 017] [Lote 600/937] Perda D: -0.0456 | Perda G: 0.7689
# [Época 017] [Lote 700/937] Perda D: -0.1341 | Perda G: -0.7430
# [Época 017] [Lote 800/937] Perda D: -0.4453 | Perda G: -7.5855
# [Época 017] [Lote 900/937] Perda D: -0.1107 | Perda G: 1.9200
# [Época 017] [Lote 936/937] Perda D: -0.0866 | Perda G: 1.2943
# [Época 018] [Lote 000/937] Perda D: -0.7484 | Perda G: 3.7306
# [Época 018] [Lote 100/937] Perda D: -0.3948 | Perda G: 4.3674
# [Época 018] [Lote 200/937] Perda D: -0.6903 | Perda G: -17.1535
# [Época 018] [Lote 300/937] Perda D: -0.1810 | Perda G: 4.1098
# [Época 018] [Lote 400/937] Perda D: -3.9543 | Perda G: -28.1510
# [Época 018] [Lote 500/937] Perda D: -0.3084 | Perda G: 0.9246
# [Época 018] [Lote 600/937] Perda D: 0.2679 | Perda G: 1.9433
# [Época 018] [Lote 700/937] Perda D: 0.0393 | Perda G: 0.7352
# [Época 018] [Lote 800/937] Perda D: -0.6604 | Perda G: -0.0954
# [Época 018] [Lote 900/937] Perda D: -0.5475 | Perda G: -7.4168
# [Época 018] [Lote 936/937] Perda D: -0.5481 | Perda G: 5.4675
# [Época 019] [Lote 000/937] Perda D: -0.1176 | Perda G: 5.3159
# [Época 019] [Lote 100/937] Perda D: -0.1229 | Perda G: -5.1518
# [Época 019] [Lote 200/937] Perda D: -1.3306 | Perda G: -10.9021
# [Época 019] [Lote 300/937] Perda D: 0.0730 | Perda G: 2.5190
# [Época 019] [Lote 400/937] Perda D: -1.7033 | Perda G: -17.9704
# [Época 019] [Lote 500/937] Perda D: -0.2617 | Perda G: -11.9242
# [Época 019] [Lote 600/937] Perda D: 0.5263 | Perda G: -9.6912
# [Época 019] [Lote 700/937] Perda D: -4.4755 | Perda G: -24.9752
# [Época 019] [Lote 800/937] Perda D: 0.6110 | Perda G: -10.8602
# [Época 019] [Lote 900/937] Perda D: -0.0123 | Perda G: 5.1057
# [Época 019] [Lote 936/937] Perda D: -0.2452 | Perda G: 4.9313
# [Época 020] [Lote 000/937] Perda D: -0.3102 | Perda G: 1.9889
# [Época 020] [Lote 100/937] Perda D: -0.2029 | Perda G: -0.6348
# [Época 020] [Lote 200/937] Perda D: 0.1447 | Perda G: -20.6960
# [Época 020] [Lote 300/937] Perda D: -1.1652 | Perda G: 4.9342
# [Época 020] [Lote 400/937] Perda D: 0.2382 | Perda G: -0.0679
# [Época 020] [Lote 500/937] Perda D: -2.2537 | Perda G: -19.1075
# [Época 020] [Lote 600/937] Perda D: 0.5244 | Perda G: -7.6978
# [Época 020] [Lote 700/937] Perda D: 0.5093 | Perda G: 7.8778
# [Época 020] [Lote 800/937] Perda D: 0.4125 | Perda G: -0.9766
# [Época 020] [Lote 900/937] Perda D: -1.6548 | Perda G: -11.7061
# [Época 020] [Lote 936/937] Perda D: -0.9730 | Perda G: 7.7997
# [Época 021] [Lote 000/937] Perda D: 0.1600 | Perda G: 8.4757
# [Época 021] [Lote 100/937] Perda D: -1.0784 | Perda G: -7.7445
# [Época 021] [Lote 200/937] Perda D: -0.0146 | Perda G: 0.3692
# [Época 021] [Lote 300/937] Perda D: -0.6943 | Perda G: 0.8388
# [Época 021] [Lote 400/937] Perda D: -0.2643 | Perda G: -7.3254
# [Época 021] [Lote 500/937] Perda D: 0.9911 | Perda G: -15.6271
# [Época 021] [Lote 600/937] Perda D: 0.3751 | Perda G: -1.0570
# [Época 021] [Lote 700/937] Perda D: -0.9167 | Perda G: -17.7030
# [Época 021] [Lote 800/937] Perda D: 0.2636 | Perda G: -7.3942
# [Época 021] [Lote 900/937] Perda D: -0.9422 | Perda G: 1.3270
# [Época 021] [Lote 936/937] Perda D: 0.2931 | Perda G: 3.1327
# [Época 022] [Lote 000/937] Perda D: 0.1602 | Perda G: 1.2829
# [Época 022] [Lote 100/937] Perda D: 0.0427 | Perda G: 1.9611
# [Época 022] [Lote 200/937] Perda D: -0.4988 | Perda G: 4.1485
# [Época 022] [Lote 300/937] Perda D: -0.3554 | Perda G: 2.9602
# [Época 022] [Lote 400/937] Perda D: -0.0859 | Perda G: -4.9424
# [Época 022] [Lote 500/937] Perda D: 0.8677 | Perda G: -12.0766
# [Época 022] [Lote 600/937] Perda D: 0.8444 | Perda G: 6.6894
# [Época 022] [Lote 700/937] Perda D: -0.3241 | Perda G: -2.3675
# [Época 022] [Lote 800/937] Perda D: -0.0991 | Perda G: -4.5536
# [Época 022] [Lote 900/937] Perda D: -0.1387 | Perda G: -2.7372
# [Época 022] [Lote 936/937] Perda D: -0.1694 | Perda G: 2.3706
# [Época 023] [Lote 000/937] Perda D: 0.3235 | Perda G: 2.4643
# [Época 023] [Lote 100/937] Perda D: -0.2595 | Perda G: -1.8207
# [Época 023] [Lote 200/937] Perda D: -1.5911 | Perda G: 4.1377
# [Época 023] [Lote 300/937] Perda D: -0.1462 | Perda G: 3.2009
# [Época 023] [Lote 400/937] Perda D: -0.2245 | Perda G: 0.3468
# [Época 023] [Lote 500/937] Perda D: -1.5558 | Perda G: 14.9018
# [Época 023] [Lote 600/937] Perda D: -0.3352 | Perda G: -14.9598
# [Época 023] [Lote 700/937] Perda D: -0.6326 | Perda G: 8.4910
# [Época 023] [Lote 800/937] Perda D: -1.8626 | Perda G: 10.3719
# [Época 023] [Lote 900/937] Perda D: -0.7963 | Perda G: -4.4969
# [Época 023] [Lote 936/937] Perda D: -0.9393 | Perda G: 5.1505
# [Época 024] [Lote 000/937] Perda D: -0.0016 | Perda G: 2.9883
# [Época 024] [Lote 100/937] Perda D: -0.4492 | Perda G: 0.8722
# [Época 024] [Lote 200/937] Perda D: -0.4314 | Perda G: -7.5718
# [Época 024] [Lote 300/937] Perda D: -0.1078 | Perda G: -7.1626
# [Época 024] [Lote 400/937] Perda D: -0.7869 | Perda G: 3.7555
# [Época 024] [Lote 500/937] Perda D: -0.3654 | Perda G: -3.7649
# [Época 024] [Lote 600/937] Perda D: -0.3154 | Perda G: -4.7055
# [Época 024] [Lote 700/937] Perda D: -0.0248 | Perda G: 7.0278
# [Época 024] [Lote 800/937] Perda D: -0.1873 | Perda G: 2.3029
# [Época 024] [Lote 900/937] Perda D: -0.0181 | Perda G: -2.9904
# [Época 024] [Lote 936/937] Perda D: -0.2677 | Perda G: -6.1933
# [Época 025] [Lote 000/937] Perda D: 0.3766 | Perda G: -5.2804
# [Época 025] [Lote 100/937] Perda D: -1.7260 | Perda G: 13.8331
# [Época 025] [Lote 200/937] Perda D: 0.0431 | Perda G: -2.2937
# [Época 025] [Lote 300/937] Perda D: -0.0621 | Perda G: 8.3788
# [Época 025] [Lote 400/937] Perda D: -0.1385 | Perda G: -1.6277
# [Época 025] [Lote 500/937] Perda D: 0.0667 | Perda G: 8.4524
# [Época 025] [Lote 600/937] Perda D: -0.7818 | Perda G: 7.9697
# [Época 025] [Lote 700/937] Perda D: 0.5857 | Perda G: 2.0681
# [Época 025] [Lote 800/937] Perda D: -0.1075 | Perda G: -0.0307
# [Época 025] [Lote 900/937] Perda D: 0.0062 | Perda G: -0.8345
# [Época 025] [Lote 936/937] Perda D: -0.3989 | Perda G: -0.7019
# [Época 026] [Lote 000/937] Perda D: 0.1382 | Perda G: 1.8415
# [Época 026] [Lote 100/937] Perda D: -0.7651 | Perda G: 10.6435
# [Época 026] [Lote 200/937] Perda D: 0.8034 | Perda G: 13.2754
# [Época 026] [Lote 300/937] Perda D: 0.1332 | Perda G: -18.1093
# [Época 026] [Lote 400/937] Perda D: -0.0123 | Perda G: -8.2677
# [Época 026] [Lote 500/937] Perda D: -1.2113 | Perda G: 12.1803
# [Época 026] [Lote 600/937] Perda D: 0.9196 | Perda G: 4.8864
# [Época 026] [Lote 700/937] Perda D: 0.6156 | Perda G: 3.9055
# [Época 026] [Lote 800/937] Perda D: 0.1521 | Perda G: 6.3946
# [Época 026] [Lote 900/937] Perda D: -1.2001 | Perda G: -11.2008
# [Época 026] [Lote 936/937] Perda D: 0.1194 | Perda G: 0.5471
# [Época 027] [Lote 000/937] Perda D: -0.9971 | Perda G: 2.8945
# [Época 027] [Lote 100/937] Perda D: -0.9080 | Perda G: 1.1488
# [Época 027] [Lote 200/937] Perda D: -0.2148 | Perda G: 8.3927
# [Época 027] [Lote 300/937] Perda D: -0.3129 | Perda G: 1.8271
# [Época 027] [Lote 400/937] Perda D: -1.7932 | Perda G: 5.8917
# [Época 027] [Lote 500/937] Perda D: 0.0587 | Perda G: 0.6758
# [Época 027] [Lote 600/937] Perda D: -0.1277 | Perda G: -9.9711
# [Época 027] [Lote 700/937] Perda D: -0.9280 | Perda G: -10.5318
# [Época 027] [Lote 800/937] Perda D: -0.2688 | Perda G: -5.8407
# [Época 027] [Lote 900/937] Perda D: -0.1878 | Perda G: -6.3311
# [Época 027] [Lote 936/937] Perda D: -0.4497 | Perda G: 0.1545
# [Época 028] [Lote 000/937] Perda D: -0.3233 | Perda G: 0.3556
# [Época 028] [Lote 100/937] Perda D: -0.2925 | Perda G: -2.5461
# [Época 028] [Lote 200/937] Perda D: -0.0254 | Perda G: -7.8291
# [Época 028] [Lote 300/937] Perda D: -0.5426 | Perda G: 6.9686
# [Época 028] [Lote 400/937] Perda D: -3.3268 | Perda G: 15.2549
# [Época 028] [Lote 500/937] Perda D: -0.1535 | Perda G: -4.0802
# [Época 028] [Lote 600/937] Perda D: 0.6512 | Perda G: 3.9201
# [Época 028] [Lote 700/937] Perda D: -0.3769 | Perda G: 2.0145
# [Época 028] [Lote 800/937] Perda D: -0.3372 | Perda G: 8.5248
# [Época 028] [Lote 900/937] Perda D: 0.0927 | Perda G: -4.6373
# [Época 028] [Lote 936/937] Perda D: 0.0087 | Perda G: -7.0623
# [Época 029] [Lote 000/937] Perda D: -0.3852 | Perda G: -6.2402
# [Época 029] [Lote 100/937] Perda D: 0.9364 | Perda G: 6.6236
# [Época 029] [Lote 200/937] Perda D: -0.0118 | Perda G: 4.1411
# [Época 029] [Lote 300/937] Perda D: -0.7510 | Perda G: 5.7253
# [Época 029] [Lote 400/937] Perda D: 0.1521 | Perda G: 0.8610
# [Época 029] [Lote 500/937] Perda D: -0.1965 | Perda G: -0.7861
# [Época 029] [Lote 600/937] Perda D: 0.4231 | Perda G: 2.7145
# [Época 029] [Lote 700/937] Perda D: -0.2765 | Perda G: -0.1321
# [Época 029] [Lote 800/937] Perda D: 0.0260 | Perda G: -11.1864
# [Época 029] [Lote 900/937] Perda D: -0.1912 | Perda G: 7.7111
# [Época 029] [Lote 936/937] Perda D: -0.1378 | Perda G: 9.2379
# [Época 030] [Lote 000/937] Perda D: 0.3566 | Perda G: 7.4326
# [Época 030] [Lote 100/937] Perda D: -0.1561 | Perda G: 1.4303
# [Época 030] [Lote 200/937] Perda D: -0.1353 | Perda G: -7.9267
# [Época 030] [Lote 300/937] Perda D: 0.7726 | Perda G: -11.1104
# [Época 030] [Lote 400/937] Perda D: -0.5204 | Perda G: 3.8834
# [Época 030] [Lote 500/937] Perda D: -0.8071 | Perda G: -9.0721
# [Época 030] [Lote 600/937] Perda D: 0.2199 | Perda G: -0.4900
# [Época 030] [Lote 700/937] Perda D: -0.1532 | Perda G: -10.5594
# [Época 030] [Lote 800/937] Perda D: -0.3545 | Perda G: 3.2894
# [Época 030] [Lote 900/937] Perda D: -0.1438 | Perda G: -1.2724
# [Época 030] [Lote 936/937] Perda D: 1.5984 | Perda G: -10.9737
# [Época 031] [Lote 000/937] Perda D: 1.3666 | Perda G: -9.8929
# [Época 031] [Lote 100/937] Perda D: 0.0188 | Perda G: 0.4189
# [Época 031] [Lote 200/937] Perda D: -0.0100 | Perda G: -4.4405
# [Época 031] [Lote 300/937] Perda D: 0.3692 | Perda G: 9.0364
# [Época 031] [Lote 400/937] Perda D: -0.6417 | Perda G: -1.6465
# [Época 031] [Lote 500/937] Perda D: -0.7210 | Perda G: 7.1426
# [Época 031] [Lote 600/937] Perda D: -0.1066 | Perda G: -9.8139
# [Época 031] [Lote 700/937] Perda D: 0.3858 | Perda G: 6.8072
# [Época 031] [Lote 800/937] Perda D: -0.0747 | Perda G: 5.8951
# [Época 031] [Lote 900/937] Perda D: -0.3709 | Perda G: -2.2119
# [Época 031] [Lote 936/937] Perda D: 0.5091 | Perda G: -3.5625
# [Época 032] [Lote 000/937] Perda D: -0.9615 | Perda G: -7.1194
# [Época 032] [Lote 100/937] Perda D: -0.4493 | Perda G: -4.0217
# [Época 032] [Lote 200/937] Perda D: -0.4408 | Perda G: 2.2710
# [Época 032] [Lote 300/937] Perda D: -0.2554 | Perda G: 2.7508
# [Época 032] [Lote 400/937] Perda D: -0.7366 | Perda G: 8.5103
# [Época 032] [Lote 500/937] Perda D: -0.3693 | Perda G: -1.5200
# [Época 032] [Lote 600/937] Perda D: -0.2193 | Perda G: -3.8639
# [Época 032] [Lote 700/937] Perda D: 0.5292 | Perda G: -10.1239
# [Época 032] [Lote 800/937] Perda D: -0.8872 | Perda G: -0.6123
# [Época 032] [Lote 900/937] Perda D: -0.5391 | Perda G: 6.8546
# [Época 032] [Lote 936/937] Perda D: -0.1447 | Perda G: 6.0866
# [Época 033] [Lote 000/937] Perda D: -0.6113 | Perda G: 4.2382
# [Época 033] [Lote 100/937] Perda D: -0.6419 | Perda G: -6.9934
# [Época 033] [Lote 200/937] Perda D: -0.2513 | Perda G: -11.7319
# [Época 033] [Lote 300/937] Perda D: -0.0156 | Perda G: -2.5553
# [Época 033] [Lote 400/937] Perda D: -1.5196 | Perda G: -20.7399
# [Época 033] [Lote 500/937] Perda D: 0.1926 | Perda G: 4.5517
# [Época 033] [Lote 600/937] Perda D: -0.4422 | Perda G: 5.2837
# [Época 033] [Lote 700/937] Perda D: -0.5761 | Perda G: 9.0250
# [Época 033] [Lote 800/937] Perda D: 0.0239 | Perda G: -2.1899
# [Época 033] [Lote 900/937] Perda D: 0.1027 | Perda G: -3.1233
# [Época 033] [Lote 936/937] Perda D: 0.2467 | Perda G: -2.9780
# [Época 034] [Lote 000/937] Perda D: -0.2313 | Perda G: -1.3401
# [Época 034] [Lote 100/937] Perda D: 0.1622 | Perda G: -5.3016
# [Época 034] [Lote 200/937] Perda D: -0.2716 | Perda G: -2.6648
# [Época 034] [Lote 300/937] Perda D: -0.1419 | Perda G: -1.2918
# [Época 034] [Lote 400/937] Perda D: -0.3681 | Perda G: 6.1251
# [Época 034] [Lote 500/937] Perda D: -0.1247 | Perda G: 1.8443
# [Época 034] [Lote 600/937] Perda D: 0.0902 | Perda G: 3.9750
# [Época 034] [Lote 700/937] Perda D: -0.1722 | Perda G: -2.2536
# [Época 034] [Lote 800/937] Perda D: -0.2050 | Perda G: -5.1813
# [Época 034] [Lote 900/937] Perda D: -0.4946 | Perda G: -6.1714
# [Época 034] [Lote 936/937] Perda D: -0.4528 | Perda G: -0.7514
# [Época 035] [Lote 000/937] Perda D: -0.5019 | Perda G: -1.2414
# [Época 035] [Lote 100/937] Perda D: 0.0467 | Perda G: 1.1159
# [Época 035] [Lote 200/937] Perda D: -0.8561 | Perda G: -3.6277
# [Época 035] [Lote 300/937] Perda D: 0.6607 | Perda G: -6.5822
# [Época 035] [Lote 400/937] Perda D: -0.1433 | Perda G: -1.6986
# [Época 035] [Lote 500/937] Perda D: -0.5642 | Perda G: 6.0900
# [Época 035] [Lote 600/937] Perda D: -0.3141 | Perda G: -5.7710
# [Época 035] [Lote 700/937] Perda D: 0.0334 | Perda G: 0.4276
# [Época 035] [Lote 800/937] Perda D: -1.3569 | Perda G: -15.3155
# [Época 035] [Lote 900/937] Perda D: 0.4576 | Perda G: 5.8720
# [Época 035] [Lote 936/937] Perda D: -0.6877 | Perda G: -7.5182
# [Época 036] [Lote 000/937] Perda D: -0.7004 | Perda G: -9.1383
# [Época 036] [Lote 100/937] Perda D: -0.2150 | Perda G: -15.6798
# [Época 036] [Lote 200/937] Perda D: 1.8633 | Perda G: -15.6190
# [Época 036] [Lote 300/937] Perda D: 0.1374 | Perda G: 2.1258
# [Época 036] [Lote 400/937] Perda D: 0.3071 | Perda G: -4.3359
# [Época 036] [Lote 500/937] Perda D: 0.0702 | Perda G: 1.5202
# [Época 036] [Lote 600/937] Perda D: -0.4670 | Perda G: -4.6471
# [Época 036] [Lote 700/937] Perda D: 0.4676 | Perda G: 6.9998
# [Época 036] [Lote 800/937] Perda D: -0.3110 | Perda G: -1.0470
# [Época 036] [Lote 900/937] Perda D: 0.8827 | Perda G: -8.9631
# [Época 036] [Lote 936/937] Perda D: 0.6545 | Perda G: -11.8585
# [Época 037] [Lote 000/937] Perda D: 0.2325 | Perda G: -9.6350
# [Época 037] [Lote 100/937] Perda D: -0.1635 | Perda G: 0.1639
# [Época 037] [Lote 200/937] Perda D: -0.0623 | Perda G: 8.2707
# [Época 037] [Lote 300/937] Perda D: -1.4988 | Perda G: 15.6003
# [Época 037] [Lote 400/937] Perda D: -0.7625 | Perda G: -13.4630
# [Época 037] [Lote 500/937] Perda D: -0.7999 | Perda G: 2.7884
# [Época 037] [Lote 600/937] Perda D: -1.0519 | Perda G: 4.9741
# [Época 037] [Lote 700/937] Perda D: -0.2380 | Perda G: -10.4318
# [Época 037] [Lote 800/937] Perda D: -0.2663 | Perda G: -5.2656
# [Época 037] [Lote 900/937] Perda D: -0.0340 | Perda G: -0.5085
# [Época 037] [Lote 936/937] Perda D: -0.2436 | Perda G: -3.9773
# [Época 038] [Lote 000/937] Perda D: -0.2440 | Perda G: -7.0581
# [Época 038] [Lote 100/937] Perda D: -0.1857 | Perda G: 1.1190
# [Época 038] [Lote 200/937] Perda D: -0.0054 | Perda G: 3.5261
# [Época 038] [Lote 300/937] Perda D: 0.1298 | Perda G: -4.3490
# [Época 038] [Lote 400/937] Perda D: -0.6878 | Perda G: -10.5519
# [Época 038] [Lote 500/937] Perda D: -0.4294 | Perda G: -4.4885
# [Época 038] [Lote 600/937] Perda D: 0.4395 | Perda G: -8.4899
# [Época 038] [Lote 700/937] Perda D: -0.5888 | Perda G: 3.3554
# [Época 038] [Lote 800/937] Perda D: -0.0913 | Perda G: -1.0880
# [Época 038] [Lote 900/937] Perda D: 0.4634 | Perda G: -5.8237
# [Época 038] [Lote 936/937] Perda D: 0.1566 | Perda G: -5.4401
# [Época 039] [Lote 000/937] Perda D: -0.3129 | Perda G: -6.0328
# [Época 039] [Lote 100/937] Perda D: 0.4842 | Perda G: 9.9796
# [Época 039] [Lote 200/937] Perda D: -0.4427 | Perda G: -7.6352
# [Época 039] [Lote 300/937] Perda D: 0.2165 | Perda G: -5.0224
# [Época 039] [Lote 400/937] Perda D: -0.1902 | Perda G: -15.1783
# [Época 039] [Lote 500/937] Perda D: -0.5091 | Perda G: 3.4032
# [Época 039] [Lote 600/937] Perda D: 0.0033 | Perda G: -5.5235
# [Época 039] [Lote 700/937] Perda D: -0.3007 | Perda G: -0.4927
# [Época 039] [Lote 800/937] Perda D: 0.2406 | Perda G: -3.9371
# [Época 039] [Lote 900/937] Perda D: -0.0175 | Perda G: -1.8467
# [Época 039] [Lote 936/937] Perda D: -0.9021 | Perda G: -10.9517
# [Época 040] [Lote 000/937] Perda D: 0.3431 | Perda G: -8.5132
# [Época 040] [Lote 100/937] Perda D: 0.2636 | Perda G: 4.5617
# [Época 040] [Lote 200/937] Perda D: -0.0294 | Perda G: -8.1744
# [Época 040] [Lote 300/937] Perda D: 0.6023 | Perda G: -7.7792
# [Época 040] [Lote 400/937] Perda D: -0.4536 | Perda G: -11.1069
# [Época 040] [Lote 500/937] Perda D: 0.1729 | Perda G: -3.2253
# [Época 040] [Lote 600/937] Perda D: 0.3593 | Perda G: -9.7541
# [Época 040] [Lote 700/937] Perda D: 0.1727 | Perda G: -12.4285
# [Época 040] [Lote 800/937] Perda D: -0.0380 | Perda G: -0.9672
# [Época 040] [Lote 900/937] Perda D: -0.6197 | Perda G: -1.3358
# [Época 040] [Lote 936/937] Perda D: -0.3550 | Perda G: -6.1778
# [Época 041] [Lote 000/937] Perda D: -0.6904 | Perda G: -5.9474
# [Época 041] [Lote 100/937] Perda D: -0.1699 | Perda G: -15.8159
# [Época 041] [Lote 200/937] Perda D: -1.5246 | Perda G: -14.3414
# [Época 041] [Lote 300/937] Perda D: -0.3326 | Perda G: -8.4525
# [Época 041] [Lote 400/937] Perda D: -0.2761 | Perda G: -0.6473
# [Época 041] [Lote 500/937] Perda D: -0.2061 | Perda G: -0.2061
# [Época 041] [Lote 600/937] Perda D: -0.5946 | Perda G: 6.2482
# [Época 041] [Lote 700/937] Perda D: -0.1135 | Perda G: -6.8059
# [Época 041] [Lote 800/937] Perda D: 0.3217 | Perda G: -5.4532
# [Época 041] [Lote 900/937] Perda D: -0.8078 | Perda G: 4.3394
# [Época 041] [Lote 936/937] Perda D: -0.6685 | Perda G: -9.9633
# [Época 042] [Lote 000/937] Perda D: -0.9886 | Perda G: -9.8547
# [Época 042] [Lote 100/937] Perda D: -0.5202 | Perda G: -16.1735
# [Época 042] [Lote 200/937] Perda D: -0.4922 | Perda G: -3.9083
# [Época 042] [Lote 300/937] Perda D: -0.1502 | Perda G: 0.7020
# [Época 042] [Lote 400/937] Perda D: -0.1694 | Perda G: -1.3006
# [Época 042] [Lote 500/937] Perda D: 0.3202 | Perda G: -7.0217
# [Época 042] [Lote 600/937] Perda D: 0.4219 | Perda G: -8.4041
# [Época 042] [Lote 700/937] Perda D: -1.0493 | Perda G: -10.1610
# [Época 042] [Lote 800/937] Perda D: 0.2966 | Perda G: -1.8589
# [Época 042] [Lote 900/937] Perda D: -0.3781 | Perda G: -0.3261
# [Época 042] [Lote 936/937] Perda D: -0.4413 | Perda G: -2.3821
# [Época 043] [Lote 000/937] Perda D: -0.0524 | Perda G: -3.3941
# [Época 043] [Lote 100/937] Perda D: 0.3700 | Perda G: 0.9226
# [Época 043] [Lote 200/937] Perda D: -0.8451 | Perda G: -25.1711
# [Época 043] [Lote 300/937] Perda D: 0.8822 | Perda G: 13.7170
# [Época 043] [Lote 400/937] Perda D: -1.3929 | Perda G: -16.1042
# [Época 043] [Lote 500/937] Perda D: -0.3380 | Perda G: -1.7885
# [Época 043] [Lote 600/937] Perda D: -0.3333 | Perda G: 1.0383
# [Época 043] [Lote 700/937] Perda D: 0.2689 | Perda G: -0.8012
# [Época 043] [Lote 800/937] Perda D: 0.0590 | Perda G: -4.7577
# [Época 043] [Lote 900/937] Perda D: -1.8455 | Perda G: 4.2747
# [Época 043] [Lote 936/937] Perda D: -0.4311 | Perda G: -7.5253
# [Época 044] [Lote 000/937] Perda D: 0.4111 | Perda G: -7.1991
# [Época 044] [Lote 100/937] Perda D: 0.3894 | Perda G: 3.3165
# [Época 044] [Lote 200/937] Perda D: 0.3935 | Perda G: 3.0328
# [Época 044] [Lote 300/937] Perda D: -1.2568 | Perda G: 9.5662
# [Época 044] [Lote 400/937] Perda D: -1.3341 | Perda G: 6.7802
# [Época 044] [Lote 500/937] Perda D: 0.0149 | Perda G: 8.2405
# [Época 044] [Lote 600/937] Perda D: 0.0671 | Perda G: -11.1152
# [Época 044] [Lote 700/937] Perda D: -0.5040 | Perda G: -4.3655
# [Época 044] [Lote 800/937] Perda D: 0.3247 | Perda G: -3.0589
# [Época 044] [Lote 900/937] Perda D: 0.3842 | Perda G: -3.3000
# [Época 044] [Lote 936/937] Perda D: -0.1737 | Perda G: -8.8946
# [Época 045] [Lote 000/937] Perda D: -0.2458 | Perda G: -6.2187
# [Época 045] [Lote 100/937] Perda D: -0.1602 | Perda G: -9.2005
# [Época 045] [Lote 200/937] Perda D: 0.4204 | Perda G: -11.0285
# [Época 045] [Lote 300/937] Perda D: -0.0671 | Perda G: -8.4501
# [Época 045] [Lote 400/937] Perda D: -0.0532 | Perda G: -8.1917
# [Época 045] [Lote 500/937] Perda D: 0.1763 | Perda G: -6.4852
# [Época 045] [Lote 600/937] Perda D: 0.1516 | Perda G: -3.5254
# [Época 045] [Lote 700/937] Perda D: -0.0415 | Perda G: 3.2077
# [Época 045] [Lote 800/937] Perda D: -0.1090 | Perda G: 0.4689
# [Época 045] [Lote 900/937] Perda D: -1.0479 | Perda G: -11.0112
# [Época 045] [Lote 936/937] Perda D: 0.2982 | Perda G: -1.5599
# [Época 046] [Lote 000/937] Perda D: -0.2177 | Perda G: 3.4427
# [Época 046] [Lote 100/937] Perda D: -0.0206 | Perda G: 1.1996
# [Época 046] [Lote 200/937] Perda D: 0.6266 | Perda G: 3.3249
# [Época 046] [Lote 300/937] Perda D: -0.3213 | Perda G: -2.7508
# [Época 046] [Lote 400/937] Perda D: 0.4579 | Perda G: 2.0409
# [Época 046] [Lote 500/937] Perda D: 0.1144 | Perda G: 1.2731
# [Época 046] [Lote 600/937] Perda D: -0.1512 | Perda G: 8.2481
# [Época 046] [Lote 700/937] Perda D: -0.0640 | Perda G: -1.6083
# [Época 046] [Lote 800/937] Perda D: -0.0414 | Perda G: -4.9370
# [Época 046] [Lote 900/937] Perda D: -0.0895 | Perda G: -4.3143
# [Época 046] [Lote 936/937] Perda D: -0.4870 | Perda G: -3.1191
# [Época 047] [Lote 000/937] Perda D: -0.2746 | Perda G: -3.0431
# [Época 047] [Lote 100/937] Perda D: -0.0356 | Perda G: -2.8465
# [Época 047] [Lote 200/937] Perda D: 0.1307 | Perda G: -7.8823
# [Época 047] [Lote 300/937] Perda D: 0.1274 | Perda G: -2.1931
# [Época 047] [Lote 400/937] Perda D: -0.1976 | Perda G: -1.1970
# [Época 047] [Lote 500/937] Perda D: -0.2449 | Perda G: 6.5842
# [Época 047] [Lote 600/937] Perda D: -0.1373 | Perda G: 5.1588
# [Época 047] [Lote 700/937] Perda D: -0.6503 | Perda G: -8.1920
# [Época 047] [Lote 800/937] Perda D: 0.1377 | Perda G: 5.2191
# [Época 047] [Lote 900/937] Perda D: -0.4434 | Perda G: -0.3472
# [Época 047] [Lote 936/937] Perda D: -0.3818 | Perda G: -5.8853
# [Época 048] [Lote 000/937] Perda D: -0.0539 | Perda G: -5.8905
# [Época 048] [Lote 100/937] Perda D: 0.0820 | Perda G: -2.8024
# [Época 048] [Lote 200/937] Perda D: -0.0876 | Perda G: -7.9322
# [Época 048] [Lote 300/937] Perda D: 0.6129 | Perda G: -0.2742
# [Época 048] [Lote 400/937] Perda D: -0.2989 | Perda G: -1.3706
# [Época 048] [Lote 500/937] Perda D: -0.2681 | Perda G: -3.9952
# [Época 048] [Lote 600/937] Perda D: -0.2913 | Perda G: -14.7110
# [Época 048] [Lote 700/937] Perda D: -0.0610 | Perda G: -4.8304
# [Época 048] [Lote 800/937] Perda D: -0.9700 | Perda G: -11.3974
# [Época 048] [Lote 900/937] Perda D: -0.4263 | Perda G: 1.4919
# [Época 048] [Lote 936/937] Perda D: -1.3674 | Perda G: 10.3896
# [Época 049] [Lote 000/937] Perda D: -1.1876 | Perda G: 11.1974
# [Época 049] [Lote 100/937] Perda D: -0.2457 | Perda G: -0.5204
# [Época 049] [Lote 200/937] Perda D: -0.2124 | Perda G: -4.7019
# [Época 049] [Lote 300/937] Perda D: 0.6104 | Perda G: 6.9741
# [Época 049] [Lote 400/937] Perda D: -0.2014 | Perda G: 1.1194
# [Época 049] [Lote 500/937] Perda D: -0.3655 | Perda G: -4.1710
# [Época 049] [Lote 600/937] Perda D: -0.0649 | Perda G: -4.4150
# [Época 049] [Lote 700/937] Perda D: -0.3114 | Perda G: -16.7619
# [Época 049] [Lote 800/937] Perda D: -0.0993 | Perda G: 1.1462
# [Época 049] [Lote 900/937] Perda D: -0.3865 | Perda G: 1.3745
# [Época 049] [Lote 936/937] Perda D: -0.3590 | Perda G: -1.1755
# [Época 050] [Lote 000/937] Perda D: 0.3467 | Perda G: -4.0944
# [Época 050] [Lote 100/937] Perda D: 0.2265 | Perda G: 4.7611
# [Época 050] [Lote 200/937] Perda D: -0.4617 | Perda G: 7.6832
# [Época 050] [Lote 300/937] Perda D: -1.0714 | Perda G: 6.5785
# [Época 050] [Lote 400/937] Perda D: 0.0321 | Perda G: -0.5493
# [Época 050] [Lote 500/937] Perda D: 0.0188 | Perda G: -2.7549
# [Época 050] [Lote 600/937] Perda D: 0.2790 | Perda G: 1.1061
# [Época 050] [Lote 700/937] Perda D: -0.9544 | Perda G: 4.9479
# [Época 050] [Lote 800/937] Perda D: 0.5169 | Perda G: -21.1662
# [Época 050] [Lote 900/937] Perda D: -0.3381 | Perda G: 6.3840
# [Época 050] [Lote 936/937] Perda D: -0.4138 | Perda G: 7.8405
# Fim!

# %% [markdown]
# # Resultados

# %%
# Salva gerador treinado
torch.save(modelo_gerador.state_dict(), "gerador_wgan_condicional.pth")

# %%
# Gera dados falsos com vetores latentes aleatórios e rótulos aleatórios
def gerar_aleatorio(modelo_gerador, device, z_dim=100, n_images=20, num_classes=10):
    modelo_gerador.eval()  # Modo de avaliação (desativa dropout, batchnorm, etc.)

    # Gera vetores de ruído aleatórios
    z = torch.randn((n_images, z_dim), device=device)

    # Gera rótulos inteiros aleatórios e converte para one-hot
    rotulos_aleatorios = torch.randint(0, num_classes, (n_images,), device=device)
    rotulos_aleatorios_one_hot = F.one_hot(rotulos_aleatorios, num_classes=num_classes).float()

    # Desativa o cálculo de gradientes
    with torch.no_grad():
        # Gera dados falsos passando (z, rotulos_one_hot) para o gerador condicional
        dados_falsos = modelo_gerador(z, rotulos_aleatorios_one_hot)
        dados_falsos = dados_falsos.detach().cpu().numpy()

    return dados_falsos, rotulos_aleatorios

# %%
# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, rotulos, n_cols=7):
    classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, (img, c) in enumerate(zip(imagens, rotulos)):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.title(classes[c.item()])
        plt.axis("off")
    plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=1.0)
    plt.show()

# %%
imagens, rotulos = gerar_aleatorio(
    modelo_gerador,   # gerador condicional
    device,           # dispositivo: 'cpu' ou 'cuda'
    z_dim=z_dim,      # dimensão do vetor latente
    n_images=28,      # número de imagens que desejamos gerar
    num_classes=10    # número de classes do conjunto de dados
)

# Chama a função para plotar as imagens em grade
plot_multiple_images(imagens, rotulos, n_cols=7)

# %%
# Gera n imagens para uma única classe (mantendo o rótulo fixo e variando o ruído)
def gerar_imagens_por_classe(modelo_gerador, device, classe_especifica, n_images=20, z_dim=100, num_classes=10):
    modelo_gerador.eval()  # Modo de avaliação

    # Vetores de ruído aleatórios
    z = torch.randn((n_images, z_dim), device=device)

    # Rótulo fixo
    rotulos = torch.full((n_images,), classe_especifica, device=device, dtype=torch.long)

    # Converte para one-hot
    rotulos_one_hot = F.one_hot(rotulos, num_classes=num_classes).float()

    # Gera as imagens com o gerador condicional
    with torch.no_grad():
        imagens_geradas = modelo_gerador(z, rotulos_one_hot)
        imagens_geradas = imagens_geradas.detach().cpu().numpy()

    return imagens_geradas, rotulos

# %%
# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, n_cols=7):
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, img in enumerate(imagens):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=1.0)
    plt.show()

# %%
imagens, rotulos = gerar_imagens_por_classe(
    modelo_gerador,
    device,
    classe_especifica=9,
    n_images=28,
    z_dim=z_dim,
    num_classes=10
)

plot_multiple_images(imagens, n_cols=7)

# %% [markdown]
# # Evolução das saídas do gerador para um vetor latente fixo durante o treinamento

# %%
# Lista com imagens 8x8
imagens = evolução_dado_falso

# Cria subplots (1 linha, -1 colunas)
fig, axes = plt.subplots(1, len(evolução_dado_falso), figsize=(15, 2))

# Itera por cada subplot e mostra a imagem
for ax, img in zip(axes, imagens):
    ax.imshow(img, cmap='gray')    # 1 = preto, 0 = branco
    ax.axis('off')                 # Remove ticks dos eixos

# ajusta o espaçamento entre subplots
plt.subplots_adjust(wspace=0.1)  # aumente para um maior espaçamento entre as imagens

plt.show()

# %%
def interp_z_fixo(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_1=0,
    classe_2=9,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera um vetor de ruído fixo (z) com dimensão z_dim
    z_fix = torch.randn((1, z_dim), device=device)

    # Cria os vetores one-hot correspondentes às classes iniciais e finais
    c1 = F.one_hot(torch.tensor([classe_1], device=device), num_classes).float()
    c2 = F.one_hot(torch.tensor([classe_2], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Expande os rótulos iniciais e finais para steps linhas
    c1_b = c1.expand(steps, -1)
    c2_b = c2.expand(steps, -1)

    # Interpola linearmente entre c1 e c2 ao longo de steps
    c_seq = torch.lerp(c1_b, c2_b, alphas.view(-1, 1))      # lerp(a,b,alpha) = (1 - alpha) * a + alpha * b

    # Repete o mesmo vetor z_fix para todos os steps
    z_batch = z_fix.expand(steps, -1)

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_batch, c_seq)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return


interp_z_fixo(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_1=2,         # classe 1
    classe_2=7,         # classe 2
    steps=15,           # número de passos da interpolação
    seed=5              # semente para reprodutibilidade
)

# %%
def interp_c_fixo(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_fixa=0,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera dois vetores de ruído aleatórios (z1 e z2), que serão os pontos extremos da interpolação
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    # Cria o vetor one-hot correspondente ao rótulo fixo
    c_fix = F.one_hot(torch.tensor([classe_fixa], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Expande os vetores z1 e z2 para steps linhas
    z1_b = z1.expand(steps, -1)
    z2_b = z2.expand(steps, -1)

    # Interpola linearmente entre z1 e z2 ao longo de steps: (1 - alpha) * z1_b + alpha * z2_b
    z_seq = torch.lerp(z1_b, z2_b, alphas.view(-1, 1))

    # Repete o mesmo rótulo fixo para todos os steps
    c_batch = c_fix.expand(steps, -1)

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_seq, c_batch)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return

interp_c_fixo(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_fixa=1,      # rótulo fixo escolhido
    steps=15,           # número de passos da interpolação
    seed=0              # semente para reprodutibilidade
)

# %%
def interp_z_e_c(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_1=0,
    classe_2=9,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera dois vetores de ruído aleatórios (z1 e z2), que serão os pontos extremos da interpolação
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    # Cria os vetores one-hot correspondentes às classes inicial e final
    c1 = F.one_hot(torch.tensor([classe_1], device=device), num_classes).float()
    c2 = F.one_hot(torch.tensor([classe_2], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Interpola linearmente entre z1 e z2 ao longo de steps: (1 - alpha) * z1_b + alpha * z2_b
    z1_b = z1.expand(steps, -1)
    z2_b = z2.expand(steps, -1)
    z_seq = torch.lerp(z1_b, z2_b, alphas.view(-1, 1))

    # Interpola linearmente entre c1 e c2 ao longo de steps (rótulos suaves): (1 - alpha) * c1_b + alpha * c2_b
    c1_b = c1.expand(steps, -1)
    c2_b = c2.expand(steps, -1)
    c_seq = torch.lerp(c1_b, c2_b, alphas.view(-1, 1))

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_seq, c_seq)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return

interp_z_e_c(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_1=2,         # classe inicial
    classe_2=7,         # classe final
    steps=15,           # número de passos da interpolação
    seed=1              # semente para reprodutibilidade
)

# %%
def variar_classe_fixa_z(gerador, device, z_dim=100, num_classes=10):
    # Gera um único vetor de ruído aleatório e o repete para todas as classes
    # Assim, apenas o rótulo varia enquanto o ruído (z) permanece fixo
    z = torch.randn((1, z_dim), device=device).repeat(num_classes, 1)

    # Cria um vetor com todas as classes (0 a num_classes-1)
    classes = torch.arange(0, num_classes, device=device)

    # Converte cada classe para representação one-hot
    rotulos_one_hot = F.one_hot(classes, num_classes=num_classes).float()

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imagens = gerador(z, rotulos_one_hot).cpu().numpy()

    # Lista de nomes correspondentes às classes do FashionMNIST
    nomes_classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
                     "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

    # Define o layout da grade para visualização
    n_cols = 5
    n_rows = (num_classes - 1) // n_cols + 1
    plt.figure(figsize=(n_cols * 2, n_rows * 2))

    # Plota cada imagem correspondente ao rótulo fixo de z
    for i, (img, nome) in enumerate(zip(imagens, nomes_classes)):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.title(nome, fontsize=8)
        plt.axis("off")

    # Ajusta espaçamentos da figura
    plt.tight_layout()
    plt.show()


variar_classe_fixa_z(modelo_gerador, device, z_dim=z_dim)

# %% [markdown]
# # Tarefa:
#
# 1. Implementar uma WCGAN condicional e treinar o modelo com o conjunto de dados Fashion MNIST.
#
# 2. Interpolar entre vetores de ruído e mostrar as imagens intermediárias considerando:
#
#     a. z fixo e interpolacão linear entre classes [c1, c2].
#
#     b. classe c fixa e interpolaćão linear entre [z1, z2].
#
#     c. interpolaćão linear entre [z1, z2] e [c1, c2].
#
# 3. Fixe o vetor de ruído e altere apenas o rótulo para observar como a imagem muda.
#
# **Entregáveis**:
# 1. Notebook `.ipynb`.
# 2. Relatório `.pdf`:
#
#     - Reporte e comente os resultados no relatório.
#
#     - Incluir imagens geradas.
