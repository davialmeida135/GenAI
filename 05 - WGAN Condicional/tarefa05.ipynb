# %% [markdown]
# Código adaptado de:
#
# [1] David Foster, Generative Deep Learning: Teaching Machines to Paint, Write, Compose, and Play, Second Edition, O'Reilly, 2023.
#
# [2] Sayak Paul, Conditional GAN tutorial, disponível no site do Keras [(link)](https://keras.io/examples/generative/conditional_gan/).
#
# [3] Aurélien Géron, Hands-On Machine Learning with Scikit-Learn: Concepts, Tools and Techniques to Build Intelligent Systems, Keras & tensorFlow, Third Edition, O'Reilly, 2023.

# %% [markdown]
# # Importações

# %%
import torch                                # Importa a biblioteca principal do PyTorch, usada para computação com tensores
from torch import nn                        # Importa o módulo 'nn' do PyTorch, utilizado para criar e treinar redes neurais
from torch.utils.data import DataLoader     # Importa o DataLoader do PyTorch, que facilita o carregamento de dados em mini-lotes (batches).
import torch.nn.functional as F             # Importa funções comuns de ativação e perda do PyTorch, usadas fora do módulo nn.Module (ex.: ReLU, cross_entropy, etc.)
from torchvision import datasets            # Importa o módulo de conjuntos de dados do torchvision, que fornece acesso a conjuntos de dados populares como MNIST, CIFAR, etc. para visão computacional
from torchvision import transforms          # Importa o módulo de transforms do torchvision, usado para pré-processar imagens (conversão em tensor, normalização, etc.).
from torchinfo import summary               # Importa a função summary da biblioteca torchinfo, usada para exibir a arquitetura do modelo
import numpy as np                          # Importa a biblioteca NumPy, usada para operações numéricas eficientes com arrays e matrizes.
import matplotlib.pyplot as plt             # Importa o módulo de visualização matplotlib para gerar gráficos.
from IPython.display import Image           # Importa a classe Image do IPython, usada para exibir imagens diretamente dentro de notebooks.
import gdown                                # Importa utilitário para baixar arquivos do Google Drive via link público
import os                                   # Importa o módulo padrão do Python para interagir com o sistema operacional (ex.: criar pastas, manipular caminhos de arquivos).
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE" # Ajusta a variável de ambiente para evitar erros ao carregar múltiplas bibliotecas MKL

# %%
# Para figuras geradas pelo matplotlib serem exibidas diretamente no notebook
# %matplotlib inline

# %% [markdown]
# # Baixar e carregar os dados

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x * 2.0 - 1.0),
])

# Baixa os dados de treinamento a partir de conjuntos de dados públicos
training_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=True,              # Indica que este é o conjunto de dados de treinamento
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# Baixa os dados de teste a partir de conjuntos de dados públicos
test_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=False,             # Indica que este é o conjunto de dados de teste
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# %%
# Lista com os nomes das classes do conjunto de dados Fashion MNIST, na mesma ordem dos índices
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Dicionário para armazenar um exemplo por classe
examples = {}

# Itera sobre o dataset até obter um exemplo de cada classe
for img, label in training_data:
    if label not in examples:
        examples[label] = img.squeeze()  # remove o canal extra (1, 28, 28) -> (28, 28)
    if len(examples) == 10:
        break

# Plota os exemplos
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(examples[i], cmap="gray")
    plt.title(classes[i])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
batch_size = 64                                                      # Define o tamanho do lote, ou seja, quantas amostras serão processadas por vez
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True, drop_last=True)  # Cria o DataLoader para o conjunto de treinamento
test_dataloader = DataLoader(test_data, batch_size=batch_size)       # Cria o DataLoader para o conjunto de teste

# Itera sobre o DataLoader de teste para visualizar as formas dos dados
for X, y in test_dataloader:
    # Exibe a forma e o tipo do tensor de imagens
    # N = tamanho do lote, C = canais (1 para imagens em tons de cinza), H = altura, W = largura
    print(f"Forma de X [N, C, H, W]: {X.shape}, Tipo de dados em X: {X.dtype}")

    # Exibe a forma e o tipo dos rótulos (labels)
    print(f"Forma de y [N, ] : {y.shape}, Tipo de dados em y: {y.dtype}")

    break  # Encerra o loop após a primeira iteração, apenas para inspeção dos dados
# Out:
# Forma de X [N, C, H, W]: torch.Size([64, 1, 28, 28]), Tipo de dados em X: torch.float32
# Forma de y [N, ] : torch.Size([64]), Tipo de dados em y: torch.int64

# %% [markdown]
# # Redes Neurais

# %% [markdown]
# ## Gerador

# %%
class Gerador(nn.Module):
    def __init__(self, z_dim=100, num_classes=10):
        super().__init__()

        # Definimos a rede sequencial do gerador
        self.rede_neural = nn.Sequential(

            # Camada totalmente conectada                                                       # Entrada: (lote, z_dim + num_classes)  (vetor de ruído z concatenado com rótulo com codificação one-hot)
            nn.Linear(z_dim + num_classes, 7 * 7 * 128),

            # Transforma o vetor 1D em um tensor 3D para convoluções
            nn.Unflatten(1, (128, 7, 7)),

            # Normalização em lote
            nn.BatchNorm2d(128),

            # Primeira convolução transposta
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.ReLU(),  # Função de ativação ReLU

            # Normalização em lote
            nn.BatchNorm2d(64),

            # Segunda convolução transposta
            nn.ConvTranspose2d(64, 1, kernel_size=5, stride=2, padding=2, output_padding=1),

            # Função de ativação final Tanh: valores de saída entre [-1, 1]
            nn.Tanh()
        )

    def forward(self, z, rotulo_one_hot):
        # Concatena o vetor de ruído com o vetor de rótulo one-hot:
        entrada = torch.cat([z, rotulo_one_hot], dim=1)  # Entrada: (lote, z_dim + num_classes)
        return self.rede_neural(entrada)                 # Saída: (lote, 1, 28, 28)

# %% [markdown]
# ## Discriminador

# %%
class Discriminador(nn.Module):
    def __init__(self, num_classes=10, tam_img=28):
        super().__init__()

        # Número de classes
        self.num_classes = num_classes

        # Tamanho da imagem
        self.tam_img = tam_img

        # Definição da rede convolucional sequencial
        self.rede_neural = nn.Sequential(

            # Primeira camada convolucional                                                                 # entrada: [lote, 1 + 10, 28, 28] (1 canal da imagem + canais do rótulo)
            nn.Conv2d(in_channels=1 + num_classes, out_channels=64, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(0.4),

            # Segunda camada convolucional
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(0.4),

            # Achatar o tensor 3D para um vetor 1D
            nn.Flatten(),

            # Camada totalmente conectada
            nn.Linear(7 * 7 * 128, 1),
        )


    def forward(self, imagem, rotulos_one_hot):
        # imagem: (B, 1, H, W) | rotulos_one_hot: (B, C)
        _, _, H, W = imagem.shape

        # (B, C, 1, 1) -> (B, C, H, W)  [expand cria uma view]
        # Cria um tensor do tamanho da imagem, preenchido com os valores do rótulo one-hot, onde cada canal corresponde a um rótulo
        mapa_rotulo = rotulos_one_hot[:, :, None, None].expand(-1, -1, H, W)

        # (B, 1+C, H, W)  [concatenar a imagem com o mapa de rótulo no eixo de canais]
        entrada = torch.cat((imagem, mapa_rotulo), dim=1)

        # Passar pela rede convolucional
        return self.rede_neural(entrada)

# %% [markdown]
# # Configurar Treinamento

# %%
def train_wgan_condicional(
    dataloader,
    gerador,
    discriminador,
    opt_gerador,
    opt_discriminador,
    device,
    epoch,
    z_dim,
    n_critic=5,
    clip_value=0.01,
    num_classes=10,
):

    gerador.train()
    discriminador.train()

    for batch_idx, (dados_reais, rotulos_reais) in enumerate(dataloader):
        batch_size = dados_reais.size(0)
        dados_reais = dados_reais.to(device)
        rotulos_reais = rotulos_reais.to(device)

        # Converte os rótulos reais para one-hot
        rotulos_reais_one_hot = F.one_hot(rotulos_reais, num_classes=num_classes).float()

        # Envia para o dispositivo (GPU/CPU)
        rotulos_reais_one_hot = rotulos_reais_one_hot.to(device)

        # ========================================
        # CRÍTICO (DISCRIMINADOR)
        # ========================================
        for _ in range(n_critic):

            # Gera ruído z
            z = torch.randn((batch_size, z_dim), device=device)

            # Gera dados falsos USANDO OS MESMOS RÓTULOS REAIS (matching label approach)
            dados_falsos = gerador(z, rotulos_reais_one_hot)

            # Avalia dados reais (imagem real + rótulo real)
            saida_reais = discriminador(dados_reais, rotulos_reais_one_hot)

            # Avalia dados falsos (imagem gerada + rótulo real)
            # detach() evita backprop no gerador nessa fase
            # FIXME Teste sem .detach()
            saida_falsos = discriminador(dados_falsos, rotulos_reais_one_hot)

            # Perda do discriminador: soma das perdas para dados reais e falsos
            perda_discriminador = saida_falsos.mean() - saida_reais.mean()

            # Otimiza o discriminador
            opt_discriminador.zero_grad()
            perda_discriminador.backward()
            opt_discriminador.step()

            # Clipping dos pesos do discriminador para satisfazer Lipschitz
            for p in discriminador.parameters():
                p.data.clamp_(-clip_value, clip_value)

        # ========================================
        # GERADOR
        # ========================================

        # Gera novo ruído z
        z = torch.randn((batch_size, z_dim), device=device)

        # Gera dados falsos novamente (com os rótulos reais do batch)
        dados_falsos = gerador(z, rotulos_reais_one_hot)

        # Faz o discriminador avaliar estes dados falsos
        saida_falsos = discriminador(dados_falsos, rotulos_reais_one_hot)

        # Perda do gerador: queremos que o discriminador ache que são reais
        perda_gerador = -saida_falsos.mean()

        # Otimiza o gerador
        opt_gerador.zero_grad()
        perda_gerador.backward()
        opt_gerador.step()

        # ========================================
        # LOG
        # ========================================
        if batch_idx % 100 == 0 or batch_idx == len(dataloader) - 1:
            print(f"[Época {epoch:03d}] [Lote {batch_idx:03d}/{len(dataloader)}] "
                  f"Perda D: {perda_discriminador.item():.4f} | "
                  f"Perda G: {perda_gerador.item():.4f}")

# %%
# Define a função de gerar dados falsos de um vetor latente fixo
def gerar(gerador, device, z_dim=30, num_classes=10, c=0):
    gerador.eval()        # Coloca o modelo em modo de avaliação (desativa dropout, batchnorm, etc.)
    with torch.no_grad(): # Desativa o cálculo de gradientes para economizar memória e acelerar a execução
      z = torch.zeros((1, z_dim), device=device)
      c_tensor = torch.tensor([c], device=device)
      rotulo_one_hot = F.one_hot(c_tensor, num_classes=num_classes).float()
      dados_falsos = gerador(z, rotulo_one_hot).detach().cpu().numpy().reshape(28,28)
    return dados_falsos

# %% [markdown]
# # Executar Treinamento

# %%
# Inicializa os gerador
z_dim = 100
modelo_gerador = Gerador(z_dim)
# Imprime a arquitetura do modelo
print(modelo_gerador)
summary(modelo_gerador, input_size=[(1, 100), (1, 10)])
# Out:
# Gerador(
#   (rede_neural): Sequential(
#     (0): Linear(in_features=110, out_features=6272, bias=True)
#     (1): Unflatten(dim=1, unflattened_size=(128, 7, 7))
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ConvTranspose2d(64, 1, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (7): Tanh()
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Gerador                                  [1, 1, 28, 28]            --
# ├─Sequential: 1-1                        [1, 1, 28, 28]            --
# │    └─Linear: 2-1                       [1, 6272]                 696,192
# │    └─Unflatten: 2-2                    [1, 128, 7, 7]            --
# │    └─BatchNorm2d: 2-3                  [1, 128, 7, 7]            256
# │    └─ConvTranspose2d: 2-4              [1, 64, 14, 14]           204,864
# │    └─ReLU: 2-5                         [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-6                  [1, 64, 14, 14]           128
# │    └─ConvTranspose2d: 2-7              [1, 1, 28, 28]            1,601
# │    └─Tanh: 2-8                         [1, 1, 28, 28]            --
# ==========================================================================================
# Total params: 903,041
# Trainable params: 903,041
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 42.11
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 3.61
# Estimated Total Size (MB): 3.92
# ==========================================================================================

# %%
# Inicializa os discriminador
modelo_discriminador = Discriminador()
# Imprime a arquitetura do modelo
print(modelo_discriminador)
summary(modelo_discriminador, input_size=[(1, 1, 28, 28), (1, 10)])
# Out:
# Discriminador(
#   (rede_neural): Sequential(
#     (0): Conv2d(11, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6272, out_features=1, bias=True)
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Discriminador                            [1, 1]                    --
# ├─Sequential: 1-1                        [1, 1]                    --
# │    └─Conv2d: 2-1                       [1, 64, 14, 14]           17,664
# │    └─LeakyReLU: 2-2                    [1, 64, 14, 14]           --
# │    └─Dropout: 2-3                      [1, 64, 14, 14]           --
# │    └─Conv2d: 2-4                       [1, 128, 7, 7]            204,928
# │    └─LeakyReLU: 2-5                    [1, 128, 7, 7]            --
# │    └─Dropout: 2-6                      [1, 128, 7, 7]            --
# │    └─Flatten: 2-7                      [1, 6272]                 --
# │    └─Linear: 2-8                       [1, 1]                    6,273
# ==========================================================================================
# Total params: 228,865
# Trainable params: 228,865
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 13.51
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.15
# Params size (MB): 0.92
# Estimated Total Size (MB): 1.07
# ==========================================================================================

# %%
# Tenta usar GPU se disponível
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
modelo_gerador.to(device)
modelo_discriminador.to(device)

# Exibe qual dispositivo está sendo utilizado
print(f"Usando {device}.")
# Out:
# Usando cuda.

# %%
# Otimizadores
lr_gerador = 1e-5         # taxa de aprendizagem do gerador
lr_discriminador = 1e-5   # taxa de aprendizagem do discriminador
optimizador_gerador = torch.optim.RMSprop(modelo_gerador.parameters(), lr=lr_gerador)
optimizador_discriminador = torch.optim.RMSprop(modelo_discriminador.parameters(), lr=lr_discriminador)

# %%
num_epochs = 50  # Define o número total de épocas (iterações completas sobre o conjunto de dados de treinamento)
evolução_dado_falso = []
for epoca in range(1, num_epochs + 1):
    train_wgan_condicional(
        dataloader=train_dataloader,
        gerador=modelo_gerador,
        discriminador=modelo_discriminador,
        opt_gerador=optimizador_gerador,
        opt_discriminador=optimizador_discriminador,
        device=device,
        epoch=epoca,
        z_dim=z_dim,
        n_critic=5,
        clip_value=0.01,
        num_classes=10
    )
    if epoca % 5 == 0 or epoca == 1:
      dados_falsos = gerar(gerador=modelo_gerador, device=device, z_dim=z_dim, num_classes=10, c=0)
      plt.imshow(dados_falsos, cmap="gray")
      plt.axis("off")
      plt.title(f"Época {epoca}")
      plt.imsave(f"dados_falsos_epoca_{epoca}.png", dados_falsos, cmap="gray")
      evolução_dado_falso.append(dados_falsos)
print("Fim!")  # Exibe mensagem final indicando que o treinamento terminou
# Out:
# [Época 001] [Lote 000/937] Perda D: -0.0077 | Perda G: 0.0144
# [Época 001] [Lote 100/937] Perda D: -6.4694 | Perda G: 3.9865
# [Época 001] [Lote 200/937] Perda D: -24.5822 | Perda G: 14.9311
# [Época 001] [Lote 300/937] Perda D: -36.0577 | Perda G: 26.2330
# [Época 001] [Lote 400/937] Perda D: -37.2817 | Perda G: 30.9705
# [Época 001] [Lote 500/937] Perda D: -29.6059 | Perda G: 25.2076
# [Época 001] [Lote 600/937] Perda D: -28.7738 | Perda G: 20.1808
# [Época 001] [Lote 700/937] Perda D: -20.4021 | Perda G: 13.4371
# [Época 001] [Lote 800/937] Perda D: -24.3262 | Perda G: 9.3052
# [Época 001] [Lote 900/937] Perda D: -16.8734 | Perda G: 2.0780
# [Época 001] [Lote 936/937] Perda D: -22.9429 | Perda G: -3.0877
# [Época 002] [Lote 000/937] Perda D: -21.5038 | Perda G: 1.8799
# [Época 002] [Lote 100/937] Perda D: -17.0255 | Perda G: -7.8569
# [Época 002] [Lote 200/937] Perda D: -18.7509 | Perda G: -10.5234
# [Época 002] [Lote 300/937] Perda D: -11.7034 | Perda G: -14.2481
# [Época 002] [Lote 400/937] Perda D: -14.2943 | Perda G: -12.5012
# [Época 002] [Lote 500/937] Perda D: -9.6149 | Perda G: -17.0909
# [Época 002] [Lote 600/937] Perda D: -7.8458 | Perda G: -17.5871
# [Época 002] [Lote 700/937] Perda D: -7.1326 | Perda G: -17.4116
# [Época 002] [Lote 800/937] Perda D: -5.8515 | Perda G: -17.6397
# [Época 002] [Lote 900/937] Perda D: -6.8529 | Perda G: -16.1844
# [Época 002] [Lote 936/937] Perda D: -6.9437 | Perda G: -14.5916
# [Época 003] [Lote 000/937] Perda D: -6.6521 | Perda G: -14.2360
# [Época 003] [Lote 100/937] Perda D: -2.3274 | Perda G: -14.3799
# [Época 003] [Lote 200/937] Perda D: -8.0474 | Perda G: -7.1417
# [Época 003] [Lote 300/937] Perda D: -4.2397 | Perda G: -4.9019
# [Época 003] [Lote 400/937] Perda D: -2.3765 | Perda G: -4.4646
# [Época 003] [Lote 500/937] Perda D: -1.4718 | Perda G: -3.7078
# [Época 003] [Lote 600/937] Perda D: -2.9721 | Perda G: -0.7776
# [Época 003] [Lote 700/937] Perda D: -1.7778 | Perda G: 0.8712
# [Época 003] [Lote 800/937] Perda D: -1.3720 | Perda G: -0.3731
# [Época 003] [Lote 900/937] Perda D: -2.6086 | Perda G: 4.2026
# [Época 003] [Lote 936/937] Perda D: -2.1532 | Perda G: 4.2638
# [Época 004] [Lote 000/937] Perda D: -2.4386 | Perda G: 3.2437
# [Época 004] [Lote 100/937] Perda D: -3.1083 | Perda G: 6.6954
# [Época 004] [Lote 200/937] Perda D: -3.1951 | Perda G: 7.2578
# [Época 004] [Lote 300/937] Perda D: -2.6428 | Perda G: 5.7649
# [Época 004] [Lote 400/937] Perda D: -3.6238 | Perda G: 5.8190
# [Época 004] [Lote 500/937] Perda D: -2.4679 | Perda G: 5.3498
# [Época 004] [Lote 600/937] Perda D: -3.7197 | Perda G: 7.2753
# [Época 004] [Lote 700/937] Perda D: -2.5778 | Perda G: 5.0720
# [Época 004] [Lote 800/937] Perda D: -2.0262 | Perda G: 6.5950
# [Época 004] [Lote 900/937] Perda D: -3.6177 | Perda G: 9.0154
# [Época 004] [Lote 936/937] Perda D: -3.0409 | Perda G: 9.5452
# [Época 005] [Lote 000/937] Perda D: -3.1560 | Perda G: 10.3547
# [Época 005] [Lote 100/937] Perda D: -2.0696 | Perda G: 9.0796
# [Época 005] [Lote 200/937] Perda D: -2.1729 | Perda G: 6.0874
# [Época 005] [Lote 300/937] Perda D: -2.0819 | Perda G: 2.8331
# [Época 005] [Lote 400/937] Perda D: -2.2087 | Perda G: 1.6580
# [Época 005] [Lote 500/937] Perda D: -3.2730 | Perda G: 2.4035
# [Época 005] [Lote 600/937] Perda D: -3.4553 | Perda G: 0.6077
# [Época 005] [Lote 700/937] Perda D: -2.3622 | Perda G: -1.0161
# [Época 005] [Lote 800/937] Perda D: -2.8583 | Perda G: -1.7827
# [Época 005] [Lote 900/937] Perda D: -2.9488 | Perda G: -4.4763
# [Época 005] [Lote 936/937] Perda D: -2.6707 | Perda G: -4.7905
# [Época 006] [Lote 000/937] Perda D: -1.7219 | Perda G: -6.0995
# [Época 006] [Lote 100/937] Perda D: -2.3191 | Perda G: -6.1556
# [Época 006] [Lote 200/937] Perda D: -0.9352 | Perda G: -7.7424
# [Época 006] [Lote 300/937] Perda D: -2.3498 | Perda G: -9.3118
# [Época 006] [Lote 400/937] Perda D: -0.8831 | Perda G: -10.8914
# [Época 006] [Lote 500/937] Perda D: -1.6591 | Perda G: -12.0994
# [Época 006] [Lote 600/937] Perda D: -0.3554 | Perda G: -13.4648
# [Época 006] [Lote 700/937] Perda D: -0.7090 | Perda G: -13.7804
# [Época 006] [Lote 800/937] Perda D: -0.0610 | Perda G: -11.5959
# [Época 006] [Lote 900/937] Perda D: 0.2007 | Perda G: -10.5043
# [Época 006] [Lote 936/937] Perda D: -0.2891 | Perda G: -9.3405
# [Época 007] [Lote 000/937] Perda D: 0.4822 | Perda G: -8.5423
# [Época 007] [Lote 100/937] Perda D: 0.4546 | Perda G: -7.9607
# [Época 007] [Lote 200/937] Perda D: -0.1825 | Perda G: -6.7150
# [Época 007] [Lote 300/937] Perda D: -0.2025 | Perda G: -4.2961
# [Época 007] [Lote 400/937] Perda D: -0.4243 | Perda G: -3.0948
# [Época 007] [Lote 500/937] Perda D: -0.4391 | Perda G: -1.6741
# [Época 007] [Lote 600/937] Perda D: -0.3143 | Perda G: -1.2021
# [Época 007] [Lote 700/937] Perda D: -0.3489 | Perda G: -1.1684
# [Época 007] [Lote 800/937] Perda D: -0.3581 | Perda G: -1.2267
# [Época 007] [Lote 900/937] Perda D: -0.4054 | Perda G: -1.2555
# [Época 007] [Lote 936/937] Perda D: -0.4963 | Perda G: -1.3178
# [Época 008] [Lote 000/937] Perda D: -0.6398 | Perda G: -1.5151
# [Época 008] [Lote 100/937] Perda D: -0.4419 | Perda G: -1.9861
# [Época 008] [Lote 200/937] Perda D: -0.3798 | Perda G: -2.6789
# [Época 008] [Lote 300/937] Perda D: -0.2454 | Perda G: -2.8012
# [Época 008] [Lote 400/937] Perda D: -0.2653 | Perda G: -2.4736
# [Época 008] [Lote 500/937] Perda D: -0.2043 | Perda G: -1.9771
# [Época 008] [Lote 600/937] Perda D: 0.0282 | Perda G: -1.6920
# [Época 008] [Lote 700/937] Perda D: -0.3164 | Perda G: -1.3788
# [Época 008] [Lote 800/937] Perda D: -0.1356 | Perda G: -1.5801
# [Época 008] [Lote 900/937] Perda D: -0.3322 | Perda G: -1.8487
# [Época 008] [Lote 936/937] Perda D: -0.2765 | Perda G: -2.1233
# [Época 009] [Lote 000/937] Perda D: -0.1832 | Perda G: -2.1801
# [Época 009] [Lote 100/937] Perda D: -0.2688 | Perda G: -1.9424
# [Época 009] [Lote 200/937] Perda D: -0.2389 | Perda G: -2.3426
# [Época 009] [Lote 300/937] Perda D: -0.2077 | Perda G: -2.2848
# [Época 009] [Lote 400/937] Perda D: -0.1963 | Perda G: -2.6559
# [Época 009] [Lote 500/937] Perda D: -0.1741 | Perda G: -2.6638
# [Época 009] [Lote 600/937] Perda D: -0.2911 | Perda G: -2.8580
# [Época 009] [Lote 700/937] Perda D: -0.1947 | Perda G: -2.5594
# [Época 009] [Lote 800/937] Perda D: -0.2691 | Perda G: -2.8766
# [Época 009] [Lote 900/937] Perda D: -0.1751 | Perda G: -2.4138
# [Época 009] [Lote 936/937] Perda D: -0.1931 | Perda G: -2.4305
# [Época 010] [Lote 000/937] Perda D: -0.2464 | Perda G: -2.7653
# [Época 010] [Lote 100/937] Perda D: -0.2911 | Perda G: -1.8534
# [Época 010] [Lote 200/937] Perda D: -0.3267 | Perda G: -2.2322
# [Época 010] [Lote 300/937] Perda D: -0.3492 | Perda G: -2.1386
# [Época 010] [Lote 400/937] Perda D: -0.1798 | Perda G: -1.7045
# [Época 010] [Lote 500/937] Perda D: -0.2222 | Perda G: -1.6231
# [Época 010] [Lote 600/937] Perda D: -0.2554 | Perda G: -1.7078
# [Época 010] [Lote 700/937] Perda D: -0.1452 | Perda G: -1.3962
# [Época 010] [Lote 800/937] Perda D: -0.1724 | Perda G: -0.9771
# [Época 010] [Lote 900/937] Perda D: -0.2350 | Perda G: -1.5920
# [Época 010] [Lote 936/937] Perda D: -0.2327 | Perda G: -1.2025
# [Época 011] [Lote 000/937] Perda D: -0.1889 | Perda G: -1.0970
# [Época 011] [Lote 100/937] Perda D: -0.1732 | Perda G: -1.1504
# [Época 011] [Lote 200/937] Perda D: -0.2981 | Perda G: -0.9405
# [Época 011] [Lote 300/937] Perda D: -0.1727 | Perda G: -0.6754
# [Época 011] [Lote 400/937] Perda D: -0.2169 | Perda G: -1.5940
# [Época 011] [Lote 500/937] Perda D: -0.2152 | Perda G: -0.4648
# [Época 011] [Lote 600/937] Perda D: -0.2613 | Perda G: -0.6771
# [Época 011] [Lote 700/937] Perda D: -0.1559 | Perda G: -0.9233
# [Época 011] [Lote 800/937] Perda D: -0.2418 | Perda G: -1.0486
# [Época 011] [Lote 900/937] Perda D: -0.2259 | Perda G: -0.9419
# [Época 011] [Lote 936/937] Perda D: -0.2369 | Perda G: -0.9402
# [Época 012] [Lote 000/937] Perda D: -0.2680 | Perda G: -1.6322
# [Época 012] [Lote 100/937] Perda D: -0.2798 | Perda G: -1.4434
# [Época 012] [Lote 200/937] Perda D: -0.2766 | Perda G: -0.6718
# [Época 012] [Lote 300/937] Perda D: -0.2196 | Perda G: -0.4321
# [Época 012] [Lote 400/937] Perda D: -0.1952 | Perda G: -1.3045
# [Época 012] [Lote 500/937] Perda D: -0.2471 | Perda G: -0.1449
# [Época 012] [Lote 600/937] Perda D: -0.3205 | Perda G: -1.2500
# [Época 012] [Lote 700/937] Perda D: -0.2753 | Perda G: -0.8073
# [Época 012] [Lote 800/937] Perda D: -0.2789 | Perda G: -1.2979
# [Época 012] [Lote 900/937] Perda D: -0.2246 | Perda G: -1.2878
# [Época 012] [Lote 936/937] Perda D: -0.1898 | Perda G: -1.4600
# [Época 013] [Lote 000/937] Perda D: -0.3033 | Perda G: -1.1224
# [Época 013] [Lote 100/937] Perda D: -0.2872 | Perda G: -0.8795
# [Época 013] [Lote 200/937] Perda D: -0.3282 | Perda G: -0.6016
# [Época 013] [Lote 300/937] Perda D: -0.2544 | Perda G: -1.7314
# [Época 013] [Lote 400/937] Perda D: -0.3319 | Perda G: -1.4428
# [Época 013] [Lote 500/937] Perda D: -0.4640 | Perda G: -0.9756
# [Época 013] [Lote 600/937] Perda D: -0.4428 | Perda G: -2.4413
# [Época 013] [Lote 700/937] Perda D: -0.3341 | Perda G: -2.3185
# [Época 013] [Lote 800/937] Perda D: -0.4133 | Perda G: -3.1959
# [Época 013] [Lote 900/937] Perda D: -0.4243 | Perda G: -2.6652
# [Época 013] [Lote 936/937] Perda D: -0.4838 | Perda G: -1.3053
# [Época 014] [Lote 000/937] Perda D: -0.4464 | Perda G: -0.4274
# [Época 014] [Lote 100/937] Perda D: -0.4755 | Perda G: -0.2362
# [Época 014] [Lote 200/937] Perda D: -0.5070 | Perda G: -0.8459
# [Época 014] [Lote 300/937] Perda D: -0.5582 | Perda G: -2.1654
# [Época 014] [Lote 400/937] Perda D: -0.5122 | Perda G: -1.6156
# [Época 014] [Lote 500/937] Perda D: -0.4735 | Perda G: -1.2188
# [Época 014] [Lote 600/937] Perda D: -0.5687 | Perda G: 1.2135
# [Época 014] [Lote 700/937] Perda D: -0.5384 | Perda G: 1.3371
# [Época 014] [Lote 800/937] Perda D: -0.4898 | Perda G: -0.4399
# [Época 014] [Lote 900/937] Perda D: -0.6010 | Perda G: -0.7841
# [Época 014] [Lote 936/937] Perda D: -0.5321 | Perda G: -0.2280
# [Época 015] [Lote 000/937] Perda D: -0.5561 | Perda G: -0.8575
# [Época 015] [Lote 100/937] Perda D: -0.4378 | Perda G: 1.1447
# [Época 015] [Lote 200/937] Perda D: -0.6302 | Perda G: 0.1325
# [Época 015] [Lote 300/937] Perda D: -0.6472 | Perda G: 1.3905
# [Época 015] [Lote 400/937] Perda D: -0.5027 | Perda G: 0.6981
# [Época 015] [Lote 500/937] Perda D: -0.5723 | Perda G: 0.6557
# [Época 015] [Lote 600/937] Perda D: -0.6878 | Perda G: 1.5837
# [Época 015] [Lote 700/937] Perda D: -0.6128 | Perda G: 1.7334
# [Época 015] [Lote 800/937] Perda D: -0.4331 | Perda G: 1.3755
# [Época 015] [Lote 900/937] Perda D: -0.6548 | Perda G: 1.9377
# [Época 015] [Lote 936/937] Perda D: -0.5829 | Perda G: 1.7114
# [Época 016] [Lote 000/937] Perda D: -0.6040 | Perda G: 1.0607
# [Época 016] [Lote 100/937] Perda D: -0.5522 | Perda G: 0.5464
# [Época 016] [Lote 200/937] Perda D: -0.5448 | Perda G: 2.1756
# [Época 016] [Lote 300/937] Perda D: -0.4864 | Perda G: 1.6607
# [Época 016] [Lote 400/937] Perda D: -0.6006 | Perda G: 1.3047
# [Época 016] [Lote 500/937] Perda D: -0.4308 | Perda G: 1.4230
# [Época 016] [Lote 600/937] Perda D: -0.5219 | Perda G: 1.5845
# [Época 016] [Lote 700/937] Perda D: -0.3819 | Perda G: 3.3685
# [Época 016] [Lote 800/937] Perda D: -0.3983 | Perda G: 2.2203
# [Época 016] [Lote 900/937] Perda D: -0.4889 | Perda G: 2.9045
# [Época 016] [Lote 936/937] Perda D: -0.4931 | Perda G: 2.7112
# [Época 017] [Lote 000/937] Perda D: -0.4333 | Perda G: 1.6608
# [Época 017] [Lote 100/937] Perda D: -0.7083 | Perda G: 1.0401
# [Época 017] [Lote 200/937] Perda D: -0.2712 | Perda G: 2.6413
# [Época 017] [Lote 300/937] Perda D: -0.4819 | Perda G: 1.4126
# [Época 017] [Lote 400/937] Perda D: -0.5041 | Perda G: 2.0401
# [Época 017] [Lote 500/937] Perda D: -0.4819 | Perda G: 1.9371
# [Época 017] [Lote 600/937] Perda D: -0.4972 | Perda G: 2.9994
# [Época 017] [Lote 700/937] Perda D: -0.4553 | Perda G: 1.8454
# [Época 017] [Lote 800/937] Perda D: -0.5305 | Perda G: 1.0104
# [Época 017] [Lote 900/937] Perda D: -0.3533 | Perda G: 3.6558
# [Época 017] [Lote 936/937] Perda D: -0.4074 | Perda G: 2.2014
# [Época 018] [Lote 000/937] Perda D: -0.3423 | Perda G: 2.2710
# [Época 018] [Lote 100/937] Perda D: -0.4405 | Perda G: 1.4507
# [Época 018] [Lote 200/937] Perda D: -0.2657 | Perda G: 2.3318
# [Época 018] [Lote 300/937] Perda D: -0.1767 | Perda G: 1.7751
# [Época 018] [Lote 400/937] Perda D: -0.2589 | Perda G: 0.7959
# [Época 018] [Lote 500/937] Perda D: -0.3770 | Perda G: 2.9740
# [Época 018] [Lote 600/937] Perda D: -0.4025 | Perda G: 3.6481
# [Época 018] [Lote 700/937] Perda D: -0.4419 | Perda G: 1.5009
# [Época 018] [Lote 800/937] Perda D: -0.2202 | Perda G: 2.8282
# [Época 018] [Lote 900/937] Perda D: -0.2144 | Perda G: 1.8545
# [Época 018] [Lote 936/937] Perda D: -0.3280 | Perda G: 2.8922
# [Época 019] [Lote 000/937] Perda D: -0.3433 | Perda G: 3.2618
# [Época 019] [Lote 100/937] Perda D: -0.3337 | Perda G: 2.1240
# [Época 019] [Lote 200/937] Perda D: -0.2360 | Perda G: 1.7001
# [Época 019] [Lote 300/937] Perda D: -0.6931 | Perda G: 3.1288
# [Época 019] [Lote 400/937] Perda D: -0.3395 | Perda G: 2.3255
# [Época 019] [Lote 500/937] Perda D: -0.5906 | Perda G: 3.2580
# [Época 019] [Lote 600/937] Perda D: -0.1752 | Perda G: 2.9149
# [Época 019] [Lote 700/937] Perda D: -0.5685 | Perda G: 2.0734
# [Época 019] [Lote 800/937] Perda D: -0.2273 | Perda G: 2.0238
# [Época 019] [Lote 900/937] Perda D: -0.2933 | Perda G: 1.2140
# [Época 019] [Lote 936/937] Perda D: -0.2513 | Perda G: 3.0050
# [Época 020] [Lote 000/937] Perda D: -0.1196 | Perda G: 3.0326
# [Época 020] [Lote 100/937] Perda D: -0.3476 | Perda G: 3.4601
# [Época 020] [Lote 200/937] Perda D: -0.4087 | Perda G: 2.5180
# [Época 020] [Lote 300/937] Perda D: -0.0961 | Perda G: 1.6305
# [Época 020] [Lote 400/937] Perda D: -0.2987 | Perda G: 3.7196
# [Época 020] [Lote 500/937] Perda D: -0.0928 | Perda G: 4.0801
# [Época 020] [Lote 600/937] Perda D: -0.3223 | Perda G: 3.3902
# [Época 020] [Lote 700/937] Perda D: -0.1961 | Perda G: 3.2998
# [Época 020] [Lote 800/937] Perda D: -0.1734 | Perda G: 3.2699
# [Época 020] [Lote 900/937] Perda D: -0.2582 | Perda G: 0.8275
# [Época 020] [Lote 936/937] Perda D: -0.0583 | Perda G: 3.3474
# [Época 021] [Lote 000/937] Perda D: -0.2926 | Perda G: 3.0811
# [Época 021] [Lote 100/937] Perda D: -0.2682 | Perda G: 2.7478
# [Época 021] [Lote 200/937] Perda D: -0.1903 | Perda G: 1.6938
# [Época 021] [Lote 300/937] Perda D: -0.2047 | Perda G: 1.9263
# [Época 021] [Lote 400/937] Perda D: -0.6817 | Perda G: 2.7210
# [Época 021] [Lote 500/937] Perda D: -0.0451 | Perda G: 2.5654
# [Época 021] [Lote 600/937] Perda D: -0.2378 | Perda G: 1.3625
# [Época 021] [Lote 700/937] Perda D: -0.2216 | Perda G: 3.4199
# [Época 021] [Lote 800/937] Perda D: 0.0340 | Perda G: 1.8308
# [Época 021] [Lote 900/937] Perda D: -0.1762 | Perda G: 2.7959
# [Época 021] [Lote 936/937] Perda D: -0.2010 | Perda G: 3.1798
# [Época 022] [Lote 000/937] Perda D: -0.2160 | Perda G: 2.8062
# [Época 022] [Lote 100/937] Perda D: -0.2191 | Perda G: 2.8650
# [Época 022] [Lote 200/937] Perda D: -0.2546 | Perda G: 2.0523
# [Época 022] [Lote 300/937] Perda D: -0.1795 | Perda G: 3.4779
# [Época 022] [Lote 400/937] Perda D: -0.1978 | Perda G: 3.3350
# [Época 022] [Lote 500/937] Perda D: -0.3309 | Perda G: 2.1097
# [Época 022] [Lote 600/937] Perda D: 0.0127 | Perda G: 2.6573
# [Época 022] [Lote 700/937] Perda D: -0.3542 | Perda G: 4.0837
# [Época 022] [Lote 800/937] Perda D: 0.0043 | Perda G: 4.0149
# [Época 022] [Lote 900/937] Perda D: -0.1877 | Perda G: 2.0086
# [Época 022] [Lote 936/937] Perda D: -0.1923 | Perda G: 2.3630
# [Época 023] [Lote 000/937] Perda D: -0.1913 | Perda G: 1.5448
# [Época 023] [Lote 100/937] Perda D: -0.2262 | Perda G: 3.9921
# [Época 023] [Lote 200/937] Perda D: -0.0997 | Perda G: 1.5144
# [Época 023] [Lote 300/937] Perda D: -0.1097 | Perda G: 0.3710
# [Época 023] [Lote 400/937] Perda D: -0.2292 | Perda G: 2.7738
# [Época 023] [Lote 500/937] Perda D: -0.3470 | Perda G: 1.1714
# [Época 023] [Lote 600/937] Perda D: -0.2736 | Perda G: 1.9320
# [Época 023] [Lote 700/937] Perda D: -0.2732 | Perda G: 2.2604
# [Época 023] [Lote 800/937] Perda D: -0.1408 | Perda G: 1.1184
# [Época 023] [Lote 900/937] Perda D: -0.4492 | Perda G: 2.1169
# [Época 023] [Lote 936/937] Perda D: -0.2910 | Perda G: 1.8707
# [Época 024] [Lote 000/937] Perda D: -0.2821 | Perda G: 1.0178
# [Época 024] [Lote 100/937] Perda D: -0.2975 | Perda G: 1.7062
# [Época 024] [Lote 200/937] Perda D: -0.2074 | Perda G: -0.2279
# [Época 024] [Lote 300/937] Perda D: -0.4156 | Perda G: -0.5342
# [Época 024] [Lote 400/937] Perda D: -0.1916 | Perda G: 1.9259
# [Época 024] [Lote 500/937] Perda D: -0.3411 | Perda G: 1.6788
# [Época 024] [Lote 600/937] Perda D: -0.0514 | Perda G: 1.6296
# [Época 024] [Lote 700/937] Perda D: -0.1046 | Perda G: 1.5927
# [Época 024] [Lote 800/937] Perda D: 0.1021 | Perda G: 1.0763
# [Época 024] [Lote 900/937] Perda D: 0.1172 | Perda G: 1.1296
# [Época 024] [Lote 936/937] Perda D: -0.0210 | Perda G: 2.0138
# [Época 025] [Lote 000/937] Perda D: 0.0339 | Perda G: 1.8782
# [Época 025] [Lote 100/937] Perda D: -0.3246 | Perda G: 3.5007
# [Época 025] [Lote 200/937] Perda D: -0.1822 | Perda G: 2.7585
# [Época 025] [Lote 300/937] Perda D: -0.2192 | Perda G: 2.2003
# [Época 025] [Lote 400/937] Perda D: -0.1510 | Perda G: 1.9034
# [Época 025] [Lote 500/937] Perda D: -0.1644 | Perda G: 1.8149
# [Época 025] [Lote 600/937] Perda D: -0.0820 | Perda G: 1.3753
# [Época 025] [Lote 700/937] Perda D: -0.3310 | Perda G: 2.4693
# [Época 025] [Lote 800/937] Perda D: 0.0453 | Perda G: 2.2735
# [Época 025] [Lote 900/937] Perda D: 0.1723 | Perda G: 1.3981
# [Época 025] [Lote 936/937] Perda D: -0.1522 | Perda G: 2.1373
# [Época 026] [Lote 000/937] Perda D: -0.1909 | Perda G: 3.1328
# [Época 026] [Lote 100/937] Perda D: 0.0227 | Perda G: 4.5070
# [Época 026] [Lote 200/937] Perda D: -0.2612 | Perda G: 1.7658
# [Época 026] [Lote 300/937] Perda D: -0.1792 | Perda G: 3.5915
# [Época 026] [Lote 400/937] Perda D: -0.2786 | Perda G: 0.6583
# [Época 026] [Lote 500/937] Perda D: -0.0887 | Perda G: 2.2673
# [Época 026] [Lote 600/937] Perda D: -0.2491 | Perda G: 1.0778
# [Época 026] [Lote 700/937] Perda D: -0.3342 | Perda G: 0.8342
# [Época 026] [Lote 800/937] Perda D: -0.1614 | Perda G: 2.8953
# [Época 026] [Lote 900/937] Perda D: -0.0512 | Perda G: 3.0441
# [Época 026] [Lote 936/937] Perda D: -0.4339 | Perda G: 1.8115
# [Época 027] [Lote 000/937] Perda D: -0.1329 | Perda G: 2.0244
# [Época 027] [Lote 100/937] Perda D: -0.0743 | Perda G: 1.6831
# [Época 027] [Lote 200/937] Perda D: -0.2631 | Perda G: 2.8862
# [Época 027] [Lote 300/937] Perda D: -0.1164 | Perda G: 2.6380
# [Época 027] [Lote 400/937] Perda D: -0.4187 | Perda G: 1.6899
# [Época 027] [Lote 500/937] Perda D: -0.1127 | Perda G: 2.0669
# [Época 027] [Lote 600/937] Perda D: -0.1915 | Perda G: 1.7697
# [Época 027] [Lote 700/937] Perda D: -0.2783 | Perda G: 3.1163
# [Época 027] [Lote 800/937] Perda D: 0.0474 | Perda G: 2.1272
# [Época 027] [Lote 900/937] Perda D: -0.1317 | Perda G: 2.9328
# [Época 027] [Lote 936/937] Perda D: -0.2887 | Perda G: 1.5478
# [Época 028] [Lote 000/937] Perda D: -0.5049 | Perda G: 0.2648
# [Época 028] [Lote 100/937] Perda D: -0.0912 | Perda G: 2.0815
# [Época 028] [Lote 200/937] Perda D: 0.1128 | Perda G: 2.1426
# [Época 028] [Lote 300/937] Perda D: -0.0632 | Perda G: 1.9757
# [Época 028] [Lote 400/937] Perda D: 0.0887 | Perda G: 0.5076
# [Época 028] [Lote 500/937] Perda D: -0.0495 | Perda G: 2.1176
# [Época 028] [Lote 600/937] Perda D: 0.0088 | Perda G: 0.8622
# [Época 028] [Lote 700/937] Perda D: 0.0178 | Perda G: 0.6945
# [Época 028] [Lote 800/937] Perda D: -0.0952 | Perda G: 2.9636
# [Época 028] [Lote 900/937] Perda D: -0.1713 | Perda G: 1.9578
# [Época 028] [Lote 936/937] Perda D: 0.0362 | Perda G: 0.5139
# [Época 029] [Lote 000/937] Perda D: -0.1593 | Perda G: 0.5385
# [Época 029] [Lote 100/937] Perda D: 0.0685 | Perda G: 1.4962
# [Época 029] [Lote 200/937] Perda D: -0.0808 | Perda G: 2.5193
# [Época 029] [Lote 300/937] Perda D: -0.1395 | Perda G: 2.0261
# [Época 029] [Lote 400/937] Perda D: -0.3950 | Perda G: 2.2429
# [Época 029] [Lote 500/937] Perda D: -0.1249 | Perda G: 2.7481
# [Época 029] [Lote 600/937] Perda D: -0.0012 | Perda G: -0.2394
# [Época 029] [Lote 700/937] Perda D: -0.3193 | Perda G: 2.1887
# [Época 029] [Lote 800/937] Perda D: -0.4432 | Perda G: 2.4191
# [Época 029] [Lote 900/937] Perda D: -0.0372 | Perda G: 3.3084
# [Época 029] [Lote 936/937] Perda D: -0.2004 | Perda G: 2.4054
# [Época 030] [Lote 000/937] Perda D: -0.1263 | Perda G: 3.9842
# [Época 030] [Lote 100/937] Perda D: -0.0410 | Perda G: 2.6149
# [Época 030] [Lote 200/937] Perda D: 0.0866 | Perda G: 2.6956
# [Época 030] [Lote 300/937] Perda D: -0.0937 | Perda G: 1.6594
# [Época 030] [Lote 400/937] Perda D: -0.1114 | Perda G: 2.0934
# [Época 030] [Lote 500/937] Perda D: -0.0952 | Perda G: 2.3442
# [Época 030] [Lote 600/937] Perda D: 0.1262 | Perda G: 4.0385
# [Época 030] [Lote 700/937] Perda D: -0.1486 | Perda G: 2.2647
# [Época 030] [Lote 800/937] Perda D: -0.1112 | Perda G: 2.7682
# [Época 030] [Lote 900/937] Perda D: 0.2279 | Perda G: 2.7882
# [Época 030] [Lote 936/937] Perda D: 0.1399 | Perda G: 2.7682
# [Época 031] [Lote 000/937] Perda D: -0.0815 | Perda G: 3.7956
# [Época 031] [Lote 100/937] Perda D: -0.2077 | Perda G: 1.2408
# [Época 031] [Lote 200/937] Perda D: -0.1341 | Perda G: 2.3146
# [Época 031] [Lote 300/937] Perda D: -0.0192 | Perda G: 1.6367
# [Época 031] [Lote 400/937] Perda D: -0.1088 | Perda G: 3.2716
# [Época 031] [Lote 500/937] Perda D: -0.0640 | Perda G: 1.5380
# [Época 031] [Lote 600/937] Perda D: -0.1107 | Perda G: 1.8031
# [Época 031] [Lote 700/937] Perda D: -0.2995 | Perda G: 2.0229
# [Época 031] [Lote 800/937] Perda D: 0.0839 | Perda G: 3.6684
# [Época 031] [Lote 900/937] Perda D: -0.0707 | Perda G: 1.3661
# [Época 031] [Lote 936/937] Perda D: -0.2359 | Perda G: 2.2482
# [Época 032] [Lote 000/937] Perda D: -0.0025 | Perda G: 2.2496
# [Época 032] [Lote 100/937] Perda D: -0.0850 | Perda G: 2.0023
# [Época 032] [Lote 200/937] Perda D: -0.0207 | Perda G: 1.5378
# [Época 032] [Lote 300/937] Perda D: -0.1097 | Perda G: 2.1639
# [Época 032] [Lote 400/937] Perda D: -0.3317 | Perda G: 3.0076
# [Época 032] [Lote 500/937] Perda D: -0.1434 | Perda G: 2.1781
# [Época 032] [Lote 600/937] Perda D: -0.1388 | Perda G: 2.9117
# [Época 032] [Lote 700/937] Perda D: -0.0565 | Perda G: 3.6182
# [Época 032] [Lote 800/937] Perda D: 0.0058 | Perda G: 1.9349
# [Época 032] [Lote 900/937] Perda D: -0.1559 | Perda G: 1.6218
# [Época 032] [Lote 936/937] Perda D: -0.1833 | Perda G: 1.6673
# [Época 033] [Lote 000/937] Perda D: 0.0112 | Perda G: 1.7580
# [Época 033] [Lote 100/937] Perda D: -0.1165 | Perda G: 3.1535
# [Época 033] [Lote 200/937] Perda D: 0.0429 | Perda G: 1.1829
# [Época 033] [Lote 300/937] Perda D: -0.1154 | Perda G: 2.3403
# [Época 033] [Lote 400/937] Perda D: -0.2321 | Perda G: 4.5731
# [Época 033] [Lote 500/937] Perda D: -0.0112 | Perda G: 2.9284
# [Época 033] [Lote 600/937] Perda D: -0.2601 | Perda G: 2.4327
# [Época 033] [Lote 700/937] Perda D: -0.1640 | Perda G: 2.2871
# [Época 033] [Lote 800/937] Perda D: -0.0675 | Perda G: 2.4389
# [Época 033] [Lote 900/937] Perda D: -0.0531 | Perda G: 1.8581
# [Época 033] [Lote 936/937] Perda D: -0.1126 | Perda G: 1.5592
# [Época 034] [Lote 000/937] Perda D: 0.0456 | Perda G: 3.6007
# [Época 034] [Lote 100/937] Perda D: -0.0281 | Perda G: 2.6334
# [Época 034] [Lote 200/937] Perda D: 0.0114 | Perda G: 2.1763
# [Época 034] [Lote 300/937] Perda D: -0.1887 | Perda G: 1.5418
# [Época 034] [Lote 400/937] Perda D: -0.3606 | Perda G: 3.2785
# [Época 034] [Lote 500/937] Perda D: -0.1416 | Perda G: 1.6097
# [Época 034] [Lote 600/937] Perda D: 0.1516 | Perda G: 0.4589
# [Época 034] [Lote 700/937] Perda D: -0.0663 | Perda G: 2.1833
# [Época 034] [Lote 800/937] Perda D: -0.0662 | Perda G: 3.5090
# [Época 034] [Lote 900/937] Perda D: -0.1798 | Perda G: 2.6649
# [Época 034] [Lote 936/937] Perda D: -0.1798 | Perda G: 2.1788
# [Época 035] [Lote 000/937] Perda D: -0.0790 | Perda G: 1.7982
# [Época 035] [Lote 100/937] Perda D: -0.0072 | Perda G: 1.9445
# [Época 035] [Lote 200/937] Perda D: -0.3587 | Perda G: 1.5104
# [Época 035] [Lote 300/937] Perda D: -0.0764 | Perda G: 1.9135
# [Época 035] [Lote 400/937] Perda D: 0.0217 | Perda G: 3.2407
# [Época 035] [Lote 500/937] Perda D: -0.0174 | Perda G: 2.8659
# [Época 035] [Lote 600/937] Perda D: 0.0817 | Perda G: 2.6268
# [Época 035] [Lote 700/937] Perda D: -0.1809 | Perda G: 1.7497
# [Época 035] [Lote 800/937] Perda D: -0.1122 | Perda G: 2.4795
# [Época 035] [Lote 900/937] Perda D: 0.0006 | Perda G: 3.7995
# [Época 035] [Lote 936/937] Perda D: -0.1561 | Perda G: 2.4607
# [Época 036] [Lote 000/937] Perda D: 0.1220 | Perda G: 1.7574
# [Época 036] [Lote 100/937] Perda D: -0.1700 | Perda G: 3.4937
# [Época 036] [Lote 200/937] Perda D: -0.1505 | Perda G: 3.3479
# [Época 036] [Lote 300/937] Perda D: 0.0158 | Perda G: 3.5089
# [Época 036] [Lote 400/937] Perda D: -0.2055 | Perda G: 3.1940
# [Época 036] [Lote 500/937] Perda D: -0.0445 | Perda G: 2.4441
# [Época 036] [Lote 600/937] Perda D: -0.3104 | Perda G: 1.4484
# [Época 036] [Lote 700/937] Perda D: 0.0136 | Perda G: 4.3446
# [Época 036] [Lote 800/937] Perda D: -0.4552 | Perda G: 2.8891
# [Época 036] [Lote 900/937] Perda D: -0.0615 | Perda G: 2.2036
# [Época 036] [Lote 936/937] Perda D: 0.0662 | Perda G: 4.5645
# [Época 037] [Lote 000/937] Perda D: 0.0110 | Perda G: 2.8895
# [Época 037] [Lote 100/937] Perda D: -0.0900 | Perda G: 2.3092
# [Época 037] [Lote 200/937] Perda D: -0.3240 | Perda G: 4.1619
# [Época 037] [Lote 300/937] Perda D: -0.1408 | Perda G: 3.0343
# [Época 037] [Lote 400/937] Perda D: -0.0645 | Perda G: 2.4869
# [Época 037] [Lote 500/937] Perda D: 0.0951 | Perda G: 2.1851
# [Época 037] [Lote 600/937] Perda D: -0.1888 | Perda G: 2.4181
# [Época 037] [Lote 700/937] Perda D: -0.0791 | Perda G: 2.9163
# [Época 037] [Lote 800/937] Perda D: -0.1640 | Perda G: 3.4558
# [Época 037] [Lote 900/937] Perda D: -0.1576 | Perda G: 2.8836
# [Época 037] [Lote 936/937] Perda D: 0.1207 | Perda G: 3.1796
# [Época 038] [Lote 000/937] Perda D: -0.0498 | Perda G: 1.0317
# [Época 038] [Lote 100/937] Perda D: -0.5252 | Perda G: 2.9169
# [Época 038] [Lote 200/937] Perda D: -0.0829 | Perda G: 3.6006
# [Época 038] [Lote 300/937] Perda D: -0.1388 | Perda G: 1.3790
# [Época 038] [Lote 400/937] Perda D: 0.0073 | Perda G: 1.7392
# [Época 038] [Lote 500/937] Perda D: 0.0867 | Perda G: 0.6395
# [Época 038] [Lote 600/937] Perda D: -0.0500 | Perda G: 1.9012
# [Época 038] [Lote 700/937] Perda D: -0.1375 | Perda G: 2.5663
# [Época 038] [Lote 800/937] Perda D: 0.2229 | Perda G: 3.7181
# [Época 038] [Lote 900/937] Perda D: -0.2653 | Perda G: 3.1093
# [Época 038] [Lote 936/937] Perda D: -0.2059 | Perda G: 2.8231
# [Época 039] [Lote 000/937] Perda D: -0.2794 | Perda G: 2.6159
# [Época 039] [Lote 100/937] Perda D: -0.2447 | Perda G: 1.0326
# [Época 039] [Lote 200/937] Perda D: 0.0294 | Perda G: 3.2464
# [Época 039] [Lote 300/937] Perda D: -0.0852 | Perda G: 3.0706
# [Época 039] [Lote 400/937] Perda D: -0.4509 | Perda G: 3.7833
# [Época 039] [Lote 500/937] Perda D: -0.0276 | Perda G: 2.3281
# [Época 039] [Lote 600/937] Perda D: -0.5399 | Perda G: 4.2381
# [Época 039] [Lote 700/937] Perda D: -0.1279 | Perda G: 2.7199
# [Época 039] [Lote 800/937] Perda D: -0.1831 | Perda G: 2.4551
# [Época 039] [Lote 900/937] Perda D: -0.0013 | Perda G: 2.5878
# [Época 039] [Lote 936/937] Perda D: -0.0572 | Perda G: 2.3689
# [Época 040] [Lote 000/937] Perda D: -0.1769 | Perda G: 2.8120
# [Época 040] [Lote 100/937] Perda D: -0.1281 | Perda G: 1.9412
# [Época 040] [Lote 200/937] Perda D: -0.2304 | Perda G: 4.4058
# [Época 040] [Lote 300/937] Perda D: -0.1358 | Perda G: 2.6655
# [Época 040] [Lote 400/937] Perda D: -0.1028 | Perda G: 2.3681
# [Época 040] [Lote 500/937] Perda D: -0.0363 | Perda G: 3.7220
# [Época 040] [Lote 600/937] Perda D: -0.1439 | Perda G: 2.5612
# [Época 040] [Lote 700/937] Perda D: -0.2031 | Perda G: 1.3660
# [Época 040] [Lote 800/937] Perda D: -0.1219 | Perda G: 2.9151
# [Época 040] [Lote 900/937] Perda D: -0.2800 | Perda G: 3.0139
# [Época 040] [Lote 936/937] Perda D: -0.4291 | Perda G: 1.3637
# [Época 041] [Lote 000/937] Perda D: -0.1067 | Perda G: 2.1484
# [Época 041] [Lote 100/937] Perda D: -0.3265 | Perda G: 3.7217
# [Época 041] [Lote 200/937] Perda D: -0.3923 | Perda G: 1.5495
# [Época 041] [Lote 300/937] Perda D: -0.1326 | Perda G: 1.9136
# [Época 041] [Lote 400/937] Perda D: -0.3812 | Perda G: 2.7711
# [Época 041] [Lote 500/937] Perda D: 0.0748 | Perda G: 2.9700
# [Época 041] [Lote 600/937] Perda D: -0.1508 | Perda G: 1.6921
# [Época 041] [Lote 700/937] Perda D: -0.0793 | Perda G: 2.7323
# [Época 041] [Lote 800/937] Perda D: -0.2437 | Perda G: 3.6235
# [Época 041] [Lote 900/937] Perda D: -0.1320 | Perda G: 2.2648
# [Época 041] [Lote 936/937] Perda D: 0.0649 | Perda G: 2.5862
# [Época 042] [Lote 000/937] Perda D: -0.2382 | Perda G: 1.7248
# [Época 042] [Lote 100/937] Perda D: -0.1294 | Perda G: 2.6392
# [Época 042] [Lote 200/937] Perda D: -0.1250 | Perda G: 3.1031
# [Época 042] [Lote 300/937] Perda D: -0.0813 | Perda G: 3.8059
# [Época 042] [Lote 400/937] Perda D: -0.2641 | Perda G: 3.1058
# [Época 042] [Lote 500/937] Perda D: -0.2373 | Perda G: 3.5168
# [Época 042] [Lote 600/937] Perda D: 0.0727 | Perda G: 2.0903
# [Época 042] [Lote 700/937] Perda D: -0.1566 | Perda G: 2.3740
# [Época 042] [Lote 800/937] Perda D: -0.5390 | Perda G: 4.3271
# [Época 042] [Lote 900/937] Perda D: -0.1802 | Perda G: 1.9284
# [Época 042] [Lote 936/937] Perda D: 0.0514 | Perda G: 2.9418
# [Época 043] [Lote 000/937] Perda D: -0.3157 | Perda G: 3.1328
# [Época 043] [Lote 100/937] Perda D: 0.1695 | Perda G: 0.8997
# [Época 043] [Lote 200/937] Perda D: -0.1974 | Perda G: 4.3857
# [Época 043] [Lote 300/937] Perda D: -0.0838 | Perda G: 2.7585
# [Época 043] [Lote 400/937] Perda D: -0.1142 | Perda G: 2.7424
# [Época 043] [Lote 500/937] Perda D: 0.0290 | Perda G: 2.5873
# [Época 043] [Lote 600/937] Perda D: -0.0109 | Perda G: 3.8663
# [Época 043] [Lote 700/937] Perda D: -0.0429 | Perda G: 2.9017
# [Época 043] [Lote 800/937] Perda D: -0.2404 | Perda G: 2.6408
# [Época 043] [Lote 900/937] Perda D: -0.2015 | Perda G: 3.1528
# [Época 043] [Lote 936/937] Perda D: -0.2595 | Perda G: 2.3376
# [Época 044] [Lote 000/937] Perda D: 0.1944 | Perda G: 1.6174
# [Época 044] [Lote 100/937] Perda D: -0.0907 | Perda G: 3.0636
# [Época 044] [Lote 200/937] Perda D: -0.1495 | Perda G: 3.0552
# [Época 044] [Lote 300/937] Perda D: -0.1842 | Perda G: 2.4524
# [Época 044] [Lote 400/937] Perda D: -0.2033 | Perda G: 4.5714
# [Época 044] [Lote 500/937] Perda D: -0.2809 | Perda G: 3.0410
# [Época 044] [Lote 600/937] Perda D: -0.1945 | Perda G: 3.2872
# [Época 044] [Lote 700/937] Perda D: -0.2156 | Perda G: 2.6699
# [Época 044] [Lote 800/937] Perda D: 0.0492 | Perda G: 3.2391
# [Época 044] [Lote 900/937] Perda D: -0.0449 | Perda G: 3.0304
# [Época 044] [Lote 936/937] Perda D: 0.1800 | Perda G: 2.4195
# [Época 045] [Lote 000/937] Perda D: -0.1647 | Perda G: 3.2562
# [Época 045] [Lote 100/937] Perda D: -0.2911 | Perda G: 2.5795
# [Época 045] [Lote 200/937] Perda D: -0.6112 | Perda G: 1.0188
# [Época 045] [Lote 300/937] Perda D: -0.1396 | Perda G: 1.1375
# [Época 045] [Lote 400/937] Perda D: -0.1287 | Perda G: 2.9758
# [Época 045] [Lote 500/937] Perda D: -0.0602 | Perda G: 1.0869
# [Época 045] [Lote 600/937] Perda D: -0.1554 | Perda G: 2.9728
# [Época 045] [Lote 700/937] Perda D: -0.6599 | Perda G: 0.3974
# [Época 045] [Lote 800/937] Perda D: -0.0123 | Perda G: 2.2208
# [Época 045] [Lote 900/937] Perda D: -0.0996 | Perda G: 2.3488
# [Época 045] [Lote 936/937] Perda D: -0.1225 | Perda G: 2.6317
# [Época 046] [Lote 000/937] Perda D: 0.0410 | Perda G: 3.4416
# [Época 046] [Lote 100/937] Perda D: -0.2072 | Perda G: 3.4650
# [Época 046] [Lote 200/937] Perda D: 0.0259 | Perda G: 1.7984
# [Época 046] [Lote 300/937] Perda D: -0.1736 | Perda G: 3.7489
# [Época 046] [Lote 400/937] Perda D: -0.0194 | Perda G: 2.2777
# [Época 046] [Lote 500/937] Perda D: 0.0740 | Perda G: 3.7024
# [Época 046] [Lote 600/937] Perda D: -0.2581 | Perda G: 2.6605
# [Época 046] [Lote 700/937] Perda D: -0.0823 | Perda G: 3.7140
# [Época 046] [Lote 800/937] Perda D: -0.0283 | Perda G: 3.1138
# [Época 046] [Lote 900/937] Perda D: 0.2480 | Perda G: 4.7050
# [Época 046] [Lote 936/937] Perda D: -0.1055 | Perda G: 1.4794
# [Época 047] [Lote 000/937] Perda D: -0.1158 | Perda G: 1.9228
# [Época 047] [Lote 100/937] Perda D: -0.2066 | Perda G: 3.2905
# [Época 047] [Lote 200/937] Perda D: 0.0952 | Perda G: 4.1523
# [Época 047] [Lote 300/937] Perda D: -0.0321 | Perda G: 3.1133
# [Época 047] [Lote 400/937] Perda D: -0.3239 | Perda G: 3.8834
# [Época 047] [Lote 500/937] Perda D: -0.1606 | Perda G: 3.2049
# [Época 047] [Lote 600/937] Perda D: -0.1816 | Perda G: 2.9344
# [Época 047] [Lote 700/937] Perda D: -0.0741 | Perda G: 1.9610
# [Época 047] [Lote 800/937] Perda D: -0.2040 | Perda G: 2.5110
# [Época 047] [Lote 900/937] Perda D: -0.1416 | Perda G: 2.4817
# [Época 047] [Lote 936/937] Perda D: -0.0822 | Perda G: 4.0596
# [Época 048] [Lote 000/937] Perda D: 0.0054 | Perda G: 3.3535
# [Época 048] [Lote 100/937] Perda D: -0.1054 | Perda G: 0.8772
# [Época 048] [Lote 200/937] Perda D: -0.0682 | Perda G: 2.6384
# [Época 048] [Lote 300/937] Perda D: -0.0004 | Perda G: 3.2919
# [Época 048] [Lote 400/937] Perda D: -0.1007 | Perda G: 3.0765
# [Época 048] [Lote 500/937] Perda D: -0.0263 | Perda G: 4.4948
# [Época 048] [Lote 600/937] Perda D: -0.1420 | Perda G: 2.5335
# [Época 048] [Lote 700/937] Perda D: -0.0507 | Perda G: 2.6340
# [Época 048] [Lote 800/937] Perda D: -0.2630 | Perda G: 2.9184
# [Época 048] [Lote 900/937] Perda D: -0.0407 | Perda G: 3.1229
# [Época 048] [Lote 936/937] Perda D: -0.2564 | Perda G: 1.5301
# [Época 049] [Lote 000/937] Perda D: -0.0287 | Perda G: 2.1832
# [Época 049] [Lote 100/937] Perda D: -0.2860 | Perda G: 2.0167
# [Época 049] [Lote 200/937] Perda D: -0.2938 | Perda G: 3.6197
# [Época 049] [Lote 300/937] Perda D: -0.2834 | Perda G: 2.1716
# [Época 049] [Lote 400/937] Perda D: -0.0918 | Perda G: 1.7886
# [Época 049] [Lote 500/937] Perda D: -0.2332 | Perda G: 2.2974
# [Época 049] [Lote 600/937] Perda D: 0.0653 | Perda G: 3.3632
# [Época 049] [Lote 700/937] Perda D: -0.0891 | Perda G: 2.8590
# [Época 049] [Lote 800/937] Perda D: -0.0248 | Perda G: 2.6551
# [Época 049] [Lote 900/937] Perda D: -0.1352 | Perda G: 3.8104
# [Época 049] [Lote 936/937] Perda D: -0.0587 | Perda G: 4.0039
# [Época 050] [Lote 000/937] Perda D: -0.2246 | Perda G: 2.2821
# [Época 050] [Lote 100/937] Perda D: -0.1262 | Perda G: 2.6851
# [Época 050] [Lote 200/937] Perda D: 0.0669 | Perda G: 5.1421
# [Época 050] [Lote 300/937] Perda D: -0.3842 | Perda G: 0.8852
# [Época 050] [Lote 400/937] Perda D: -0.0544 | Perda G: 3.0830
# [Época 050] [Lote 500/937] Perda D: -0.0263 | Perda G: 2.5412
# [Época 050] [Lote 600/937] Perda D: 0.1512 | Perda G: 3.4425
# [Época 050] [Lote 700/937] Perda D: -0.1859 | Perda G: 2.2049
# [Época 050] [Lote 800/937] Perda D: -0.1316 | Perda G: 3.4818
# [Época 050] [Lote 900/937] Perda D: 0.0101 | Perda G: 2.7637
# [Época 050] [Lote 936/937] Perda D: -0.1234 | Perda G: 4.1621
# Fim!

# %% [markdown]
# # Resultados

# %%
# Salva gerador treinado
torch.save(modelo_gerador.state_dict(), "gerador_wgan_condicional.pth")

# %%
z_dim = 100
device = "cpu"
modelo_gerador = Gerador(z_dim)
modelo_gerador.load_state_dict(torch.load("wgan_ruim.pth", weights_only=False))
# Out:
# <All keys matched successfully>

# %%
# Gera dados falsos com vetores latentes aleatórios e rótulos aleatórios
def gerar_aleatorio(modelo_gerador, device, z_dim=100, n_images=20, num_classes=10):
    modelo_gerador.eval()  # Modo de avaliação (desativa dropout, batchnorm, etc.)

    # Gera vetores de ruído aleatórios
    z = torch.randn((n_images, z_dim), device=device)

    # Gera rótulos inteiros aleatórios e converte para one-hot
    rotulos_aleatorios = torch.randint(0, num_classes, (n_images,), device=device)
    rotulos_aleatorios_one_hot = F.one_hot(rotulos_aleatorios, num_classes=num_classes).float()

    # Desativa o cálculo de gradientes
    with torch.no_grad():
        # Gera dados falsos passando (z, rotulos_one_hot) para o gerador condicional
        dados_falsos = modelo_gerador(z, rotulos_aleatorios_one_hot)
        dados_falsos = dados_falsos.detach().cpu().numpy()

    return dados_falsos, rotulos_aleatorios

# %%
# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, rotulos, n_cols=7):
    classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, (img, c) in enumerate(zip(imagens, rotulos)):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.title(classes[c.item()])
        plt.axis("off")
    plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=1.0)
    plt.show()

# %%
imagens, rotulos = gerar_aleatorio(
    modelo_gerador,   # gerador condicional
    device,           # dispositivo: 'cpu' ou 'cuda'
    z_dim=z_dim,      # dimensão do vetor latente
    n_images=28,      # número de imagens que desejamos gerar
    num_classes=10    # número de classes do conjunto de dados
)

# Chama a função para plotar as imagens em grade
plot_multiple_images(imagens, rotulos, n_cols=7)

# %%
# Gera n imagens para uma única classe (mantendo o rótulo fixo e variando o ruído)
def gerar_imagens_por_classe(modelo_gerador, device, classe_especifica, n_images=20, z_dim=100, num_classes=10):
    modelo_gerador.eval()  # Modo de avaliação

    # Vetores de ruído aleatórios
    z = torch.randn((n_images, z_dim), device=device)

    # Rótulo fixo
    rotulos = torch.full((n_images,), classe_especifica, device=device, dtype=torch.long)

    # Converte para one-hot
    rotulos_one_hot = F.one_hot(rotulos, num_classes=num_classes).float()

    # Gera as imagens com o gerador condicional
    with torch.no_grad():
        imagens_geradas = modelo_gerador(z, rotulos_one_hot)
        imagens_geradas = imagens_geradas.detach().cpu().numpy()

    return imagens_geradas, rotulos

# %%
# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, n_cols=7):
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, img in enumerate(imagens):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=1.0)
    plt.show()

# %%
imagens, rotulos = gerar_imagens_por_classe(
    modelo_gerador,
    device,
    classe_especifica=9,
    n_images=28,
    z_dim=z_dim,
    num_classes=10
)

plot_multiple_images(imagens, n_cols=7)

# %% [markdown]
# # Evolução das saídas do gerador para um vetor latente fixo durante o treinamento

# %%
# Lista com imagens 8x8
imagens = evolução_dado_falso

# Cria subplots (1 linha, -1 colunas)
fig, axes = plt.subplots(1, len(evolução_dado_falso), figsize=(15, 2))

# Itera por cada subplot e mostra a imagem
for ax, img in zip(axes, imagens):
    ax.imshow(img, cmap='gray')    # 1 = preto, 0 = branco
    ax.axis('off')                 # Remove ticks dos eixos

# ajusta o espaçamento entre subplots
plt.subplots_adjust(wspace=0.1)  # aumente para um maior espaçamento entre as imagens

plt.show()

# %%
def interp_z_fixo(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_1=0,
    classe_2=9,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera um vetor de ruído fixo (z) com dimensão z_dim
    z_fix = torch.randn((1, z_dim), device=device)

    # Cria os vetores one-hot correspondentes às classes iniciais e finais
    c1 = F.one_hot(torch.tensor([classe_1], device=device), num_classes).float()
    c2 = F.one_hot(torch.tensor([classe_2], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Expande os rótulos iniciais e finais para steps linhas
    c1_b = c1.expand(steps, -1)
    c2_b = c2.expand(steps, -1)

    # Interpola linearmente entre c1 e c2 ao longo de steps
    c_seq = torch.lerp(c1_b, c2_b, alphas.view(-1, 1))      # lerp(a,b,alpha) = (1 - alpha) * a + alpha * b

    # Repete o mesmo vetor z_fix para todos os steps
    z_batch = z_fix.expand(steps, -1)

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_batch, c_seq)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return


interp_z_fixo(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_1=2,         # classe 1
    classe_2=7,         # classe 2
    steps=15,           # número de passos da interpolação
    seed=5              # semente para reprodutibilidade
)

# %%
def interp_c_fixo(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_fixa=0,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera dois vetores de ruído aleatórios (z1 e z2), que serão os pontos extremos da interpolação
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    # Cria o vetor one-hot correspondente ao rótulo fixo
    c_fix = F.one_hot(torch.tensor([classe_fixa], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Expande os vetores z1 e z2 para steps linhas
    z1_b = z1.expand(steps, -1)
    z2_b = z2.expand(steps, -1)

    # Interpola linearmente entre z1 e z2 ao longo de steps: (1 - alpha) * z1_b + alpha * z2_b
    z_seq = torch.lerp(z1_b, z2_b, alphas.view(-1, 1))

    # Repete o mesmo rótulo fixo para todos os steps
    c_batch = c_fix.expand(steps, -1)

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_seq, c_batch)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return

interp_c_fixo(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_fixa=1,      # rótulo fixo escolhido
    steps=15,           # número de passos da interpolação
    seed=0              # semente para reprodutibilidade
)

# %%
def interp_z_e_c(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_1=0,
    classe_2=9,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera dois vetores de ruído aleatórios (z1 e z2), que serão os pontos extremos da interpolação
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    # Cria os vetores one-hot correspondentes às classes inicial e final
    c1 = F.one_hot(torch.tensor([classe_1], device=device), num_classes).float()
    c2 = F.one_hot(torch.tensor([classe_2], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Interpola linearmente entre z1 e z2 ao longo de steps: (1 - alpha) * z1_b + alpha * z2_b
    z1_b = z1.expand(steps, -1)
    z2_b = z2.expand(steps, -1)
    z_seq = torch.lerp(z1_b, z2_b, alphas.view(-1, 1))

    # Interpola linearmente entre c1 e c2 ao longo de steps (rótulos suaves): (1 - alpha) * c1_b + alpha * c2_b
    c1_b = c1.expand(steps, -1)
    c2_b = c2.expand(steps, -1)
    c_seq = torch.lerp(c1_b, c2_b, alphas.view(-1, 1))

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_seq, c_seq)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return

interp_z_e_c(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_1=2,         # classe inicial
    classe_2=7,         # classe final
    steps=15,           # número de passos da interpolação
    seed=1              # semente para reprodutibilidade
)

# %%
def variar_classe_fixa_z(gerador, device, z_dim=100, num_classes=10):
    # Gera um único vetor de ruído aleatório e o repete para todas as classes
    # Assim, apenas o rótulo varia enquanto o ruído (z) permanece fixo
    z = torch.randn((1, z_dim), device=device).repeat(num_classes, 1)

    # Cria um vetor com todas as classes (0 a num_classes-1)
    classes = torch.arange(0, num_classes, device=device)

    # Converte cada classe para representação one-hot
    rotulos_one_hot = F.one_hot(classes, num_classes=num_classes).float()

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imagens = gerador(z, rotulos_one_hot).cpu().numpy()

    # Lista de nomes correspondentes às classes do FashionMNIST
    nomes_classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
                     "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

    # Define o layout da grade para visualização
    n_cols = 5
    n_rows = (num_classes - 1) // n_cols + 1
    plt.figure(figsize=(n_cols * 2, n_rows * 2))

    # Plota cada imagem correspondente ao rótulo fixo de z
    for i, (img, nome) in enumerate(zip(imagens, nomes_classes)):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.title(nome, fontsize=8)
        plt.axis("off")

    # Ajusta espaçamentos da figura
    plt.tight_layout()
    plt.show()


variar_classe_fixa_z(modelo_gerador, device, z_dim=z_dim)

# %% [markdown]
# # Tarefa:
#
# 1. Implementar uma WCGAN condicional e treinar o modelo com o conjunto de dados Fashion MNIST.
#
# 2. Interpolar entre vetores de ruído e mostrar as imagens intermediárias considerando:
#
#     a. z fixo e interpolacão linear entre classes [c1, c2].
#
#     b. classe c fixa e interpolaćão linear entre [z1, z2].
#
#     c. interpolaćão linear entre [z1, z2] e [c1, c2].
#
# 3. Fixe o vetor de ruído e altere apenas o rótulo para observar como a imagem muda.
#
# **Entregáveis**:
# 1. Notebook `.ipynb`.
# 2. Relatório `.pdf`:
#
#     - Reporte e comente os resultados no relatório.
#
#     - Incluir imagens geradas.
