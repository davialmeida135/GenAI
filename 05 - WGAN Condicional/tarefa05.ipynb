# %% [markdown]
# Código adaptado de:
#
# [1] David Foster, Generative Deep Learning: Teaching Machines to Paint, Write, Compose, and Play, Second Edition, O'Reilly, 2023.
#
# [2] Sayak Paul, Conditional GAN tutorial, disponível no site do Keras [(link)](https://keras.io/examples/generative/conditional_gan/).
#
# [3] Aurélien Géron, Hands-On Machine Learning with Scikit-Learn: Concepts, Tools and Techniques to Build Intelligent Systems, Keras & tensorFlow, Third Edition, O'Reilly, 2023.

# %% [markdown]
# # Importações

# %%
import torch                                # Importa a biblioteca principal do PyTorch, usada para computação com tensores
from torch import nn                        # Importa o módulo 'nn' do PyTorch, utilizado para criar e treinar redes neurais
from torch.utils.data import DataLoader     # Importa o DataLoader do PyTorch, que facilita o carregamento de dados em mini-lotes (batches).
import torch.nn.functional as F             # Importa funções comuns de ativação e perda do PyTorch, usadas fora do módulo nn.Module (ex.: ReLU, cross_entropy, etc.)
from torchvision import datasets            # Importa o módulo de conjuntos de dados do torchvision, que fornece acesso a conjuntos de dados populares como MNIST, CIFAR, etc. para visão computacional
from torchvision import transforms          # Importa o módulo de transforms do torchvision, usado para pré-processar imagens (conversão em tensor, normalização, etc.).
from torchinfo import summary               # Importa a função summary da biblioteca torchinfo, usada para exibir a arquitetura do modelo
import numpy as np                          # Importa a biblioteca NumPy, usada para operações numéricas eficientes com arrays e matrizes.
import matplotlib.pyplot as plt             # Importa o módulo de visualização matplotlib para gerar gráficos.
from IPython.display import Image           # Importa a classe Image do IPython, usada para exibir imagens diretamente dentro de notebooks.
import gdown                                # Importa utilitário para baixar arquivos do Google Drive via link público
import os                                   # Importa o módulo padrão do Python para interagir com o sistema operacional (ex.: criar pastas, manipular caminhos de arquivos).
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE" # Ajusta a variável de ambiente para evitar erros ao carregar múltiplas bibliotecas MKL

# %%
# Para figuras geradas pelo matplotlib serem exibidas diretamente no notebook
# %matplotlib inline

# %% [markdown]
# # Baixar e carregar os dados

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x * 2.0 - 1.0),
])

# Baixa os dados de treinamento a partir de conjuntos de dados públicos
training_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=True,              # Indica que este é o conjunto de dados de treinamento
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# Baixa os dados de teste a partir de conjuntos de dados públicos
test_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=False,             # Indica que este é o conjunto de dados de teste
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# %%
# Lista com os nomes das classes do conjunto de dados Fashion MNIST, na mesma ordem dos índices
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Dicionário para armazenar um exemplo por classe
examples = {}

# Itera sobre o dataset até obter um exemplo de cada classe
for img, label in training_data:
    if label not in examples:
        examples[label] = img.squeeze()  # remove o canal extra (1, 28, 28) -> (28, 28)
    if len(examples) == 10:
        break

# Plota os exemplos
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(examples[i], cmap="gray")
    plt.title(classes[i])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
batch_size = 64                                                      # Define o tamanho do lote, ou seja, quantas amostras serão processadas por vez
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True, drop_last=True)  # Cria o DataLoader para o conjunto de treinamento
test_dataloader = DataLoader(test_data, batch_size=batch_size)       # Cria o DataLoader para o conjunto de teste

# Itera sobre o DataLoader de teste para visualizar as formas dos dados
for X, y in test_dataloader:
    # Exibe a forma e o tipo do tensor de imagens
    # N = tamanho do lote, C = canais (1 para imagens em tons de cinza), H = altura, W = largura
    print(f"Forma de X [N, C, H, W]: {X.shape}, Tipo de dados em X: {X.dtype}")

    # Exibe a forma e o tipo dos rótulos (labels)
    print(f"Forma de y [N, ] : {y.shape}, Tipo de dados em y: {y.dtype}")

    break  # Encerra o loop após a primeira iteração, apenas para inspeção dos dados
# Out:
# Forma de X [N, C, H, W]: torch.Size([64, 1, 28, 28]), Tipo de dados em X: torch.float32
# Forma de y [N, ] : torch.Size([64]), Tipo de dados em y: torch.int64

# %% [markdown]
# # Redes Neurais

# %% [markdown]
# ## Gerador

# %%
class Gerador(nn.Module):
    def __init__(self, z_dim=100, num_classes=10):
        super().__init__()

        # Definimos a rede sequencial do gerador
        self.rede_neural = nn.Sequential(

            # Camada totalmente conectada                                                       # Entrada: (lote, z_dim + num_classes)  (vetor de ruído z concatenado com rótulo com codificação one-hot)
            nn.Linear(z_dim + num_classes, 7 * 7 * 128),

            # Transforma o vetor 1D em um tensor 3D para convoluções
            nn.Unflatten(1, (128, 7, 7)),

            # Normalização em lote
            nn.BatchNorm2d(128),

            # Primeira convolução transposta
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.ReLU(),  # Função de ativação ReLU

            # Normalização em lote
            nn.BatchNorm2d(64),

            # Segunda convolução transposta
            nn.ConvTranspose2d(64, 1, kernel_size=5, stride=2, padding=2, output_padding=1),

            # Função de ativação final Tanh: valores de saída entre [-1, 1]
            nn.Tanh()
        )

    def forward(self, z, rotulo_one_hot):
        # Concatena o vetor de ruído com o vetor de rótulo one-hot:
        entrada = torch.cat([z, rotulo_one_hot], dim=1)  # Entrada: (lote, z_dim + num_classes)
        return self.rede_neural(entrada)                 # Saída: (lote, 1, 28, 28)

# %% [markdown]
# ## Discriminador

# %%
class Discriminador(nn.Module):
    def __init__(self, num_classes=10, tam_img=28):
        super().__init__()

        # Número de classes
        self.num_classes = num_classes

        # Tamanho da imagem
        self.tam_img = tam_img

        # Definição da rede convolucional sequencial
        self.rede_neural = nn.Sequential(

            # Primeira camada convolucional                                                                 # entrada: [lote, 1 + 10, 28, 28] (1 canal da imagem + canais do rótulo)
            nn.Conv2d(in_channels=1 + num_classes, out_channels=64, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(0.4),

            # Segunda camada convolucional
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(0.4),

            # Achatar o tensor 3D para um vetor 1D
            nn.Flatten(),

            # Camada totalmente conectada
            nn.Linear(7 * 7 * 128, 1),
        )


    def forward(self, imagem, rotulos_one_hot):
        # imagem: (B, 1, H, W) | rotulos_one_hot: (B, C)
        _, _, H, W = imagem.shape

        # (B, C, 1, 1) -> (B, C, H, W)  [expand cria uma view]
        # Cria um tensor do tamanho da imagem, preenchido com os valores do rótulo one-hot, onde cada canal corresponde a um rótulo
        mapa_rotulo = rotulos_one_hot[:, :, None, None].expand(-1, -1, H, W)

        # (B, 1+C, H, W)  [concatenar a imagem com o mapa de rótulo no eixo de canais]
        entrada = torch.cat((imagem, mapa_rotulo), dim=1)

        # Passar pela rede convolucional
        return self.rede_neural(entrada)

# %% [markdown]
# # Configurar Treinamento

# %%
def train_wgan_condicional(
    dataloader,
    gerador,
    discriminador,
    opt_gerador,
    opt_discriminador,
    device,
    epoch,
    z_dim,
    n_critic=5,
    clip_value=0.01,
    num_classes=10,
):

    gerador.train()
    discriminador.train()

    for batch_idx, (dados_reais, rotulos_reais) in enumerate(dataloader):
        batch_size = dados_reais.size(0)
        dados_reais = dados_reais.to(device)
        rotulos_reais = rotulos_reais.to(device)

        # Converte os rótulos reais para one-hot
        rotulos_reais_one_hot = F.one_hot(rotulos_reais, num_classes=num_classes).float()

        # Envia para o dispositivo (GPU/CPU)
        rotulos_reais_one_hot = rotulos_reais_one_hot.to(device)

        # ========================================
        # CRÍTICO (DISCRIMINADOR)
        # ========================================
        for _ in range(n_critic):

            # Gera ruído z
            z = torch.randn((batch_size, z_dim), device=device)

            # Gera dados falsos USANDO OS MESMOS RÓTULOS REAIS (matching label approach)
            dados_falsos = gerador(z, rotulos_reais_one_hot)

            # Avalia dados reais (imagem real + rótulo real)
            saida_reais = discriminador(dados_reais, rotulos_reais_one_hot)

            # Avalia dados falsos (imagem gerada + rótulo real)
            # detach() evita backprop no gerador nessa fase
            # FIXME Teste sem .detach()
            saida_falsos = discriminador(dados_falsos, rotulos_reais_one_hot)

            # Perda do discriminador: soma das perdas para dados reais e falsos
            perda_discriminador = saida_falsos.mean() - saida_reais.mean()

            # Otimiza o discriminador
            opt_discriminador.zero_grad()
            perda_discriminador.backward()
            opt_discriminador.step()

            # Clipping dos pesos do discriminador para satisfazer Lipschitz
            for p in discriminador.parameters():
                p.data.clamp_(-clip_value, clip_value)

        # ========================================
        # GERADOR
        # ========================================

        # Gera novo ruído z
        z = torch.randn((batch_size, z_dim), device=device)

        # Gera dados falsos novamente (com os rótulos reais do batch)
        dados_falsos = gerador(z, rotulos_reais_one_hot)

        # Faz o discriminador avaliar estes dados falsos
        saida_falsos = discriminador(dados_falsos, rotulos_reais_one_hot)

        # Perda do gerador: queremos que o discriminador ache que são reais
        perda_gerador = -saida_falsos.mean()

        # Otimiza o gerador
        opt_gerador.zero_grad()
        perda_gerador.backward()
        opt_gerador.step()

        # ========================================
        # LOG
        # ========================================
        if batch_idx % 100 == 0 or batch_idx == len(dataloader) - 1:
            print(f"[Época {epoch:03d}] [Lote {batch_idx:03d}/{len(dataloader)}] "
                  f"Perda D: {perda_discriminador.item():.4f} | "
                  f"Perda G: {perda_gerador.item():.4f}")
    
    return perda_discriminador.item(), perda_gerador.item()

# %%
# Define a função de gerar dados falsos de um vetor latente fixo
def gerar(gerador, device, z_dim=30, num_classes=10, c=0):
    gerador.eval()        # Coloca o modelo em modo de avaliação (desativa dropout, batchnorm, etc.)
    with torch.no_grad(): # Desativa o cálculo de gradientes para economizar memória e acelerar a execução
      z = torch.zeros((1, z_dim), device=device)
      c_tensor = torch.tensor([c], device=device)
      rotulo_one_hot = F.one_hot(c_tensor, num_classes=num_classes).float()
      dados_falsos = gerador(z, rotulo_one_hot).detach().cpu().numpy().reshape(28,28)
    return dados_falsos

# %% [markdown]
# # Executar Treinamento

# %%
# Inicializa os gerador
z_dim = 100
modelo_gerador = Gerador(z_dim)
# Imprime a arquitetura do modelo
print(modelo_gerador)
summary(modelo_gerador, input_size=[(1, 100), (1, 10)])
# Out:
# Gerador(
#   (rede_neural): Sequential(
#     (0): Linear(in_features=110, out_features=6272, bias=True)
#     (1): Unflatten(dim=1, unflattened_size=(128, 7, 7))
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ConvTranspose2d(64, 1, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (7): Tanh()
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Gerador                                  [1, 1, 28, 28]            --
# ├─Sequential: 1-1                        [1, 1, 28, 28]            --
# │    └─Linear: 2-1                       [1, 6272]                 696,192
# │    └─Unflatten: 2-2                    [1, 128, 7, 7]            --
# │    └─BatchNorm2d: 2-3                  [1, 128, 7, 7]            256
# │    └─ConvTranspose2d: 2-4              [1, 64, 14, 14]           204,864
# │    └─ReLU: 2-5                         [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-6                  [1, 64, 14, 14]           128
# │    └─ConvTranspose2d: 2-7              [1, 1, 28, 28]            1,601
# │    └─Tanh: 2-8                         [1, 1, 28, 28]            --
# ==========================================================================================
# Total params: 903,041
# Trainable params: 903,041
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 42.11
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 3.61
# Estimated Total Size (MB): 3.92
# ==========================================================================================

# %%
# Inicializa os discriminador
modelo_discriminador = Discriminador()
# Imprime a arquitetura do modelo
print(modelo_discriminador)
summary(modelo_discriminador, input_size=[(1, 1, 28, 28), (1, 10)])
# Out:
# Discriminador(
#   (rede_neural): Sequential(
#     (0): Conv2d(11, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6272, out_features=1, bias=True)
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Discriminador                            [1, 1]                    --
# ├─Sequential: 1-1                        [1, 1]                    --
# │    └─Conv2d: 2-1                       [1, 64, 14, 14]           17,664
# │    └─LeakyReLU: 2-2                    [1, 64, 14, 14]           --
# │    └─Dropout: 2-3                      [1, 64, 14, 14]           --
# │    └─Conv2d: 2-4                       [1, 128, 7, 7]            204,928
# │    └─LeakyReLU: 2-5                    [1, 128, 7, 7]            --
# │    └─Dropout: 2-6                      [1, 128, 7, 7]            --
# │    └─Flatten: 2-7                      [1, 6272]                 --
# │    └─Linear: 2-8                       [1, 1]                    6,273
# ==========================================================================================
# Total params: 228,865
# Trainable params: 228,865
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 13.51
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.15
# Params size (MB): 0.92
# Estimated Total Size (MB): 1.07
# ==========================================================================================

# %%
# Tenta usar GPU se disponível
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
modelo_gerador.to(device)
modelo_discriminador.to(device)

# Exibe qual dispositivo está sendo utilizado
print(f"Usando {device}.")
# Out:
# Usando cuda.

# %%
# Otimizadores
lr_gerador = 1e-5         # taxa de aprendizagem do gerador
lr_discriminador = 1e-5   # taxa de aprendizagem do discriminador
optimizador_gerador = torch.optim.RMSprop(modelo_gerador.parameters(), lr=lr_gerador)
optimizador_discriminador = torch.optim.RMSprop(modelo_discriminador.parameters(), lr=lr_discriminador)

# %%
num_epochs = 50  # Define o número total de épocas (iterações completas sobre o conjunto de dados de treinamento)
evolução_dado_falso = []
hist_loss_discriminador = []
hist_loss_gerador = []
for epoca in range(1, num_epochs + 1):
    loss_discriminador, loss_gerador = train_wgan_condicional(
        dataloader=train_dataloader,
        gerador=modelo_gerador,
        discriminador=modelo_discriminador,
        opt_gerador=optimizador_gerador,
        opt_discriminador=optimizador_discriminador,
        device=device,
        epoch=epoca,
        z_dim=z_dim,
        n_critic=5,
        clip_value=0.01,
        num_classes=10
    )
    hist_loss_discriminador.append(loss_discriminador)
    hist_loss_gerador.append(loss_gerador)
    if epoca % 5 == 0 or epoca == 1:
      dados_falsos = gerar(gerador=modelo_gerador, device=device, z_dim=z_dim, num_classes=10, c=0)
      plt.imshow(dados_falsos, cmap="gray")
      plt.axis("off")
      plt.title(f"Época {epoca}")
      plt.imsave(f"dados_falsos_epoca_{epoca}.png", dados_falsos, cmap="gray")
      evolução_dado_falso.append(dados_falsos)

torch.save(modelo_gerador.state_dict(), "gerador_wgan_condicional_05.pth")
print("Fim!")  # Exibe mensagem final indicando que o treinamento terminou
# Out:
# [Época 001] [Lote 000/937] Perda D: -0.0105 | Perda G: -0.0027
# [Época 001] [Lote 100/937] Perda D: -6.7845 | Perda G: 2.9209
# [Época 001] [Lote 200/937] Perda D: -20.4584 | Perda G: 10.7611
# [Época 001] [Lote 300/937] Perda D: -32.7934 | Perda G: 17.8624
# [Época 001] [Lote 400/937] Perda D: -33.2108 | Perda G: 20.6643
# [Época 001] [Lote 500/937] Perda D: -27.1415 | Perda G: 15.6744
# [Época 001] [Lote 600/937] Perda D: -26.9336 | Perda G: 11.4361
# [Época 001] [Lote 700/937] Perda D: -23.1394 | Perda G: 5.4095
# [Época 001] [Lote 800/937] Perda D: -22.4002 | Perda G: -0.4044
# [Época 001] [Lote 900/937] Perda D: -14.9457 | Perda G: -5.3445
# [Época 001] [Lote 936/937] Perda D: -18.0962 | Perda G: -8.8024
# [Época 002] [Lote 000/937] Perda D: -25.1268 | Perda G: -8.4009
# [Época 002] [Lote 100/937] Perda D: -15.7565 | Perda G: -10.9729
# [Época 002] [Lote 200/937] Perda D: -15.8152 | Perda G: -12.4355
# [Época 002] [Lote 300/937] Perda D: -14.6073 | Perda G: -21.3500
# [Época 002] [Lote 400/937] Perda D: -7.3604 | Perda G: -20.0480
# [Época 002] [Lote 500/937] Perda D: -9.1503 | Perda G: -26.9901
# [Época 002] [Lote 600/937] Perda D: -10.1576 | Perda G: -23.2363
# [Época 002] [Lote 700/937] Perda D: -6.9182 | Perda G: -26.9516
# [Época 002] [Lote 800/937] Perda D: -8.2638 | Perda G: -28.3514
# [Época 002] [Lote 900/937] Perda D: -4.0895 | Perda G: -27.1412
# [Época 002] [Lote 936/937] Perda D: -4.7266 | Perda G: -27.4604
# [Época 003] [Lote 000/937] Perda D: -7.7866 | Perda G: -27.4178
# [Época 003] [Lote 100/937] Perda D: -4.7612 | Perda G: -24.0184
# [Época 003] [Lote 200/937] Perda D: -3.6685 | Perda G: -20.4416
# [Época 003] [Lote 300/937] Perda D: -3.2748 | Perda G: -16.1853
# [Época 003] [Lote 400/937] Perda D: -2.5850 | Perda G: -12.5960
# [Época 003] [Lote 500/937] Perda D: -2.1573 | Perda G: -11.7382
# [Época 003] [Lote 600/937] Perda D: -1.6041 | Perda G: -10.5361
# [Época 003] [Lote 700/937] Perda D: -1.1477 | Perda G: -10.9647
# [Época 003] [Lote 800/937] Perda D: -0.7437 | Perda G: -10.3858
# [Época 003] [Lote 900/937] Perda D: -2.3489 | Perda G: -6.3622
# [Época 003] [Lote 936/937] Perda D: -2.4597 | Perda G: -5.7927
# [Época 004] [Lote 000/937] Perda D: -0.9081 | Perda G: -7.7381
# [Época 004] [Lote 100/937] Perda D: -1.9824 | Perda G: -6.1942
# [Época 004] [Lote 200/937] Perda D: -0.8349 | Perda G: -5.8202
# [Época 004] [Lote 300/937] Perda D: -1.8132 | Perda G: -4.0766
# [Época 004] [Lote 400/937] Perda D: -2.3589 | Perda G: -2.0130
# [Época 004] [Lote 500/937] Perda D: -3.2188 | Perda G: 1.9292
# [Época 004] [Lote 600/937] Perda D: -6.0322 | Perda G: 5.1046
# [Época 004] [Lote 700/937] Perda D: -5.1157 | Perda G: 10.8661
# [Época 004] [Lote 800/937] Perda D: -3.7862 | Perda G: 13.7442
# [Época 004] [Lote 900/937] Perda D: -3.0545 | Perda G: 12.7987
# [Época 004] [Lote 936/937] Perda D: -2.1650 | Perda G: 12.0334
# [Época 005] [Lote 000/937] Perda D: -4.3483 | Perda G: 12.1660
# [Época 005] [Lote 100/937] Perda D: -2.4822 | Perda G: 9.2796
# [Época 005] [Lote 200/937] Perda D: -4.3665 | Perda G: 8.9326
# [Época 005] [Lote 300/937] Perda D: -3.7177 | Perda G: 9.9235
# [Época 005] [Lote 400/937] Perda D: -3.4493 | Perda G: 10.4105
# [Época 005] [Lote 500/937] Perda D: -3.8055 | Perda G: 9.9805
# [Época 005] [Lote 600/937] Perda D: -1.9012 | Perda G: 7.9720
# [Época 005] [Lote 700/937] Perda D: -1.7931 | Perda G: 6.4716
# [Época 005] [Lote 800/937] Perda D: -1.7425 | Perda G: 2.8621
# [Época 005] [Lote 900/937] Perda D: -1.5539 | Perda G: 1.4643
# [Época 005] [Lote 936/937] Perda D: -2.2018 | Perda G: 1.1789
# [Época 006] [Lote 000/937] Perda D: -1.4358 | Perda G: 1.1938
# [Época 006] [Lote 100/937] Perda D: -1.8654 | Perda G: -0.6270
# [Época 006] [Lote 200/937] Perda D: -1.9649 | Perda G: -1.4818
# [Época 006] [Lote 300/937] Perda D: -1.7930 | Perda G: -4.4181
# [Época 006] [Lote 400/937] Perda D: -0.9212 | Perda G: -6.3715
# [Época 006] [Lote 500/937] Perda D: -0.5980 | Perda G: -10.0085
# [Época 006] [Lote 600/937] Perda D: -0.8507 | Perda G: -11.3304
# [Época 006] [Lote 700/937] Perda D: -0.6889 | Perda G: -12.0408
# [Época 006] [Lote 800/937] Perda D: -0.7939 | Perda G: -11.3747
# [Época 006] [Lote 900/937] Perda D: -1.3839 | Perda G: -10.8992
# [Época 006] [Lote 936/937] Perda D: -0.3000 | Perda G: -11.9422
# [Época 007] [Lote 000/937] Perda D: -0.7519 | Perda G: -11.2942
# [Época 007] [Lote 100/937] Perda D: -0.8703 | Perda G: -11.2097
# [Época 007] [Lote 200/937] Perda D: -0.3462 | Perda G: -11.9356
# [Época 007] [Lote 300/937] Perda D: 0.4217 | Perda G: -11.2818
# [Época 007] [Lote 400/937] Perda D: 0.3507 | Perda G: -10.3119
# [Época 007] [Lote 500/937] Perda D: -0.4690 | Perda G: -9.4703
# [Época 007] [Lote 600/937] Perda D: -0.2691 | Perda G: -7.3265
# [Época 007] [Lote 700/937] Perda D: -0.5416 | Perda G: -6.0085
# [Época 007] [Lote 800/937] Perda D: -0.6684 | Perda G: -4.7070
# [Época 007] [Lote 900/937] Perda D: -0.5242 | Perda G: -4.1805
# [Época 007] [Lote 936/937] Perda D: -0.7025 | Perda G: -4.0161
# [Época 008] [Lote 000/937] Perda D: -0.3820 | Perda G: -3.6418
# [Época 008] [Lote 100/937] Perda D: -0.4376 | Perda G: -3.8865
# [Época 008] [Lote 200/937] Perda D: -0.4456 | Perda G: -4.9053
# [Época 008] [Lote 300/937] Perda D: -0.5415 | Perda G: -4.5811
# [Época 008] [Lote 400/937] Perda D: -0.2131 | Perda G: -5.4662
# [Época 008] [Lote 500/937] Perda D: -0.3208 | Perda G: -5.9510
# [Época 008] [Lote 600/937] Perda D: -0.3068 | Perda G: -4.4865
# [Época 008] [Lote 700/937] Perda D: -0.2364 | Perda G: -4.6310
# [Época 008] [Lote 800/937] Perda D: -0.1957 | Perda G: -4.7606
# [Época 008] [Lote 900/937] Perda D: -0.2518 | Perda G: -4.1829
# [Época 008] [Lote 936/937] Perda D: -0.2265 | Perda G: -5.1677
# [Época 009] [Lote 000/937] Perda D: -0.4018 | Perda G: -4.4600
# [Época 009] [Lote 100/937] Perda D: -0.5021 | Perda G: -4.7005
# [Época 009] [Lote 200/937] Perda D: -0.2712 | Perda G: -4.3155
# [Época 009] [Lote 300/937] Perda D: -0.2883 | Perda G: -4.7550
# [Época 009] [Lote 400/937] Perda D: -0.3519 | Perda G: -4.3901
# [Época 009] [Lote 500/937] Perda D: -0.3017 | Perda G: -4.4750
# [Época 009] [Lote 600/937] Perda D: -0.2751 | Perda G: -5.6634
# [Época 009] [Lote 700/937] Perda D: -0.2561 | Perda G: -5.0569
# [Época 009] [Lote 800/937] Perda D: -0.3120 | Perda G: -4.5097
# [Época 009] [Lote 900/937] Perda D: -0.1693 | Perda G: -4.1764
# [Época 009] [Lote 936/937] Perda D: -0.0623 | Perda G: -4.4620
# [Época 010] [Lote 000/937] Perda D: -0.3106 | Perda G: -4.2961
# [Época 010] [Lote 100/937] Perda D: -0.3098 | Perda G: -5.2890
# [Época 010] [Lote 200/937] Perda D: -0.0749 | Perda G: -5.3995
# [Época 010] [Lote 300/937] Perda D: -0.2217 | Perda G: -5.3261
# [Época 010] [Lote 400/937] Perda D: -0.2406 | Perda G: -5.5835
# [Época 010] [Lote 500/937] Perda D: -0.3143 | Perda G: -5.2684
# [Época 010] [Lote 600/937] Perda D: -0.0782 | Perda G: -3.4933
# [Época 010] [Lote 700/937] Perda D: -0.1639 | Perda G: -5.0450
# [Época 010] [Lote 800/937] Perda D: -0.3211 | Perda G: -4.3515
# [Época 010] [Lote 900/937] Perda D: -0.2690 | Perda G: -3.5305
# [Época 010] [Lote 936/937] Perda D: -0.1931 | Perda G: -3.9399
# [Época 011] [Lote 000/937] Perda D: -0.3440 | Perda G: -5.6442
# [Época 011] [Lote 100/937] Perda D: -0.1912 | Perda G: -4.6325
# [Época 011] [Lote 200/937] Perda D: -0.1120 | Perda G: -4.0390
# [Época 011] [Lote 300/937] Perda D: -0.1616 | Perda G: -3.2606
# [Época 011] [Lote 400/937] Perda D: -0.2614 | Perda G: -3.7317
# [Época 011] [Lote 500/937] Perda D: -0.2315 | Perda G: -2.8265
# [Época 011] [Lote 600/937] Perda D: -0.2613 | Perda G: -3.5251
# [Época 011] [Lote 700/937] Perda D: -0.0735 | Perda G: -2.8187
# [Época 011] [Lote 800/937] Perda D: -0.2185 | Perda G: -3.8588
# [Época 011] [Lote 900/937] Perda D: -0.1335 | Perda G: -2.6148
# [Época 011] [Lote 936/937] Perda D: -0.1632 | Perda G: -2.0616
# [Época 012] [Lote 000/937] Perda D: -0.0795 | Perda G: -2.8484
# [Época 012] [Lote 100/937] Perda D: -0.2181 | Perda G: -3.5316
# [Época 012] [Lote 200/937] Perda D: -0.1087 | Perda G: -3.0522
# [Época 012] [Lote 300/937] Perda D: -0.1925 | Perda G: -3.5928
# [Época 012] [Lote 400/937] Perda D: -0.1469 | Perda G: -3.8160
# [Época 012] [Lote 500/937] Perda D: -0.0588 | Perda G: -3.4236
# [Época 012] [Lote 600/937] Perda D: -0.1597 | Perda G: -4.1463
# [Época 012] [Lote 700/937] Perda D: -0.1520 | Perda G: -4.7114
# [Época 012] [Lote 800/937] Perda D: -0.1827 | Perda G: -4.3810
# [Época 012] [Lote 900/937] Perda D: -0.2660 | Perda G: -4.1894
# [Época 012] [Lote 936/937] Perda D: -0.2011 | Perda G: -3.2404
# [Época 013] [Lote 000/937] Perda D: -0.2889 | Perda G: -3.1886
# [Época 013] [Lote 100/937] Perda D: -0.1211 | Perda G: -3.3723
# [Época 013] [Lote 200/937] Perda D: -0.1579 | Perda G: -2.7820
# [Época 013] [Lote 300/937] Perda D: -0.4026 | Perda G: -3.7689
# [Época 013] [Lote 400/937] Perda D: -0.3260 | Perda G: -4.2717
# [Época 013] [Lote 500/937] Perda D: -0.2294 | Perda G: -4.0922
# [Época 013] [Lote 600/937] Perda D: -0.2469 | Perda G: -4.5180
# [Época 013] [Lote 700/937] Perda D: -0.2472 | Perda G: -3.3488
# [Época 013] [Lote 800/937] Perda D: -0.3339 | Perda G: -4.3011
# [Época 013] [Lote 900/937] Perda D: -0.2441 | Perda G: -4.2493
# [Época 013] [Lote 936/937] Perda D: -0.2347 | Perda G: -4.9709
# [Época 014] [Lote 000/937] Perda D: -0.2414 | Perda G: -4.4358
# [Época 014] [Lote 100/937] Perda D: -0.4205 | Perda G: -4.1261
# [Época 014] [Lote 200/937] Perda D: -0.3154 | Perda G: -4.8384
# [Época 014] [Lote 300/937] Perda D: -0.2707 | Perda G: -4.4106
# [Época 014] [Lote 400/937] Perda D: -0.4136 | Perda G: -5.1070
# [Época 014] [Lote 500/937] Perda D: -0.3208 | Perda G: -5.2893
# [Época 014] [Lote 600/937] Perda D: -0.2710 | Perda G: -4.8093
# [Época 014] [Lote 700/937] Perda D: -0.2966 | Perda G: -4.3831
# [Época 014] [Lote 800/937] Perda D: -0.3169 | Perda G: -7.0708
# [Época 014] [Lote 900/937] Perda D: -0.3883 | Perda G: -5.8404
# [Época 014] [Lote 936/937] Perda D: -0.3681 | Perda G: -6.9289
# [Época 015] [Lote 000/937] Perda D: -0.3245 | Perda G: -5.2419
# [Época 015] [Lote 100/937] Perda D: -0.3866 | Perda G: -5.5768
# [Época 015] [Lote 200/937] Perda D: -0.3542 | Perda G: -6.0513
# [Época 015] [Lote 300/937] Perda D: -0.3369 | Perda G: -6.4977
# [Época 015] [Lote 400/937] Perda D: -0.3234 | Perda G: -5.5135
# [Época 015] [Lote 500/937] Perda D: -0.3148 | Perda G: -5.6962
# [Época 015] [Lote 600/937] Perda D: -0.3420 | Perda G: -5.2684
# [Época 015] [Lote 700/937] Perda D: -0.3225 | Perda G: -5.9473
# [Época 015] [Lote 800/937] Perda D: -0.3235 | Perda G: -7.0685
# [Época 015] [Lote 900/937] Perda D: -0.4757 | Perda G: -5.2211
# [Época 015] [Lote 936/937] Perda D: -0.4347 | Perda G: -6.0059
# [Época 016] [Lote 000/937] Perda D: -0.4079 | Perda G: -4.2978
# [Época 016] [Lote 100/937] Perda D: -0.4220 | Perda G: -5.4585
# [Época 016] [Lote 200/937] Perda D: -0.3693 | Perda G: -5.4642
# [Época 016] [Lote 300/937] Perda D: -0.3958 | Perda G: -4.8014
# [Época 016] [Lote 400/937] Perda D: -0.6219 | Perda G: -5.6344
# [Época 016] [Lote 500/937] Perda D: -0.3306 | Perda G: -5.5907
# [Época 016] [Lote 600/937] Perda D: -0.4217 | Perda G: -5.6235
# [Época 016] [Lote 700/937] Perda D: -0.4874 | Perda G: -5.6467
# [Época 016] [Lote 800/937] Perda D: -0.3925 | Perda G: -6.2971
# [Época 016] [Lote 900/937] Perda D: -0.4312 | Perda G: -5.4409
# [Época 016] [Lote 936/937] Perda D: -0.5423 | Perda G: -5.9492
# [Época 017] [Lote 000/937] Perda D: -0.3373 | Perda G: -4.9798
# [Época 017] [Lote 100/937] Perda D: -0.4613 | Perda G: -8.0948
# [Época 017] [Lote 200/937] Perda D: -0.4833 | Perda G: -4.5994
# [Época 017] [Lote 300/937] Perda D: -0.4401 | Perda G: -4.9369
# [Época 017] [Lote 400/937] Perda D: -0.6451 | Perda G: -6.7810
# [Época 017] [Lote 500/937] Perda D: -0.5112 | Perda G: -5.7987
# [Época 017] [Lote 600/937] Perda D: -0.4472 | Perda G: -6.0911
# [Época 017] [Lote 700/937] Perda D: -0.5814 | Perda G: -6.6732
# [Época 017] [Lote 800/937] Perda D: -0.3882 | Perda G: -5.3546
# [Época 017] [Lote 900/937] Perda D: -0.4104 | Perda G: -7.9179
# [Época 017] [Lote 936/937] Perda D: -0.4831 | Perda G: -5.9315
# [Época 018] [Lote 000/937] Perda D: -0.4468 | Perda G: -7.0486
# [Época 018] [Lote 100/937] Perda D: -0.4652 | Perda G: -6.4490
# [Época 018] [Lote 200/937] Perda D: -0.3840 | Perda G: -5.7526
# [Época 018] [Lote 300/937] Perda D: -0.4666 | Perda G: -5.7638
# [Época 018] [Lote 400/937] Perda D: -0.4007 | Perda G: -5.1518
# [Época 018] [Lote 500/937] Perda D: -0.3717 | Perda G: -5.6746
# [Época 018] [Lote 600/937] Perda D: -0.4413 | Perda G: -6.7178
# [Época 018] [Lote 700/937] Perda D: -0.4823 | Perda G: -7.2832
# [Época 018] [Lote 800/937] Perda D: -0.4978 | Perda G: -4.3163
# [Época 018] [Lote 900/937] Perda D: -0.3788 | Perda G: -5.8805
# [Época 018] [Lote 936/937] Perda D: -0.5687 | Perda G: -7.9368
# [Época 019] [Lote 000/937] Perda D: -0.3663 | Perda G: -5.6277
# [Época 019] [Lote 100/937] Perda D: -0.5147 | Perda G: -5.7069
# [Época 019] [Lote 200/937] Perda D: -0.3246 | Perda G: -5.3600
# [Época 019] [Lote 300/937] Perda D: -0.3727 | Perda G: -6.5627
# [Época 019] [Lote 400/937] Perda D: -0.2764 | Perda G: -6.6739
# [Época 019] [Lote 500/937] Perda D: -0.3571 | Perda G: -7.3366
# [Época 019] [Lote 600/937] Perda D: -0.5119 | Perda G: -6.7320
# [Época 019] [Lote 700/937] Perda D: -0.3949 | Perda G: -6.6976
# [Época 019] [Lote 800/937] Perda D: -0.3998 | Perda G: -5.9559
# [Época 019] [Lote 900/937] Perda D: -0.3110 | Perda G: -5.5788
# [Época 019] [Lote 936/937] Perda D: -0.3124 | Perda G: -5.7970
# [Época 020] [Lote 000/937] Perda D: -0.4647 | Perda G: -6.3365
# [Época 020] [Lote 100/937] Perda D: -0.4242 | Perda G: -6.6517
# [Época 020] [Lote 200/937] Perda D: -0.4703 | Perda G: -6.0445
# [Época 020] [Lote 300/937] Perda D: -0.2854 | Perda G: -5.4135
# [Época 020] [Lote 400/937] Perda D: -0.3400 | Perda G: -6.7736
# [Época 020] [Lote 500/937] Perda D: -0.1445 | Perda G: -6.8384
# [Época 020] [Lote 600/937] Perda D: -0.2389 | Perda G: -6.3816
# [Época 020] [Lote 700/937] Perda D: -0.1561 | Perda G: -6.3103
# [Época 020] [Lote 800/937] Perda D: -0.3411 | Perda G: -5.3452
# [Época 020] [Lote 900/937] Perda D: -0.4333 | Perda G: -7.2019
# [Época 020] [Lote 936/937] Perda D: -0.3812 | Perda G: -6.2998
# [Época 021] [Lote 000/937] Perda D: -0.4534 | Perda G: -6.2435
# [Época 021] [Lote 100/937] Perda D: -0.3050 | Perda G: -6.8613
# [Época 021] [Lote 200/937] Perda D: -0.2131 | Perda G: -5.7999
# [Época 021] [Lote 300/937] Perda D: -0.4639 | Perda G: -5.7817
# [Época 021] [Lote 400/937] Perda D: -0.2911 | Perda G: -6.9935
# [Época 021] [Lote 500/937] Perda D: -0.2673 | Perda G: -5.7357
# [Época 021] [Lote 600/937] Perda D: -0.3193 | Perda G: -6.2474
# [Época 021] [Lote 700/937] Perda D: -0.2690 | Perda G: -7.0023
# [Época 021] [Lote 800/937] Perda D: -0.3526 | Perda G: -6.4016
# [Época 021] [Lote 900/937] Perda D: -0.2799 | Perda G: -7.0369
# [Época 021] [Lote 936/937] Perda D: -0.0996 | Perda G: -6.5427
# [Época 022] [Lote 000/937] Perda D: -0.3338 | Perda G: -6.4746
# [Época 022] [Lote 100/937] Perda D: -0.3134 | Perda G: -7.2234
# [Época 022] [Lote 200/937] Perda D: -0.3054 | Perda G: -6.5898
# [Época 022] [Lote 300/937] Perda D: -0.3569 | Perda G: -5.6540
# [Época 022] [Lote 400/937] Perda D: -0.2843 | Perda G: -6.6217
# [Época 022] [Lote 500/937] Perda D: -0.1309 | Perda G: -8.1266
# [Época 022] [Lote 600/937] Perda D: -0.2481 | Perda G: -6.7434
# [Época 022] [Lote 700/937] Perda D: -0.1564 | Perda G: -6.5046
# [Época 022] [Lote 800/937] Perda D: -0.4197 | Perda G: -7.0212
# [Época 022] [Lote 900/937] Perda D: -0.1849 | Perda G: -7.2551
# [Época 022] [Lote 936/937] Perda D: -0.1562 | Perda G: -5.6474
# [Época 023] [Lote 000/937] Perda D: -0.3664 | Perda G: -6.7309
# [Época 023] [Lote 100/937] Perda D: -0.2318 | Perda G: -6.1776
# [Época 023] [Lote 200/937] Perda D: -0.2557 | Perda G: -7.9323
# [Época 023] [Lote 300/937] Perda D: -0.3363 | Perda G: -6.9478
# [Época 023] [Lote 400/937] Perda D: -0.2474 | Perda G: -5.8180
# [Época 023] [Lote 500/937] Perda D: -0.1945 | Perda G: -7.1429
# [Época 023] [Lote 600/937] Perda D: -0.4703 | Perda G: -6.6736
# [Época 023] [Lote 700/937] Perda D: -0.3428 | Perda G: -7.7047
# [Época 023] [Lote 800/937] Perda D: -0.4059 | Perda G: -6.8648
# [Época 023] [Lote 900/937] Perda D: -0.2541 | Perda G: -6.5142
# [Época 023] [Lote 936/937] Perda D: -0.1573 | Perda G: -8.0386
# [Época 024] [Lote 000/937] Perda D: -0.1871 | Perda G: -7.1377
# [Época 024] [Lote 100/937] Perda D: -0.2762 | Perda G: -7.9907
# [Época 024] [Lote 200/937] Perda D: -0.2463 | Perda G: -8.2644
# [Época 024] [Lote 300/937] Perda D: -0.1655 | Perda G: -7.9623
# [Época 024] [Lote 400/937] Perda D: -0.0836 | Perda G: -6.0223
# [Época 024] [Lote 500/937] Perda D: -0.3693 | Perda G: -6.4115
# [Época 024] [Lote 600/937] Perda D: -0.2591 | Perda G: -6.8913
# [Época 024] [Lote 700/937] Perda D: 0.1555 | Perda G: -8.4568
# [Época 024] [Lote 800/937] Perda D: -0.2882 | Perda G: -8.6492
# [Época 024] [Lote 900/937] Perda D: -0.3842 | Perda G: -7.0033
# [Época 024] [Lote 936/937] Perda D: -0.3100 | Perda G: -8.0135
# [Época 025] [Lote 000/937] Perda D: -0.2999 | Perda G: -7.7360
# [Época 025] [Lote 100/937] Perda D: -0.1880 | Perda G: -7.9602
# [Época 025] [Lote 200/937] Perda D: -0.2972 | Perda G: -7.0231
# [Época 025] [Lote 300/937] Perda D: -0.2819 | Perda G: -7.2214
# [Época 025] [Lote 400/937] Perda D: -0.1391 | Perda G: -7.6790
# [Época 025] [Lote 500/937] Perda D: -0.2979 | Perda G: -6.8792
# [Época 025] [Lote 600/937] Perda D: -0.2937 | Perda G: -6.0592
# [Época 025] [Lote 700/937] Perda D: -0.2771 | Perda G: -7.2684
# [Época 025] [Lote 800/937] Perda D: -0.2934 | Perda G: -6.7837
# [Época 025] [Lote 900/937] Perda D: -0.1140 | Perda G: -6.0620
# [Época 025] [Lote 936/937] Perda D: -0.4262 | Perda G: -7.7546
# [Época 026] [Lote 000/937] Perda D: -0.5437 | Perda G: -8.0986
# [Época 026] [Lote 100/937] Perda D: -0.2196 | Perda G: -7.2275
# [Época 026] [Lote 200/937] Perda D: -0.2638 | Perda G: -8.1738
# [Época 026] [Lote 300/937] Perda D: -0.2779 | Perda G: -9.0541
# [Época 026] [Lote 400/937] Perda D: -0.0845 | Perda G: -9.6238
# [Época 026] [Lote 500/937] Perda D: -0.1451 | Perda G: -7.8024
# [Época 026] [Lote 600/937] Perda D: -0.2525 | Perda G: -8.5610
# [Época 026] [Lote 700/937] Perda D: -0.4471 | Perda G: -5.9881
# [Época 026] [Lote 800/937] Perda D: -0.1426 | Perda G: -7.5836
# [Época 026] [Lote 900/937] Perda D: -0.1780 | Perda G: -7.9924
# [Época 026] [Lote 936/937] Perda D: -0.3269 | Perda G: -7.0312
# [Época 027] [Lote 000/937] Perda D: -0.2369 | Perda G: -8.0003
# [Época 027] [Lote 100/937] Perda D: 0.0547 | Perda G: -9.5808
# [Época 027] [Lote 200/937] Perda D: -0.3016 | Perda G: -8.3040
# [Época 027] [Lote 300/937] Perda D: -0.1617 | Perda G: -6.8114
# [Época 027] [Lote 400/937] Perda D: -0.2649 | Perda G: -8.0867
# [Época 027] [Lote 500/937] Perda D: -0.4835 | Perda G: -9.9436
# [Época 027] [Lote 600/937] Perda D: -0.0898 | Perda G: -9.3970
# [Época 027] [Lote 700/937] Perda D: -0.5193 | Perda G: -6.2356
# [Época 027] [Lote 800/937] Perda D: 0.0574 | Perda G: -8.7877
# [Época 027] [Lote 900/937] Perda D: -0.0578 | Perda G: -8.2771
# [Época 027] [Lote 936/937] Perda D: -0.3713 | Perda G: -7.4754
# [Época 028] [Lote 000/937] Perda D: -0.2390 | Perda G: -7.9259
# [Época 028] [Lote 100/937] Perda D: -0.2773 | Perda G: -7.6597
# [Época 028] [Lote 200/937] Perda D: -0.2886 | Perda G: -8.4584
# [Época 028] [Lote 300/937] Perda D: -0.2500 | Perda G: -7.8687
# [Época 028] [Lote 400/937] Perda D: -0.3595 | Perda G: -8.2051
# [Época 028] [Lote 500/937] Perda D: -0.1891 | Perda G: -7.8150
# [Época 028] [Lote 600/937] Perda D: -0.6000 | Perda G: -9.8168
# [Época 028] [Lote 700/937] Perda D: -0.6545 | Perda G: -10.5238
# [Época 028] [Lote 800/937] Perda D: -0.2477 | Perda G: -8.7927
# [Época 028] [Lote 900/937] Perda D: -0.1070 | Perda G: -9.3361
# [Época 028] [Lote 936/937] Perda D: -0.1425 | Perda G: -8.1681
# [Época 029] [Lote 000/937] Perda D: -0.3597 | Perda G: -9.7367
# [Época 029] [Lote 100/937] Perda D: -0.1752 | Perda G: -7.7734
# [Época 029] [Lote 200/937] Perda D: -0.2961 | Perda G: -8.0544
# [Época 029] [Lote 300/937] Perda D: -0.3165 | Perda G: -8.0104
# [Época 029] [Lote 400/937] Perda D: -0.1131 | Perda G: -8.8095
# [Época 029] [Lote 500/937] Perda D: -0.1708 | Perda G: -7.2915
# [Época 029] [Lote 600/937] Perda D: -0.4454 | Perda G: -8.9203
# [Época 029] [Lote 700/937] Perda D: -0.2105 | Perda G: -8.9044
# [Época 029] [Lote 800/937] Perda D: -0.1974 | Perda G: -7.7109
# [Época 029] [Lote 900/937] Perda D: -0.0868 | Perda G: -7.5758
# [Época 029] [Lote 936/937] Perda D: -0.1555 | Perda G: -7.8388
# [Época 030] [Lote 000/937] Perda D: -0.1747 | Perda G: -8.8847
# [Época 030] [Lote 100/937] Perda D: -0.1447 | Perda G: -7.9629
# [Época 030] [Lote 200/937] Perda D: -0.2169 | Perda G: -9.5283
# [Época 030] [Lote 300/937] Perda D: -0.0654 | Perda G: -7.6341
# [Época 030] [Lote 400/937] Perda D: -0.4357 | Perda G: -7.7502
# [Época 030] [Lote 500/937] Perda D: -0.2219 | Perda G: -9.3505
# [Época 030] [Lote 600/937] Perda D: -0.3203 | Perda G: -7.6325
# [Época 030] [Lote 700/937] Perda D: -0.3405 | Perda G: -10.0714
# [Época 030] [Lote 800/937] Perda D: -0.2555 | Perda G: -8.8642
# [Época 030] [Lote 900/937] Perda D: -0.3714 | Perda G: -8.1231
# [Época 030] [Lote 936/937] Perda D: -0.1796 | Perda G: -7.3049
# [Época 031] [Lote 000/937] Perda D: -0.0408 | Perda G: -8.8179
# [Época 031] [Lote 100/937] Perda D: -0.0924 | Perda G: -7.7901
# [Época 031] [Lote 200/937] Perda D: -0.2267 | Perda G: -9.2264
# [Época 031] [Lote 300/937] Perda D: -0.2159 | Perda G: -7.6091
# [Época 031] [Lote 400/937] Perda D: -0.3312 | Perda G: -7.8764
# [Época 031] [Lote 500/937] Perda D: -0.1228 | Perda G: -7.4674
# [Época 031] [Lote 600/937] Perda D: -0.2514 | Perda G: -8.8684
# [Época 031] [Lote 700/937] Perda D: -0.1410 | Perda G: -7.8410
# [Época 031] [Lote 800/937] Perda D: -0.0969 | Perda G: -8.0295
# [Época 031] [Lote 900/937] Perda D: -0.2585 | Perda G: -7.6045
# [Época 031] [Lote 936/937] Perda D: -0.1238 | Perda G: -8.6521
# [Época 032] [Lote 000/937] Perda D: -0.1863 | Perda G: -8.6040
# [Época 032] [Lote 100/937] Perda D: -0.0683 | Perda G: -7.4157
# [Época 032] [Lote 200/937] Perda D: -0.1334 | Perda G: -8.6765
# [Época 032] [Lote 300/937] Perda D: -0.0446 | Perda G: -8.9007
# [Época 032] [Lote 400/937] Perda D: -0.1846 | Perda G: -7.6566
# [Época 032] [Lote 500/937] Perda D: -0.2723 | Perda G: -8.2217
# [Época 032] [Lote 600/937] Perda D: 0.0940 | Perda G: -7.7049
# [Época 032] [Lote 700/937] Perda D: -0.4396 | Perda G: -8.1626
# [Época 032] [Lote 800/937] Perda D: -0.0209 | Perda G: -9.2689
# [Época 032] [Lote 900/937] Perda D: -0.2653 | Perda G: -9.2147
# [Época 032] [Lote 936/937] Perda D: -0.1803 | Perda G: -8.1089
# [Época 033] [Lote 000/937] Perda D: -0.1844 | Perda G: -8.6487
# [Época 033] [Lote 100/937] Perda D: -0.1976 | Perda G: -8.5996
# [Época 033] [Lote 200/937] Perda D: -0.1538 | Perda G: -7.9425
# [Época 033] [Lote 300/937] Perda D: -0.0531 | Perda G: -8.7042
# [Época 033] [Lote 400/937] Perda D: -0.2605 | Perda G: -8.1377
# [Época 033] [Lote 500/937] Perda D: -0.3116 | Perda G: -8.5681
# [Época 033] [Lote 600/937] Perda D: 0.0720 | Perda G: -7.9654
# [Época 033] [Lote 700/937] Perda D: -0.2671 | Perda G: -7.7626
# [Época 033] [Lote 800/937] Perda D: -0.1220 | Perda G: -8.2014
# [Época 033] [Lote 900/937] Perda D: 0.0524 | Perda G: -9.1699
# [Época 033] [Lote 936/937] Perda D: 0.0744 | Perda G: -7.4028
# [Época 034] [Lote 000/937] Perda D: -0.0139 | Perda G: -8.4154
# [Época 034] [Lote 100/937] Perda D: 0.0020 | Perda G: -8.4632
# [Época 034] [Lote 200/937] Perda D: -0.2122 | Perda G: -7.7927
# [Época 034] [Lote 300/937] Perda D: 0.0601 | Perda G: -7.7243
# [Época 034] [Lote 400/937] Perda D: -0.2013 | Perda G: -8.0347
# [Época 034] [Lote 500/937] Perda D: -0.2435 | Perda G: -8.8396
# [Época 034] [Lote 600/937] Perda D: -0.1364 | Perda G: -7.7868
# [Época 034] [Lote 700/937] Perda D: 0.1439 | Perda G: -8.4426
# [Época 034] [Lote 800/937] Perda D: -0.2395 | Perda G: -8.7222
# [Época 034] [Lote 900/937] Perda D: -0.3246 | Perda G: -8.8176
# [Época 034] [Lote 936/937] Perda D: -0.1814 | Perda G: -7.9931
# [Época 035] [Lote 000/937] Perda D: -0.2115 | Perda G: -7.6839
# [Época 035] [Lote 100/937] Perda D: -0.0864 | Perda G: -8.7266
# [Época 035] [Lote 200/937] Perda D: -0.0012 | Perda G: -7.3715
# [Época 035] [Lote 300/937] Perda D: -0.2861 | Perda G: -8.6603
# [Época 035] [Lote 400/937] Perda D: -0.0582 | Perda G: -7.9945
# [Época 035] [Lote 500/937] Perda D: 0.0735 | Perda G: -8.5839
# [Época 035] [Lote 600/937] Perda D: -0.3203 | Perda G: -7.9643
# [Época 035] [Lote 700/937] Perda D: -0.3068 | Perda G: -6.9997
# [Época 035] [Lote 800/937] Perda D: -0.2483 | Perda G: -8.4360
# [Época 035] [Lote 900/937] Perda D: -0.3416 | Perda G: -8.6646
# [Época 035] [Lote 936/937] Perda D: -0.0539 | Perda G: -7.5363
# [Época 036] [Lote 000/937] Perda D: -0.1405 | Perda G: -6.8917
# [Época 036] [Lote 100/937] Perda D: -0.2688 | Perda G: -9.1896
# [Época 036] [Lote 200/937] Perda D: -0.2468 | Perda G: -8.9789
# [Época 036] [Lote 300/937] Perda D: -0.6024 | Perda G: -8.8711
# [Época 036] [Lote 400/937] Perda D: -0.3057 | Perda G: -8.1174
# [Época 036] [Lote 500/937] Perda D: -0.0748 | Perda G: -8.8945
# [Época 036] [Lote 600/937] Perda D: 0.0364 | Perda G: -8.3255
# [Época 036] [Lote 700/937] Perda D: -0.4779 | Perda G: -7.6431
# [Época 036] [Lote 800/937] Perda D: -0.1993 | Perda G: -8.3800
# [Época 036] [Lote 900/937] Perda D: -0.1383 | Perda G: -7.5957
# [Época 036] [Lote 936/937] Perda D: -0.1122 | Perda G: -8.1456
# [Época 037] [Lote 000/937] Perda D: -0.1946 | Perda G: -7.3486
# [Época 037] [Lote 100/937] Perda D: -0.2294 | Perda G: -7.5023
# [Época 037] [Lote 200/937] Perda D: -0.0261 | Perda G: -8.3062
# [Época 037] [Lote 300/937] Perda D: -0.2884 | Perda G: -7.4522
# [Época 037] [Lote 400/937] Perda D: -0.0325 | Perda G: -8.3140
# [Época 037] [Lote 500/937] Perda D: -0.0906 | Perda G: -8.2645
# [Época 037] [Lote 600/937] Perda D: -0.1625 | Perda G: -8.0261
# [Época 037] [Lote 700/937] Perda D: -0.2996 | Perda G: -8.5197
# [Época 037] [Lote 800/937] Perda D: -0.2555 | Perda G: -8.1821
# [Época 037] [Lote 900/937] Perda D: -0.3516 | Perda G: -8.3324
# [Época 037] [Lote 936/937] Perda D: -0.1599 | Perda G: -9.2772
# [Época 038] [Lote 000/937] Perda D: -0.0697 | Perda G: -9.2167
# [Época 038] [Lote 100/937] Perda D: -0.1736 | Perda G: -8.6053
# [Época 038] [Lote 200/937] Perda D: 0.3524 | Perda G: -8.5641
# [Época 038] [Lote 300/937] Perda D: -0.2443 | Perda G: -7.3793
# [Época 038] [Lote 400/937] Perda D: -0.1325 | Perda G: -8.5039
# [Época 038] [Lote 500/937] Perda D: -0.2164 | Perda G: -8.0832
# [Época 038] [Lote 600/937] Perda D: -0.1075 | Perda G: -8.5223
# [Época 038] [Lote 700/937] Perda D: -0.1083 | Perda G: -7.3421
# [Época 038] [Lote 800/937] Perda D: -0.0034 | Perda G: -8.0695
# [Época 038] [Lote 900/937] Perda D: -0.2548 | Perda G: -8.4019
# [Época 038] [Lote 936/937] Perda D: -0.3284 | Perda G: -8.3004
# [Época 039] [Lote 000/937] Perda D: -0.0515 | Perda G: -8.4022
# [Época 039] [Lote 100/937] Perda D: -0.0643 | Perda G: -8.6929
# [Época 039] [Lote 200/937] Perda D: -0.1567 | Perda G: -8.3022
# [Época 039] [Lote 300/937] Perda D: 0.0043 | Perda G: -7.6147
# [Época 039] [Lote 400/937] Perda D: -0.1086 | Perda G: -8.5393
# [Época 039] [Lote 500/937] Perda D: -0.1731 | Perda G: -8.6227
# [Época 039] [Lote 600/937] Perda D: 0.1517 | Perda G: -7.7621
# [Época 039] [Lote 700/937] Perda D: -0.0749 | Perda G: -9.0628
# [Época 039] [Lote 800/937] Perda D: 0.0061 | Perda G: -7.9854
# [Época 039] [Lote 900/937] Perda D: -0.2873 | Perda G: -8.4846
# [Época 039] [Lote 936/937] Perda D: -0.2151 | Perda G: -9.3457
# [Época 040] [Lote 000/937] Perda D: 0.0057 | Perda G: -7.5404
# [Época 040] [Lote 100/937] Perda D: 0.1215 | Perda G: -7.9661
# [Época 040] [Lote 200/937] Perda D: 0.0735 | Perda G: -9.2853
# [Época 040] [Lote 300/937] Perda D: -0.0393 | Perda G: -9.3021
# [Época 040] [Lote 400/937] Perda D: -0.3543 | Perda G: -7.6738
# [Época 040] [Lote 500/937] Perda D: -0.2305 | Perda G: -8.2745
# [Época 040] [Lote 600/937] Perda D: -0.1867 | Perda G: -7.4396
# [Época 040] [Lote 700/937] Perda D: -0.2896 | Perda G: -7.6525
# [Época 040] [Lote 800/937] Perda D: -0.3467 | Perda G: -9.1310
# [Época 040] [Lote 900/937] Perda D: -0.0518 | Perda G: -8.3739
# [Época 040] [Lote 936/937] Perda D: -0.2428 | Perda G: -8.9599
# [Época 041] [Lote 000/937] Perda D: -0.1705 | Perda G: -9.1007
# [Época 041] [Lote 100/937] Perda D: -0.0867 | Perda G: -9.0530
# [Época 041] [Lote 200/937] Perda D: -0.0414 | Perda G: -8.8199
# [Época 041] [Lote 300/937] Perda D: -0.1892 | Perda G: -8.2238
# [Época 041] [Lote 400/937] Perda D: -0.1923 | Perda G: -8.4045
# [Época 041] [Lote 500/937] Perda D: -0.1340 | Perda G: -7.6797
# [Época 041] [Lote 600/937] Perda D: -0.1640 | Perda G: -9.7419
# [Época 041] [Lote 700/937] Perda D: -0.1418 | Perda G: -7.8577
# [Época 041] [Lote 800/937] Perda D: -0.2144 | Perda G: -9.4361
# [Época 041] [Lote 900/937] Perda D: -0.1617 | Perda G: -8.1659
# [Época 041] [Lote 936/937] Perda D: -0.3035 | Perda G: -8.5117
# [Época 042] [Lote 000/937] Perda D: -0.1059 | Perda G: -8.6440
# [Época 042] [Lote 100/937] Perda D: -0.1195 | Perda G: -7.5407
# [Época 042] [Lote 200/937] Perda D: -0.0745 | Perda G: -8.8623
# [Época 042] [Lote 300/937] Perda D: -0.3067 | Perda G: -7.3684
# [Época 042] [Lote 400/937] Perda D: -0.2199 | Perda G: -9.0721
# [Época 042] [Lote 500/937] Perda D: -0.2155 | Perda G: -8.2453
# [Época 042] [Lote 600/937] Perda D: -0.0071 | Perda G: -8.9612
# [Época 042] [Lote 700/937] Perda D: -0.2265 | Perda G: -8.3464
# [Época 042] [Lote 800/937] Perda D: -0.2628 | Perda G: -8.4105
# [Época 042] [Lote 900/937] Perda D: -0.3101 | Perda G: -8.3197
# [Época 042] [Lote 936/937] Perda D: -0.3141 | Perda G: -8.2641
# [Época 043] [Lote 000/937] Perda D: -0.2034 | Perda G: -7.3978
# [Época 043] [Lote 100/937] Perda D: -0.1801 | Perda G: -7.0616
# [Época 043] [Lote 200/937] Perda D: -0.0328 | Perda G: -9.0146
# [Época 043] [Lote 300/937] Perda D: -0.0746 | Perda G: -9.0514
# [Época 043] [Lote 400/937] Perda D: -0.1228 | Perda G: -8.6611
# [Época 043] [Lote 500/937] Perda D: -0.1526 | Perda G: -8.5291
# [Época 043] [Lote 600/937] Perda D: -0.2799 | Perda G: -7.9427
# [Época 043] [Lote 700/937] Perda D: -0.1379 | Perda G: -7.9301
# [Época 043] [Lote 800/937] Perda D: 0.0341 | Perda G: -9.2379
# [Época 043] [Lote 900/937] Perda D: -0.0616 | Perda G: -8.6150
# [Época 043] [Lote 936/937] Perda D: -0.3016 | Perda G: -7.4738
# [Época 044] [Lote 000/937] Perda D: -0.0976 | Perda G: -8.2717
# [Época 044] [Lote 100/937] Perda D: -0.3108 | Perda G: -9.0587
# [Época 044] [Lote 200/937] Perda D: -0.2484 | Perda G: -9.1899
# [Época 044] [Lote 300/937] Perda D: -0.2096 | Perda G: -8.1165
# [Época 044] [Lote 400/937] Perda D: -0.2011 | Perda G: -8.6390
# [Época 044] [Lote 500/937] Perda D: -0.0192 | Perda G: -8.3126
# [Época 044] [Lote 600/937] Perda D: -0.2164 | Perda G: -9.1693
# [Época 044] [Lote 700/937] Perda D: -0.2525 | Perda G: -8.4332
# [Época 044] [Lote 800/937] Perda D: 0.0546 | Perda G: -8.2453
# [Época 044] [Lote 900/937] Perda D: -0.1611 | Perda G: -8.0335
# [Época 044] [Lote 936/937] Perda D: -0.3046 | Perda G: -8.4945
# [Época 045] [Lote 000/937] Perda D: -0.2969 | Perda G: -8.6892
# [Época 045] [Lote 100/937] Perda D: -0.1055 | Perda G: -8.5149
# [Época 045] [Lote 200/937] Perda D: -0.1718 | Perda G: -7.7090
# [Época 045] [Lote 300/937] Perda D: -0.4400 | Perda G: -6.9549
# [Época 045] [Lote 400/937] Perda D: -0.2424 | Perda G: -7.9574
# [Época 045] [Lote 500/937] Perda D: -0.2236 | Perda G: -8.1059
# [Época 045] [Lote 600/937] Perda D: 0.0614 | Perda G: -7.8351
# [Época 045] [Lote 700/937] Perda D: -0.2449 | Perda G: -7.2491
# [Época 045] [Lote 800/937] Perda D: -0.1894 | Perda G: -7.2052
# [Época 045] [Lote 900/937] Perda D: -0.0589 | Perda G: -8.8570
# [Época 045] [Lote 936/937] Perda D: -0.0925 | Perda G: -8.3283
# [Época 046] [Lote 000/937] Perda D: 0.0280 | Perda G: -9.8963
# [Época 046] [Lote 100/937] Perda D: -0.1774 | Perda G: -7.5266
# [Época 046] [Lote 200/937] Perda D: 0.0592 | Perda G: -8.7149
# [Época 046] [Lote 300/937] Perda D: 0.0988 | Perda G: -9.4638
# [Época 046] [Lote 400/937] Perda D: -0.1286 | Perda G: -8.4293
# [Época 046] [Lote 500/937] Perda D: -0.1637 | Perda G: -9.1886
# [Época 046] [Lote 600/937] Perda D: -0.1226 | Perda G: -8.6132
# [Época 046] [Lote 700/937] Perda D: 0.0234 | Perda G: -7.1594
# [Época 046] [Lote 800/937] Perda D: -0.4400 | Perda G: -7.6935
# [Época 046] [Lote 900/937] Perda D: -0.1396 | Perda G: -8.1895
# [Época 046] [Lote 936/937] Perda D: -0.0774 | Perda G: -8.4005
# [Época 047] [Lote 000/937] Perda D: -0.2228 | Perda G: -8.1614
# [Época 047] [Lote 100/937] Perda D: -0.0606 | Perda G: -7.3986
# [Época 047] [Lote 200/937] Perda D: -0.1001 | Perda G: -8.0096
# [Época 047] [Lote 300/937] Perda D: -0.1217 | Perda G: -8.1948
# [Época 047] [Lote 400/937] Perda D: -0.1148 | Perda G: -8.6545
# [Época 047] [Lote 500/937] Perda D: -0.0788 | Perda G: -8.0130
# [Época 047] [Lote 600/937] Perda D: -0.2057 | Perda G: -9.4385
# [Época 047] [Lote 700/937] Perda D: -0.2737 | Perda G: -7.9778
# [Época 047] [Lote 800/937] Perda D: -0.2030 | Perda G: -8.2297
# [Época 047] [Lote 900/937] Perda D: -0.4562 | Perda G: -7.7511
# [Época 047] [Lote 936/937] Perda D: -0.2304 | Perda G: -9.6811
# [Época 048] [Lote 000/937] Perda D: -0.0934 | Perda G: -9.1218
# [Época 048] [Lote 100/937] Perda D: 0.0552 | Perda G: -8.1844
# [Época 048] [Lote 200/937] Perda D: -0.1727 | Perda G: -8.8967
# [Época 048] [Lote 300/937] Perda D: 0.0643 | Perda G: -7.2274
# [Época 048] [Lote 400/937] Perda D: -0.1561 | Perda G: -7.8703
# [Época 048] [Lote 500/937] Perda D: -0.3249 | Perda G: -8.7006
# [Época 048] [Lote 600/937] Perda D: -0.1735 | Perda G: -7.9219
# [Época 048] [Lote 700/937] Perda D: -0.1606 | Perda G: -7.2956
# [Época 048] [Lote 800/937] Perda D: -0.1677 | Perda G: -8.7809
# [Época 048] [Lote 900/937] Perda D: -0.0467 | Perda G: -8.9172
# [Época 048] [Lote 936/937] Perda D: -0.2176 | Perda G: -8.0252
# [Época 049] [Lote 000/937] Perda D: -0.0614 | Perda G: -7.6603
# [Época 049] [Lote 100/937] Perda D: -0.2808 | Perda G: -7.8423
# [Época 049] [Lote 200/937] Perda D: 0.0594 | Perda G: -7.2622
# [Época 049] [Lote 300/937] Perda D: -0.2956 | Perda G: -7.0646
# [Época 049] [Lote 400/937] Perda D: -0.1382 | Perda G: -7.4919
# [Época 049] [Lote 500/937] Perda D: -0.2309 | Perda G: -7.3810
# [Época 049] [Lote 600/937] Perda D: -0.1896 | Perda G: -7.4806
# [Época 049] [Lote 700/937] Perda D: -0.2189 | Perda G: -7.9717
# [Época 049] [Lote 800/937] Perda D: -0.3296 | Perda G: -8.3366
# [Época 049] [Lote 900/937] Perda D: -0.1386 | Perda G: -8.3079
# [Época 049] [Lote 936/937] Perda D: 0.0564 | Perda G: -7.8403
# [Época 050] [Lote 000/937] Perda D: -0.1547 | Perda G: -8.6017
# [Época 050] [Lote 100/937] Perda D: -0.1319 | Perda G: -7.6346
# [Época 050] [Lote 200/937] Perda D: -0.1533 | Perda G: -7.4553
# [Época 050] [Lote 300/937] Perda D: -0.1682 | Perda G: -7.3752
# [Época 050] [Lote 400/937] Perda D: -0.2265 | Perda G: -8.0376
# [Época 050] [Lote 500/937] Perda D: -0.2589 | Perda G: -8.5036
# [Época 050] [Lote 600/937] Perda D: -0.1925 | Perda G: -8.8395
# [Época 050] [Lote 700/937] Perda D: -0.2140 | Perda G: -7.6291
# [Época 050] [Lote 800/937] Perda D: -0.2813 | Perda G: -7.7215
# [Época 050] [Lote 900/937] Perda D: -0.1856 | Perda G: -8.8725
# [Época 050] [Lote 936/937] Perda D: -0.5604 | Perda G: -8.8760
# Fim!

# %% [markdown]
# # Resultados

# %%
# Salva gerador treinado
torch.save(modelo_gerador.state_dict(), "gerador_wgan_condicional.pth")

# %%
z_dim = 100
device = "cpu"
modelo_gerador = Gerador(z_dim)
modelo_gerador.load_state_dict(torch.load("wgan_ruim.pth", weights_only=False))
# Out:
# <All keys matched successfully>

# %%
# Plotar evolução da loss para discriminador e gerador 
plt.figure(figsize=(10, 5))
plt.plot(hist_loss_discriminador, label="Perda Crítico")
plt.plot(hist_loss_gerador, label="Perda Gerador")
plt.xlabel("Épocas")
plt.ylabel("Perda")
plt.legend()
plt.title("Evolução da Perda - WGAN Condicional")
plt.show()

# %%
# Gera dados falsos com vetores latentes aleatórios e rótulos aleatórios
def gerar_aleatorio(modelo_gerador, device, z_dim=100, n_images=20, num_classes=10):
    modelo_gerador.eval()  # Modo de avaliação (desativa dropout, batchnorm, etc.)

    # Gera vetores de ruído aleatórios
    z = torch.randn((n_images, z_dim), device=device)

    # Gera rótulos inteiros aleatórios e converte para one-hot
    rotulos_aleatorios = torch.randint(0, num_classes, (n_images,), device=device)
    rotulos_aleatorios_one_hot = F.one_hot(rotulos_aleatorios, num_classes=num_classes).float()

    # Desativa o cálculo de gradientes
    with torch.no_grad():
        # Gera dados falsos passando (z, rotulos_one_hot) para o gerador condicional
        dados_falsos = modelo_gerador(z, rotulos_aleatorios_one_hot)
        dados_falsos = dados_falsos.detach().cpu().numpy()

    return dados_falsos, rotulos_aleatorios

# %%
# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, rotulos, n_cols=7):
    classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, (img, c) in enumerate(zip(imagens, rotulos)):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.title(classes[c.item()])
        plt.axis("off")
    plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=1.0)
    plt.show()

# %%
imagens, rotulos = gerar_aleatorio(
    modelo_gerador,   # gerador condicional
    device,           # dispositivo: 'cpu' ou 'cuda'
    z_dim=z_dim,      # dimensão do vetor latente
    n_images=28,      # número de imagens que desejamos gerar
    num_classes=10    # número de classes do conjunto de dados
)

# Chama a função para plotar as imagens em grade
plot_multiple_images(imagens, rotulos, n_cols=7)

# %%
# Gera n imagens para uma única classe (mantendo o rótulo fixo e variando o ruído)
def gerar_imagens_por_classe(modelo_gerador, device, classe_especifica, n_images=20, z_dim=100, num_classes=10):
    modelo_gerador.eval()  # Modo de avaliação

    # Vetores de ruído aleatórios
    z = torch.randn((n_images, z_dim), device=device)

    # Rótulo fixo
    rotulos = torch.full((n_images,), classe_especifica, device=device, dtype=torch.long)

    # Converte para one-hot
    rotulos_one_hot = F.one_hot(rotulos, num_classes=num_classes).float()

    # Gera as imagens com o gerador condicional
    with torch.no_grad():
        imagens_geradas = modelo_gerador(z, rotulos_one_hot)
        imagens_geradas = imagens_geradas.detach().cpu().numpy()

    return imagens_geradas, rotulos

# %%
# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, n_cols=7):
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, img in enumerate(imagens):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=1.0)
    plt.show()

# %%
imagens, rotulos = gerar_imagens_por_classe(
    modelo_gerador,
    device,
    classe_especifica=9,
    n_images=28,
    z_dim=z_dim,
    num_classes=10
)

plot_multiple_images(imagens, n_cols=7)

# %% [markdown]
# # Evolução das saídas do gerador para um vetor latente fixo durante o treinamento

# %%
# Lista com imagens 8x8
imagens = evolução_dado_falso

# Cria subplots (1 linha, -1 colunas)
fig, axes = plt.subplots(1, len(evolução_dado_falso), figsize=(15, 2))

# Itera por cada subplot e mostra a imagem
for ax, img in zip(axes, imagens):
    ax.imshow(img, cmap='gray')    # 1 = preto, 0 = branco
    ax.axis('off')                 # Remove ticks dos eixos

# ajusta o espaçamento entre subplots
plt.subplots_adjust(wspace=0.1)  # aumente para um maior espaçamento entre as imagens

plt.show()

# %%
def interp_z_fixo(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_1=0,
    classe_2=9,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera um vetor de ruído fixo (z) com dimensão z_dim
    z_fix = torch.randn((1, z_dim), device=device)

    # Cria os vetores one-hot correspondentes às classes iniciais e finais
    c1 = F.one_hot(torch.tensor([classe_1], device=device), num_classes).float()
    c2 = F.one_hot(torch.tensor([classe_2], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Expande os rótulos iniciais e finais para steps linhas
    c1_b = c1.expand(steps, -1)
    c2_b = c2.expand(steps, -1)

    # Interpola linearmente entre c1 e c2 ao longo de steps
    c_seq = torch.lerp(c1_b, c2_b, alphas.view(-1, 1))      # lerp(a,b,alpha) = (1 - alpha) * a + alpha * b

    # Repete o mesmo vetor z_fix para todos os steps
    z_batch = z_fix.expand(steps, -1)

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_batch, c_seq)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return


interp_z_fixo(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_1=1,         # classe 1
    classe_2=7,         # classe 2
    steps=15,           # número de passos da interpolação
    seed=5              # semente para reprodutibilidade
)

# %%
def interp_c_fixo(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_fixa=0,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera dois vetores de ruído aleatórios (z1 e z2), que serão os pontos extremos da interpolação
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    # Cria o vetor one-hot correspondente ao rótulo fixo
    c_fix = F.one_hot(torch.tensor([classe_fixa], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Expande os vetores z1 e z2 para steps linhas
    z1_b = z1.expand(steps, -1)
    z2_b = z2.expand(steps, -1)

    # Interpola linearmente entre z1 e z2 ao longo de steps: (1 - alpha) * z1_b + alpha * z2_b
    z_seq = torch.lerp(z1_b, z2_b, alphas.view(-1, 1))

    # Repete o mesmo rótulo fixo para todos os steps
    c_batch = c_fix.expand(steps, -1)

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_seq, c_batch)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return

interp_c_fixo(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_fixa=1,      # rótulo fixo escolhido
    steps=15,           # número de passos da interpolação
    seed=0              # semente para reprodutibilidade
)

# %%
def interp_z_e_c(
    gerador,
    device,
    z_dim=100,
    num_classes=10,
    classe_1=1,
    classe_2=7,
    steps=10,
    seed=42,
):
    torch.manual_seed(seed)  # Define a semente para reprodutibilidade

    # Gera dois vetores de ruído aleatórios (z1 e z2), que serão os pontos extremos da interpolação
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    # Cria os vetores one-hot correspondentes às classes inicial e final
    c1 = F.one_hot(torch.tensor([classe_1], device=device), num_classes).float()
    c2 = F.one_hot(torch.tensor([classe_2], device=device), num_classes).float()

    # Cria valores entre 0 e 1 igualmente espaçados para interpolação
    alphas = torch.linspace(0, 1, steps, device=device)

    # Interpola linearmente entre z1 e z2 ao longo de steps: (1 - alpha) * z1_b + alpha * z2_b
    z1_b = z1.expand(steps, -1)
    z2_b = z2.expand(steps, -1)
    z_seq = torch.lerp(z1_b, z2_b, alphas.view(-1, 1))

    # Interpola linearmente entre c1 e c2 ao longo de steps (rótulos suaves): (1 - alpha) * c1_b + alpha * c2_b
    c1_b = c1.expand(steps, -1)
    c2_b = c2.expand(steps, -1)
    c_seq = torch.lerp(c1_b, c2_b, alphas.view(-1, 1))

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imgs = gerador(z_seq, c_seq)

    # Converte cada imagem gerada para numpy e remove dimensões extras
    interpolados = [img.squeeze().cpu().numpy() for img in imgs]

    # Plota as imagens em um grid
    plot_multiple_images(interpolados, n_cols=steps)

    return

interp_z_e_c(
    gerador=modelo_gerador,
    device=device,
    z_dim=z_dim,        # dimensão latente usada no treinamento
    num_classes=10,     # número de classes do conjunto de dados
    classe_1=1,         # classe inicial
    classe_2=7,         # classe final
    steps=15,           # número de passos da interpolação
    seed=1              # semente para reprodutibilidade
)

# %%
def variar_classe_fixa_z(gerador, device, z_dim=100, num_classes=10):
    # Gera um único vetor de ruído aleatório e o repete para todas as classes
    # Assim, apenas o rótulo varia enquanto o ruído (z) permanece fixo
    z = torch.randn((1, z_dim), device=device).repeat(num_classes, 1)

    # Cria um vetor com todas as classes (0 a num_classes-1)
    classes = torch.arange(0, num_classes, device=device)

    # Converte cada classe para representação one-hot
    rotulos_one_hot = F.one_hot(classes, num_classes=num_classes).float()

    # Desativa o cálculo de gradientes durante a geração
    with torch.no_grad():
        gerador.eval()
        imagens = gerador(z, rotulos_one_hot).cpu().numpy()

    # Lista de nomes correspondentes às classes do FashionMNIST
    nomes_classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
                     "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

    # Define o layout da grade para visualização
    n_cols = 5
    n_rows = (num_classes - 1) // n_cols + 1
    plt.figure(figsize=(n_cols * 2, n_rows * 2))

    # Plota cada imagem correspondente ao rótulo fixo de z
    for i, (img, nome) in enumerate(zip(imagens, nomes_classes)):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.title(nome, fontsize=8)
        plt.axis("off")

    # Ajusta espaçamentos da figura
    plt.tight_layout()
    plt.show()


variar_classe_fixa_z(modelo_gerador, device, z_dim=z_dim)

# %% [markdown]
# # Tarefa:
#
# 1. Implementar uma WCGAN condicional e treinar o modelo com o conjunto de dados Fashion MNIST.
#
# 2. Interpolar entre vetores de ruído e mostrar as imagens intermediárias considerando:
#
#     a. z fixo e interpolacão linear entre classes [c1, c2].
#
#     b. classe c fixa e interpolaćão linear entre [z1, z2].
#
#     c. interpolaćão linear entre [z1, z2] e [c1, c2].
#
# 3. Fixe o vetor de ruído e altere apenas o rótulo para observar como a imagem muda.
#
# **Entregáveis**:
# 1. Notebook `.ipynb`.
# 2. Relatório `.pdf`:
#
#     - Reporte e comente os resultados no relatório.
#
#     - Incluir imagens geradas.
